# %%
import os
from lxml import etree 
doc = etree.parse('../Data/xml_data/provenance.xml')

# %%
provenance = doc.findall('recordList/record/provenance')

# %%
print(provenance)
# Out:
# [<Element provenance at 0x1f77a2e9988>, <Element provenance at 0x1f77a2e9dc8>, <Element provenance at 0x1f77a2e9c08>, <Element provenance at 0x1f77a2e9948>, <Element provenance at 0x1f77a2e9908>, <Element provenance at 0x1f77a2e98c8>, <Element provenance at 0x1f77a2e9888>, <Element provenance at 0x1f77a2e9848>, <Element provenance at 0x1f77a2e9808>, <Element provenance at 0x1f77a2e97c8>, <Element provenance at 0x1f77a2e9788>, <Element provenance at 0x1f77a2e9748>, <Element provenance at 0x1f77a2e9708>, <Element provenance at 0x1f77a2e96c8>, <Element provenance at 0x1f77a2e9688>, <Element provenance at 0x1f77a2e9648>, <Element provenance at 0x1f77a2e9608>, <Element provenance at 0x1f77a2e95c8>, <Element provenance at 0x1f77a2e9588>, <Element provenance at 0x1f77a2e9548>, <Element provenance at 0x1f77a2e9508>, <Element provenance at 0x1f77a2e94c8>, <Element provenance at 0x1f77a2e9488>, <Element provenance at 0x1f77a2e9448>, <Element provenance at 0x1f77a2e9408>, <Element provenance at
# ...

# %%
for elements in provenance:
    element = elements.get('provenance.project.txt')
    print(element)
    
    issue: get None
# Out:
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# ...
