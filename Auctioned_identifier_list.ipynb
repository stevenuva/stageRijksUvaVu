# %%
#import everything that's necessary
import os
from lxml import etree

#get path where provenance XML file is stored
xml_path = input('Please enter the path to the provenance XML file on your computer. ')
doc = etree.parse(xml_path)
record_elem = doc.findall('recordList/record')
# Out:
# Please enter the path to the provenance XML file on your computer. ../Data/xml_data/provenance.xml

# %%
identifier_dict = dict()
for elem in record_elem[:401]:
    #get the identifier
    identifier = elem.find('PersistentIdentifier')
    identifier = identifier.text
    #get the provenance text
    provenance = elem.find('provenance/provenance.project.txt')
    if provenance == None:
        continue
    provenance = provenance.text
    #split the provenance text into its separate chunks
    provenance_list = provenance.split(';')
    for elem in provenance_list:
        #see what kind of element it is and go to that function
        elem_old = elem
        if 'Londen' in elem:
            elem.replace('Londen', 'London')
        if ' hrough ' in elem:
            elem.replace(' hrough ', ' through ')
        if ' throught ' in elem:
            elem.replace(' throught ', ' through ')
        if 'Christies' in elem:
            elem.replace('Christies', "Christie's")
        if 'Sothbys' in elem:
            elem.replace('Sothbys', "Sothby's")
        if 'Sale' in elem or 'sale' in elem:
            elem_new_format, elem_new_readable, parsed_dict = auction_item(elem)
        else: 
            continue
            
        format_dict = {'Old format' : elem_old, 'Format' : elem_new_format, 'Readable sentence' : elem_new_readable, 'Parsed objects': parsed_dict}
        identifier_dict[identifier] = format_dict
#print(identifier_dict)
identifiers = identifier_dict.keys()
for painting in identifiers:
    if identifier_dict[painting]['Parsed objects'] == 'Wrongly assigned due to source information':
        continue
    print(identifier_dict[painting])
    identifier = painting
    owner = identifier_dict[painting]['Parsed objects']['Owner name']
    buyer = identifier_dict[painting]['Parsed objects']['Buyer']
    if 'to the dealer' in buyer:
        buyer = buyer.replace('to the dealer ','')
    if 'to ' in buyer:
        buyer = buyer.replace('to ', '')
    if 'for the museum' in buyer:
        buyer = buyer.replace(' for the museum','')
    price = identifier_dict[painting]['Parsed objects']['Price']
    date_sale = identifier_dict[painting]['Parsed objects']['Date of auction']
    if '1' not in date_sale:
        date_sale = ''
    auctionhouse = identifier_dict[painting]['Parsed objects']['Auction house']
    print('Identifier ',identifier)
    print('Owner ',owner)
    print('Buyer ',buyer)
    print('Price ',price)
    print('Date sale ',date_sale)
    print('Auction house ',auctionhouse,'\n')
# Out:
# {'Old format': ' anonymous sale, The Hague (Glerum), 25 November 1991, no. 123, to the dealer R. Noortman for the museum', 'Format': 'anonymous sale, The Hague (Glerum), 25 November 1991, no. 123, to the dealer R. Noortman for the museum', 'Readable sentence': 'Sold by anonymous, auctioned off in The Hague (auction house Glerum) on 25 November 1991, no. 123, sold to the dealer R. Noortman for the museum.', 'Parsed objects': {'Source': '', 'Section of the sale': '', 'Owner name': '', 'Owner Birth and Death Date': '', 'Place collection was stored': '', 'Place of auction': 'The Hague', 'Auction house': 'Glerum', 'Date of auction': '25 November 1991', 'Kavel': 'no. 123', 'Attribution': '', 'Description': '', 'Pendant': '', 'Pendant extra information': '', 'Price': '', 'Buyer': 'to the dealer R. Noortman for the museum', 'City of buyer': '', 'Supporter of buy': ''}}
# Identifier  RM0001.COLLECT.2
# Owner
# Buyer  R. Noortman
# Price
# Date sale  25 November 1991
# Auction house  Glerum
#
# {'Old format': ' his sale, Amsterdam (F. Muller), 26 April 1976 sqq., no. 29', 'Format': 'his sale, Amsterdam (F. Muller), 26 April 1976 sqq., no. 29', 'Readable sentence': 'Sold by him, auctioned off in Amsterdam (auction house F. Muller) on 26 April 1976 sqq., no. 29.', 'Parsed objects': {'Source': '', 'Section of the sale': '', 'Owner name': '', 'Owner Birth and Death Date': '', 'Place collection was stored': '', 'Place of auction': 'Amsterdam', 'Auction house': 'F. Muller', 'Date of auction': '26 April 1976 sqq.', 'Kavel': 'no. 29', 'Attribution': '', 'Description': '', 'Pendant': '', 'Pendant extra information': '', 'Price': '', 'Buyer': '', 'City of buyer': '', 'Supporter of buy': ''}}
# Identifier  RM0001.COLLECT.9
# Owner
# Buyer
# Price
# Date sale  26 April 1976 sqq.
# Auction house  F. Muller
#
# {'Old format': "{Coll. cat. Weill III, p. 463.} sale, Irwin Laughlin et al. [section 'The property of a gentleman', probably David Weill], London (Sotheby's), 10 June 1959, no. 131, £ 1,100, to the dealer Colnaghi for the museum, with support from the Vereniging Rembrandt", 'Format': "{Coll. cat. Weill III, p. 463.} sale, Irwin Laughlin et al. [section 'The property of a gentleman' [section 'The property of a gentleman', probably David Weill], 10 June 1959, no. 131, £ 1,100, to the dealer Colnaghi for the museum, with support from the Vereniging Rembrandt", 'Readable sentence': "Sold by Irwin Laughlin et al. [section 'The property of a gentleman' [section 'The property of a gentleman', probably David Weill], auctioned off in 10 June 1959, no. 131, bought for £ 1,100, sold to the dealer Colnaghi for the museum, with support from the Vereniging Rembrandt.", 'Parsed objects': {'Source': '{Coll. cat. Weill III, p. 463.}', 'Section of the sale': '', 'Owner name': "Irwin Laughlin et al. [section 'The property of a gentleman' [section 'The property of a gentleman', probably David Weill]", 'Owner Birth and Death Date': '', 'Place collection was stored': '', 'Place of auction': '10 June 1959', 'Auction house': '', 'Date of auction': '', 'Kavel': 'no. 131', 'Attribution': '', 'Description': '', 'Pendant': '', 'Pendant extra information': '', 'Price': '£ 1,100', 'Buyer': 'to the dealer Colnaghi for the museum', 'City of buyer': '', 'Supporter of buy': 'with support from the Vereniging Rembrandt'}}
# Identifier  RM0001.COLLECT.2316
# Owner  Irwin Laughlin et al. [section 'The property of a gentleman' [section 'The property of a gentleman', probably David Weill]
# Buyer  Colnaghi
# Price  £ 1,100
# Date sale
# Auction house
#
# {'Old format': ' sale, Christiaan Kramm (1797-1875, Utrecht), Amsterdam (G. Theod. Bom en Zoon), 30 November 1937, no. 131, as D. Marot', 'Format': 'sale, Christiaan Kramm (1797-1875, Utrecht), Amsterdam (G. Theod. Bom en Zoon), 30 November 1937, no. 131, as D. Marot', 'Readable sentence': 'Sold by Christiaan Kramm (1797-1875, item previously kept in Utrecht), auctioned off in Amsterdam (auction house G. Theod. Bom en Zoon) on 30 November 1937, no. 131, as D. Marot.', 'Parsed objects': {'Source': '', 'Section of the sale': '', 'Owner name': 'Christiaan Kramm', 'Owner Birth and Death Date': '1797-1875', 'Place collection was stored': 'Utrecht', 'Place of auction': 'Amsterdam', 'Auction house': 'G. Theod. Bom en Zoon', 'Date of auction': '30 November 1937', 'Kavel': 'no. 131', 'Attribution': 'as D. Marot', 'Description': '', 'Pendant': '', 'Pendant extra information': '', 'Price': '', 'Buyer': '', 'City of buyer': '', 'Supporter of buy': ''}}
# Identifier  RM0001.COLLECT.2805
# Owner  Christiaan Kramm
# Buyer
# Price
# Date sale  30 November 1937
# Auction house  G. Theod. Bom en Zoon
#
# {'Old format': ' sale, Christiaan Kramm (1797-1875, Utrecht), Amsterdam (G. Theod. Bom en Zoon), 30 November 1937, no. 131, as D. Marot', 'Format': 'sale, Christiaan Kramm (1797-1875, Utrecht), Amsterdam (G. Theod. Bom en Zoon), 30 November 1937, no. 131, as D. Marot', 'Readable sentence': 'Sold by Christiaan Kramm (1797-1875, item previously kept in Utrecht), auctioned off in Amsterdam (auction house G. Theod. Bom en Zoon) on 30 November 1937, no. 131, as D. Marot.', 'Parsed objects': {'Source': '', 'Section of the sale': '', 'Owner name': 'Christiaan Kramm', 'Owner Birth and Death Date': '1797-1875', 'Place collection was stored': 'Utrecht', 'Place of auction': 'Amsterdam', 'Auction house': 'G. Theod. Bom en Zoon', 'Date of auction': '30 November 1937', 'Kavel': 'no. 131', 'Attribution': 'as D. Marot', 'Description': '', 'Pendant': '', 'Pendant extra information': '', 'Price': '', 'Buyer': '', 'City of buyer': '', 'Supporter of buy': ''}}
# Identifier  RM0001.COLLECT.2807
# Owner  Christiaan Kramm
# Buyer
# Price
# Date sale  30 November 1937
# Auction house  G. Theod. Bom en Zoon
#
# {'Old format': ' sale, Sächsischen Staatssammlungen Johanneum, Grünes Gewölbe, Gemäldegalerie in Dresden, Dresden (Rudolph Lepke), 12 (13) October 1920 sqq., no. 780, DM 250,000, to the dealer Heilbronner, Berlin', 'Format': 'sale, Sächsischen Staatssammlungen Johanneum, Grünes Gewölbe, Gemäldegalerie in Dresden, no. 780, DM 250,000, to the dealer Heilbronner, Berlin', 'Readable sentence': 'Sold by Sächsischen Staatssammlungen Johanneum, auctioned off in Grünes Gewölbe on Gemäldegalerie in Dresden, no. 780, bought for DM 250,000, sold to the dealer Heilbronner, Berlin.', 'Parsed objects': {'Source': '', 'Section of the sale': '', 'Owner name': 'Sächsischen Staatssammlungen Johanneum', 'Owner Birth and Death Date': '', 'Place collection was stored': '', 'Place of auction': 'Grünes Gewölbe', 'Auction house': '', 'Date of auction': 'Gemäldegalerie in Dresden', 'Kavel': 'no. 780', 'Attribution': '', 'Description': '', 'Pendant': '', 'Pendant extra information': '', 'Price': 'DM 250,000', 'Buyer': 'to the dealer Heilbronner', 'City of buyer': 'Berlin', 'Supporter of buy': ''}}
# Identifier  RM0001.COLLECT.3177
# Owner  Sächsischen Staatssammlungen Johanneum
# Buyer  Heilbronner
# Price  DM 250,000
# Date sale
# Auction house
#
# {'Old format': ' sale, Sächsischen Staatssammlungen Johanneum, Grünes Gewölbe, Gemäldegalerie in Dresden, Dresden (Rudolph Lepke), 12 (13) October 1920 sqq., no. 778', 'Format': 'sale, Sächsischen Staatssammlungen Johanneum, Grünes Gewölbe, Gemäldegalerie in Dresden, no. 778', 'Readable sentence': 'Sold by Sächsischen Staatssammlungen Johanneum, auctioned off in Grünes Gewölbe on Gemäldegalerie in Dresden, no. 778.', 'Parsed objects': {'Source': '', 'Section of the sale': '', 'Owner name': 'Sächsischen Staatssammlungen Johanneum', 'Owner Birth and Death Date': '', 'Place collection was stored': '', 'Place of auction': 'Grünes Gewölbe', 'Auction house': '', 'Date of auction': 'Gemäldegalerie in Dresden', 'Kavel': 'no. 778', 'Attribution': '', 'Description': '', 'Pendant': '', 'Pendant extra information': '', 'Price': '', 'Buyer': '', 'City of buyer': '', 'Supporter of buy': ''}}
# Identifier  RM0001.COLLECT.3864
# Owner  Sächsischen Staatssammlungen Johanneum
# Buyer
# Price
# Date sale
# Auction house
#
# {'Old format': ' sale, Sächsischen Staatssammlungen Johanneum, Grünes Gewölbe, Gemäldegalerie in Dresden, Dresden (Rudolph Lepke), 12 (13) October 1920 sqq., no. 779', 'Format': 'sale, Sächsischen Staatssammlungen Johanneum, Grünes Gewölbe, Gemäldegalerie in Dresden, no. 779', 'Readable sentence': 'Sold by Sächsischen Staatssammlungen Johanneum, auctioned off in Grünes Gewölbe on Gemäldegalerie in Dresden, no. 779.', 'Parsed objects': {'Source': '', 'Section of the sale': '', 'Owner name': 'Sächsischen Staatssammlungen Johanneum', 'Owner Birth and Death Date': '', 'Place collection was stored': '', 'Place of auction': 'Grünes Gewölbe', 'Auction house': '', 'Date of auction': 'Gemäldegalerie in Dresden', 'Kavel': 'no. 779', 'Attribution': '', 'Description': '', 'Pendant': '', 'Pendant extra information': '', 'Price': '', 'Buyer': '', 'City of buyer': '', 'Supporter of buy': ''}}
# Identifier  RM0001.COLLECT.3865
# Owner  Sächsischen Staatssammlungen Johanneum
# Buyer
# Price
# Date sale
# Auction house
#
# {'Old format': ' his sale, 12-15 June 1899, Paris, Drouot (expert E. Gandouin père ', 'Format': 'his sale, 12-15 June 1899, Paris', 'Readable sentence': 'Sold by him, auctioned off in 12-15 June 1899 on Paris.', 'Parsed objects': {'Source': '', 'Section of the sale': '', 'Owner name': '', 'Owner Birth and Death Date': '', 'Place collection was stored': '', 'Place of auction': '12-15 June 1899', 'Auction house': '', 'Date of auction': 'Paris', 'Kavel': '', 'Attribution': '', 'Description': '', 'Pendant': '', 'Pendant extra information': '', 'Price': '', 'Buyer': '', 'City of buyer': '', 'Supporter of buy': ''}}
# Identifier  RM0001.COLLECT.4468
# Owner
# Buyer
# Price
# Date sale
# Auction house
#
# {'Old format': '{Ekkart et al. 2000, NK 1792, p.87} anonymous sale [section J.J. Thole], Amsterdam (Mak van Waay), 22 (23) December 1942 sqq., no. 22, as Portrait of a family', 'Format': '{Ekkart et al. 2000, NK 1792, p.87} anonymous sale [section J.J. Thole], Amsterdam (Mak van Waay), 22 (23) December 1942 sqq., no. 22, as Portrait of a family', 'Readable sentence': 'Sold by anonymous [section J.J. Thole], auctioned off in Amsterdam (auction house Mak van Waay) on 22 (23) December 1942 sqq., no. 22, as Portrait of a family.', 'Parsed objects': {'Source': '{Ekkart et al. 2000, NK 1792, p.87}', 'Section of the sale': 'section J.J. Thole', 'Owner name': '', 'Owner Birth and Death Date': '', 'Place collection was stored': '', 'Place of auction': 'Amsterdam', 'Auction house': 'Mak van Waay', 'Date of auction': '22 (23) December 1942 sqq.', 'Kavel': 'no. 22', 'Attribution': 'as Portrait of a family', 'Description': '', 'Pendant': '', 'Pendant extra information': '', 'Price': '', 'Buyer': '', 'City of buyer': '', 'Supporter of buy': ''}}
# Identifier  RM0001.COLLECT.4553
# Owner
# Buyer
# Price
# Date sale  22 (23) December 1942 sqq.
# Auction house  Mak van Waay
#
# {'Old format': ' sale, Cologne (Kunsthaus Lempertz), 21 (22) November 1985 sqq., no. 1784, as Französischer oder Russischer Meister des 18. Jh, with pendant, no. 1783, SK-A-4836, DM 5,600, to the Rijksmuseum-Stichting, for the museum', 'Format': 'sale, Cologne, 21, 22 November 1985 sqq., no. 1784, as Französischer oder Russischer Meister des 18. Jh, with pendant,  no. 1783, SK-A-4836, DM 5,600, to the Rijksmuseum-Stichting, for the museum', 'Readable sentence': 'Sold by Cologne, auctioned off in 21 on 22 November 1985 sqq., no. 1784, as Französischer oder Russischer Meister des 18. Jh, with pendant,  no. 1783, SK-A-4836, bought for DM 5,600, sold to the Rijksmuseum-Stichting, for the museum.', 'Parsed objects': {'Source': '', 'Section of the sale': '', 'Owner name': 'Cologne', 'Owner Birth and Death Date': '', 'Place collection was stored': '', 'Place of auction': '21', 'Auction house': '', 'Date of auction': '22 November 1985 sqq.', 'Kavel': 'no. 1784', 'Attribution': 'as Französischer oder Russischer Meister des 18. Jh', 'Description': '', 'Pendant': 'with pendant', 'Pendant extra information': ' no. 1783, SK-A-4836', 'Price': 'DM 5,600', 'Buyer': 'to the Rijksmuseum-Stichting', 'City of buyer': 'for the museum', 'Supporter of buy': ''}}
# Identifier  RM0001.COLLECT.4565
# Owner  Cologne
# Buyer  the Rijksmuseum-Stichting
# Price  DM 5,600
# Date sale  22 November 1985 sqq.
# Auction house
#
# {'Old format': ' sale, Cologne (Kunsthaus Lempertz), 21 (22) November 1985 sqq., no. 1784, as Französischer oder Russischer Meister des 18. Jh, with pendant, no. 1783, SK-A-4836, DM 5,600, to the Rijksmuseum-Stichting, for the museum', 'Format': 'sale, Cologne, 21, 22 November 1985 sqq., no. 1784, as Französischer oder Russischer Meister des 18. Jh, with pendant,  no. 1783, SK-A-4836, DM 5,600, to the Rijksmuseum-Stichting, for the museum', 'Readable sentence': 'Sold by Cologne, auctioned off in 21 on 22 November 1985 sqq., no. 1784, as Französischer oder Russischer Meister des 18. Jh, with pendant,  no. 1783, SK-A-4836, bought for DM 5,600, sold to the Rijksmuseum-Stichting, for the museum.', 'Parsed objects': {'Source': '', 'Section of the sale': '', 'Owner name': 'Cologne', 'Owner Birth and Death Date': '', 'Place collection was stored': '', 'Place of auction': '21', 'Auction house': '', 'Date of auction': '22 November 1985 sqq.', 'Kavel': 'no. 1784', 'Attribution': 'as Französischer oder Russischer Meister des 18. Jh', 'Description': '', 'Pendant': 'with pendant', 'Pendant extra information': ' no. 1783, SK-A-4836', 'Price': 'DM 5,600', 'Buyer': 'to the Rijksmuseum-Stichting', 'City of buyer': 'for the museum', 'Supporter of buy': ''}}
# Identifier  RM0001.COLLECT.4566
# Owner  Cologne
# Buyer  the Rijksmuseum-Stichting
# Price  DM 5,600
# Date sale  22 November 1985 sqq.
# Auction house
#
# {'Old format': ' sale, Mss S.D.V. M. et al., Dordrecht (A. Mak), 14 (15) May 1929 sqq., no. 557, fl. 60, to Adolph Staring van de Wildenborch (1890-1980), Deventer', 'Format': 'sale, Mss S.D.V. M. et al., Dordrecht (A. Mak), 14 (15) May 1929 sqq., no. 557,  fl. 60, to Adolph Staring van de Wildenborch (1890-1980), Deventer', 'Readable sentence': 'Sold by Mss S.D.V. M. et al., auctioned off in Dordrecht (auction house A. Mak) on 14 (15) May 1929 sqq., no. 557, bought for  fl. 60, sold to Adolph Staring van de Wildenborch (1890-1980), Deventer.', 'Parsed objects': {'Source': '', 'Section of the sale': '', 'Owner name': 'Mss S.D.V. M. et al.', 'Owner Birth and Death Date': '', 'Place collection was stored': '', 'Place of auction': 'Dordrecht', 'Auction house': 'A. Mak', 'Date of auction': '14 (15) May 1929 sqq.', 'Kavel': 'no. 557', 'Attribution': '', 'Description': '', 'Pendant': '', 'Pendant extra information': '', 'Price': ' fl. 60', 'Buyer': 'to Adolph Staring van de Wildenborch (1890-1980)', 'City of buyer': 'Deventer', 'Supporter of buy': ''}}
# Identifier  RM0001.COLLECT.4581
# Owner  Mss S.D.V. M. et al.
# Buyer  Adolph Staring van de Wildenborch (1890-1980)
# Price   fl. 60
# Date sale  14 (15) May 1929 sqq.
# Auction house  A. Mak
#
# {'Old format': " sale, 'une famille noble de la province d’Utrecht' [Jonkheer C.H.C.A. van Sypesteyn (1857-1937) Loosdrecht], Amsterdam (R.W.P. de Vries), 16 June 1924, no. 23, fl. 38, to Adolph Staring van de Wildenborch (1890-1980), Deventer", 'Format': "sale, 'une famille noble de la province d’Utrecht' [Jonkheer C.H.C.A. van Sypesteyn (1857-1937 Loosdrecht], Amsterdam (R.W.P. de Vries), 16 June 1924, no. 23,  fl. 38, to Adolph Staring van de Wildenborch (1890-1980), Deventer", 'Readable sentence': "Sold by 'une famille noble de la province d’Utrecht' [Jonkheer C.H.C.A. van Sypesteyn (1857-1937 Loosdrecht], item previously kept in Amsterdam (R.W.P. de Vries), auctioned off in 16 June 1924, no. 23, bought for  fl. 38, sold to Adolph Staring van de Wildenborch (1890-1980), Deventer.", 'Parsed objects': {'Source': '', 'Section of the sale': '', 'Owner name': "'une famille noble de la province d’Utrecht' [Jonkheer C.H.C.A. van Sypesteyn", 'Owner Birth and Death Date': '1857-1937 Loosdrecht]', 'Place collection was stored': 'Amsterdam (R.W.P. de Vries', 'Place of auction': '16 June 1924', 'Auction house': '', 'Date of auction': '', 'Kavel': 'no. 23', 'Attribution': '', 'Description': '', 'Pendant': '', 'Pendant extra information': '', 'Price': ' fl. 38', 'Buyer': 'to Adolph Staring van de Wildenborch (1890-1980)', 'City of buyer': 'Deventer', 'Supporter of buy': ''}}
# Identifier  RM0001.COLLECT.4582
# Owner  'une famille noble de la province d’Utrecht' [Jonkheer C.H.C.A. van Sypesteyn
# Buyer  Adolph Staring van de Wildenborch (1890-1980)
# Price   fl. 38
# Date sale
# Auction house
#
# {'Old format': ' sale, L.A.M. de Bruyn, Dordrecht (A. Mak), 11 May 1937 sqq., no. 43, fl. 10, to Adolph Staring van de Wildenborch (1890-1980), Deventer', 'Format': 'sale, L.A.M. de Bruyn, Dordrecht (A. Mak), 11 May 1937 sqq., no. 43,  fl. 10, to Adolph Staring van de Wildenborch (1890-1980), Deventer', 'Readable sentence': 'Sold by L.A.M. de Bruyn, auctioned off in Dordrecht (auction house A. Mak) on 11 May 1937 sqq., no. 43, bought for  fl. 10, sold to Adolph Staring van de Wildenborch (1890-1980), Deventer.', 'Parsed objects': {'Source': '', 'Section of the sale': '', 'Owner name': 'L.A.M. de Bruyn', 'Owner Birth and Death Date': '', 'Place collection was stored': '', 'Place of auction': 'Dordrecht', 'Auction house': 'A. Mak', 'Date of auction': '11 May 1937 sqq.', 'Kavel': 'no. 43', 'Attribution': '', 'Description': '', 'Pendant': '', 'Pendant extra information': '', 'Price': ' fl. 10', 'Buyer': 'to Adolph Staring van de Wildenborch (1890-1980)', 'City of buyer': 'Deventer', 'Supporter of buy': ''}}
# Identifier  RM0001.COLLECT.4586
# Owner  L.A.M. de Bruyn
# Buyer  Adolph Staring van de Wildenborch (1890-1980)
# Price   fl. 10
# Date sale  11 May 1937 sqq.
# Auction house  A. Mak
#
# {'Old format': ' sale, Nathan Katz, Dieren, 14 May 1963 sqq. no. 204, fl. 130, to Adolph Staring van de Wildenborch (1890-1980), Deventer', 'Format': 'sale, Nathan Katz, Dieren, 14 May 1963 sqq. no. 204,  fl. 130, to Adolph Staring van de Wildenborch (1890-1980), Deventer', 'Readable sentence': 'Sold by Nathan Katz, auctioned off in Dieren, 14 May 1963 sqq. no. 204, bought for  fl. 130, sold to Adolph Staring van de Wildenborch (1890-1980), Deventer.', 'Parsed objects': {'Source': '', 'Section of the sale': '', 'Owner name': 'Nathan Katz', 'Owner Birth and Death Date': '', 'Place collection was stored': '', 'Place of auction': 'Dieren', 'Auction house': '', 'Date of auction': '', 'Kavel': '14 May 1963 sqq. no. 204', 'Attribution': '', 'Description': '', 'Pendant': '', 'Pendant extra information': '', 'Price': ' fl. 130', 'Buyer': 'to Adolph Staring van de Wildenborch (1890-1980)', 'City of buyer': 'Deventer', 'Supporter of buy': ''}}
# Identifier  RM0001.COLLECT.4595
# Owner  Nathan Katz
# Buyer  Adolph Staring van de Wildenborch (1890-1980)
# Price   fl. 130
# Date sale
# Auction house
#
# {'Old format': ' sale, Dordrecht (Mak van Waay), April 1917, fl. 88, to Adolph Staring van de Wildenborch (1890-1980), Deventer', 'Format': 'sale, Dordrecht, April 1917, fl. 88,  fl. 88, to Adolph Staring van de Wildenborch (1890-1980), Deventer', 'Readable sentence': 'Sold by Dordrecht, auctioned off in April 1917 on fl. 88, bought for  fl. 88, sold to Adolph Staring van de Wildenborch (1890-1980), Deventer.', 'Parsed objects': {'Source': '', 'Section of the sale': '', 'Owner name': 'Dordrecht', 'Owner Birth and Death Date': '', 'Place collection was stored': '', 'Place of auction': 'April 1917', 'Auction house': '', 'Date of auction': 'fl. 88', 'Kavel': '', 'Attribution': '', 'Description': '', 'Pendant': '', 'Pendant extra information': '', 'Price': ' fl. 88', 'Buyer': 'to Adolph Staring van de Wildenborch (1890-1980)', 'City of buyer': 'Deventer', 'Supporter of buy': ''}}
# Identifier  RM0001.COLLECT.4596
# Owner  Dordrecht
# Buyer  Adolph Staring van de Wildenborch (1890-1980)
# Price   fl. 88
# Date sale
# Auction house
#
# {'Old format': ' sale, L.A.M. de Bruyn, Dordrecht (A. Mak), 11 May 1937 sqq., no. 40, fl. 16, to Adolph Staring van de Wildenborch (1890-1980), Deventer', 'Format': 'sale, L.A.M. de Bruyn, Dordrecht (A. Mak), 11 May 1937 sqq., no. 40,  fl. 16, to Adolph Staring van de Wildenborch (1890-1980), Deventer', 'Readable sentence': 'Sold by L.A.M. de Bruyn, auctioned off in Dordrecht (auction house A. Mak) on 11 May 1937 sqq., no. 40, bought for  fl. 16, sold to Adolph Staring van de Wildenborch (1890-1980), Deventer.', 'Parsed objects': {'Source': '', 'Section of the sale': '', 'Owner name': 'L.A.M. de Bruyn', 'Owner Birth and Death Date': '', 'Place collection was stored': '', 'Place of auction': 'Dordrecht', 'Auction house': 'A. Mak', 'Date of auction': '11 May 1937 sqq.', 'Kavel': 'no. 40', 'Attribution': '', 'Description': '', 'Pendant': '', 'Pendant extra information': '', 'Price': ' fl. 16', 'Buyer': 'to Adolph Staring van de Wildenborch (1890-1980)', 'City of buyer': 'Deventer', 'Supporter of buy': ''}}
# Identifier  RM0001.COLLECT.4597
# Owner  L.A.M. de Bruyn
# Buyer  Adolph Staring van de Wildenborch (1890-1980)
# Price   fl. 16
# Date sale  11 May 1937 sqq.
# Auction house  A. Mak
#
# {'Old format': ' sale, collection Fraeylemaborg, Slochteren et al., Amsterdam (Mak van Waay), 25 May (2 June) 1971 sqq., no. 1841, as Hollandse School (XVIIIde eeuw), fl.140, with SK-A-4847 and one other object', 'Format': 'sale, collection Fraeylemaborg,  Slochteren et al., Amsterdam (Mak van Waay), 25 May (2 June) 1971 sqq., no. 1841, as Hollandse School (XVIIIde eeuw)', 'Readable sentence': 'Sold by collection Fraeylemaborg,  Slochteren et al., auctioned off in Amsterdam (auction house Mak van Waay) on 25 May (2 June) 1971 sqq., no. 1841, as Hollandse School (XVIIIde eeuw).', 'Parsed objects': {'Source': '', 'Section of the sale': '', 'Owner name': 'collection Fraeylemaborg,  Slochteren et al.', 'Owner Birth and Death Date': '', 'Place collection was stored': '', 'Place of auction': 'Amsterdam', 'Auction house': 'Mak van Waay', 'Date of auction': '25 May (2 June) 1971 sqq.', 'Kavel': 'no. 1841', 'Attribution': 'as Hollandse School (XVIIIde eeuw)', 'Description': '', 'Pendant': '', 'Pendant extra information': '', 'Price': '', 'Buyer': '', 'City of buyer': '', 'Supporter of buy': ''}}
# Identifier  RM0001.COLLECT.4599
# Owner  collection Fraeylemaborg,  Slochteren et al.
# Buyer
# Price
# Date sale  25 May (2 June) 1971 sqq.
# Auction house  Mak van Waay
#
# {'Old format': ' sale, collection Fraeylemaborg, Slochteren et al., Amsterdam (Mak van Waay), 25 May (2 June) 1971 sqq., no. 1841, as Hollandse School (XVIIIde eeuw), fl.140, with SK-A-4847 and one other object', 'Format': 'sale, collection Fraeylemaborg,  Slochteren et al., Amsterdam (Mak van Waay), 25 May (2 June) 1971 sqq., no. 1841, as Hollandse School (XVIIIde eeuw)', 'Readable sentence': 'Sold by collection Fraeylemaborg,  Slochteren et al., auctioned off in Amsterdam (auction house Mak van Waay) on 25 May (2 June) 1971 sqq., no. 1841, as Hollandse School (XVIIIde eeuw).', 'Parsed objects': {'Source': '', 'Section of the sale': '', 'Owner name': 'collection Fraeylemaborg,  Slochteren et al.', 'Owner Birth and Death Date': '', 'Place collection was stored': '', 'Place of auction': 'Amsterdam', 'Auction house': 'Mak van Waay', 'Date of auction': '25 May (2 June) 1971 sqq.', 'Kavel': 'no. 1841', 'Attribution': 'as Hollandse School (XVIIIde eeuw)', 'Description': '', 'Pendant': '', 'Pendant extra information': '', 'Price': '', 'Buyer': '', 'City of buyer': '', 'Supporter of buy': ''}}
# Identifier  RM0001.COLLECT.4600
# Owner  collection Fraeylemaborg,  Slochteren et al.
# Buyer
# Price
# Date sale  25 May (2 June) 1971 sqq.
# Auction house  Mak van Waay
#
# {'Old format': ' sale, Lady Strachie et al. [section ‘The property of a gentleman’], London (Sotheby’s), 27 June 1922, no. 118, £ 10, to the dealer Mellaart', 'Format': 'sale, Lady Strachie et al. [section ‘The property of a gentleman’] [section ‘The property of a gentleman’], London (Sotheby’s), 27 June 1922, no. 118,  £ 10, to the dealer Mellaart', 'Readable sentence': 'Sold by Lady Strachie et al. [section ‘The property of a gentleman’] [section ‘The property of a gentleman’], auctioned off in London (auction house Sotheby’s) on 27 June 1922, no. 118, bought for  £ 10, sold to the dealer Mellaart.', 'Parsed objects': {'Source': '', 'Section of the sale': '', 'Owner name': 'Lady Strachie et al. [section ‘The property of a gentleman’] [section ‘The property of a gentleman’]', 'Owner Birth and Death Date': '', 'Place collection was stored': '', 'Place of auction': 'London', 'Auction house': 'Sotheby’s', 'Date of auction': '27 June 1922', 'Kavel': 'no. 118', 'Attribution': '', 'Description': '', 'Pendant': '', 'Pendant extra information': '', 'Price': ' £ 10', 'Buyer': 'to the dealer Mellaart', 'City of buyer': '', 'Supporter of buy': ''}}
# Identifier  RM0001.COLLECT.4602
# Owner  Lady Strachie et al. [section ‘The property of a gentleman’] [section ‘The property of a gentleman’]
# Buyer  Mellaart
# Price   £ 10
# Date sale  27 June 1922
# Auction house  Sotheby’s
#
# {'Old format': ' sale, Richard von Kaufmann (1849-1908, Berlin), Berlin (Cassirer & Helbing), 4 December 1917 sqq., no. 4, DM 8,000, to Prof. Dr Otto Lanz (1865-1935), Amsterdam', 'Format': 'sale, Richard von Kaufmann (1849-1908, Berlin), Berlin (Cassirer & Helbing), 4 December 1917 sqq., no. 4, DM 8,000, to Prof. Dr Otto Lanz (1865-1935), Amsterdam', 'Readable sentence': 'Sold by Richard von Kaufmann (1849-1908, item previously kept in Berlin), auctioned off in Berlin (auction house Cassirer & Helbing) on 4 December 1917 sqq., no. 4, bought for DM 8,000, sold to Prof. Dr Otto Lanz (1865-1935), Amsterdam.', 'Parsed objects': {'Source': '', 'Section of the sale': '', 'Owner name': 'Richard von Kaufmann', 'Owner Birth and Death Date': '1849-1908', 'Place collection was stored': 'Berlin', 'Place of auction': 'Berlin', 'Auction house': 'Cassirer & Helbing', 'Date of auction': '4 December 1917 sqq.', 'Kavel': 'no. 4', 'Attribution': '', 'Description': '', 'Pendant': '', 'Pendant extra information': '', 'Price': 'DM 8,000', 'Buyer': 'to Prof. Dr Otto Lanz (1865-1935)', 'City of buyer': 'Amsterdam', 'Supporter of buy': ''}}
# Identifier  RM0001.COLLECT.4623
# Owner  Richard von Kaufmann
# Buyer  Prof. Dr OtLanz (1865-1935)
# Price  DM 8,000
# Date sale  4 December 1917 sqq.
# Auction house  Cassirer & Helbing
#
# {'Old format': " sale, Mortimer Loeb Schiff (1877-1931, New York), London (Christie's), 24 June 1938, no. 76, to the dealer Rosenberg", 'Format': "sale, Mortimer Loeb Schiff (1877-1931, New York), London (Christie's), 24 June 1938, no. 76, to the dealer Rosenberg", 'Readable sentence': "Sold by Mortimer Loeb Schiff (1877-1931, item previously kept in New York), auctioned off in London (auction house Christie's) on 24 June 1938, no. 76, sold to the dealer Rosenberg.", 'Parsed objects': {'Source': '', 'Section of the sale': '', 'Owner name': 'Mortimer Loeb Schiff', 'Owner Birth and Death Date': '1877-1931', 'Place collection was stored': 'New York', 'Place of auction': 'London', 'Auction house': "Christie's", 'Date of auction': '24 June 1938', 'Kavel': 'no. 76', 'Attribution': '', 'Description': '', 'Pendant': '', 'Pendant extra information': '', 'Price': '', 'Buyer': 'to the dealer Rosenberg', 'City of buyer': '', 'Supporter of buy': ''}}
# Identifier  RM0001.COLLECT.4656
# Owner  Mortimer Loeb Schiff
# Buyer  Rosenberg
# Price
# Date sale  24 June 1938
# Auction house  Christie's
#
# {'Old format': ' his sale, Amsterdam (C.F. Roos), 19 August 1879, no. 1, as 15th-century Flemish school, fl. 2,200, to J.W. Kaiser, for the museum', 'Format': 'his sale, Amsterdam (C.F. Roos), 19 August 1879, no. 1, as 15th-century Flemish school, fl. 2,200, to J.W. Kaiser, for the museum', 'Readable sentence': 'Sold by him, auctioned off in Amsterdam (auction house C.F. Roos) on 19 August 1879, no. 1, as 15th-century Flemish school, bought for fl. 2,200, sold to J.W. Kaiser, for the museum.', 'Parsed objects': {'Source': '', 'Section of the sale': '', 'Owner name': '', 'Owner Birth and Death Date': '', 'Place collection was stored': '', 'Place of auction': 'Amsterdam', 'Auction house': 'C.F. Roos', 'Date of auction': '19 August 1879', 'Kavel': 'no. 1', 'Attribution': 'as 15th-century Flemish school', 'Description': '', 'Pendant': '', 'Pendant extra information': '', 'Price': 'fl. 2,200', 'Buyer': 'to J.W. Kaiser', 'City of buyer': 'for the museum', 'Supporter of buy': ''}}
# Identifier  RM0001.COLLECT.4657
# Owner
# Buyer  J.W. Kaiser
# Price  fl. 2,200
# Date sale  19 August 1879
# Auction house  C.F. Roos
#
# {'Old format': ' sale, Chevalier F. Meazza (Milan), sold on the premises (Riblet), 15 (21) April 1884 sqq., no. 200, as Quinten Massijs', 'Format': 'sale, Chevalier F. Meazza, sold on the premises (Riblet), 15 (21) April 1884 sqq., no. 200, as Quinten Massijs', 'Readable sentence': 'Sold by Chevalier F. Meazza, auctioned off in sold on the premises (auction house Riblet) on 15 (21) April 1884 sqq., no. 200, as Quinten Massijs.', 'Parsed objects': {'Source': '', 'Section of the sale': '', 'Owner name': 'Chevalier F. Meazza', 'Owner Birth and Death Date': '', 'Place collection was stored': '', 'Place of auction': 'sold on the premises', 'Auction house': 'Riblet', 'Date of auction': '15 (21) April 1884 sqq.', 'Kavel': 'no. 200', 'Attribution': 'as Quinten Massijs', 'Description': '', 'Pendant': '', 'Pendant extra information': '', 'Price': '', 'Buyer': '', 'City of buyer': '', 'Supporter of buy': ''}}
# Identifier  RM0001.COLLECT.4659
# Owner  Chevalier F. Meazza
# Buyer
# Price
# Date sale  15 (21) April 1884 sqq.
# Auction house  Riblet
#
# {'Old format': '{Note RMA.} sale, Viscount Bearsted et al. [section Sir Humphrey de Trafford], London (Christie’s), 13 December 1929, no. 134, £ 315, to Partridge', 'Format': '{Note RMA.} sale, Viscount Bearsted et al. [section Sir Humphrey de Trafford] [section Sir Humphrey de Trafford], London (Christie’s), 13 December 1929, no. 134,  £ 315, to Partridge', 'Readable sentence': 'Sold by Viscount Bearsted et al. [section Sir Humphrey de Trafford] [section Sir Humphrey de Trafford], auctioned off in London (auction house Christie’s) on 13 December 1929, no. 134, bought for  £ 315, sold to Partridge.', 'Parsed objects': {'Source': '{Note RMA.}', 'Section of the sale': '', 'Owner name': 'Viscount Bearsted et al. [section Sir Humphrey de Trafford] [section Sir Humphrey de Trafford]', 'Owner Birth and Death Date': '', 'Place collection was stored': '', 'Place of auction': 'London', 'Auction house': 'Christie’s', 'Date of auction': '13 December 1929', 'Kavel': 'no. 134', 'Attribution': '', 'Description': '', 'Pendant': '', 'Pendant extra information': '', 'Price': ' £ 315', 'Buyer': 'to Partridge', 'City of buyer': '', 'Supporter of buy': ''}}
# Identifier  RM0001.COLLECT.4673
# Owner  Viscount Bearsted et al. [section Sir Humphrey de Trafford] [section Sir Humphrey de Trafford]
# Buyer  Partridge
# Price   £ 315
# Date sale  13 December 1929
# Auction house  Christie’s
#
# {'Old format': " sale, estate of Mary Armour-Dunn et al. [section 'Various Properties'], New York (Christie’s), 11 January 1989, no. 68, as Circle of Lucas van Valkenborch, $ 71,500", 'Format': "sale, estate of Mary Armour-Dunn et al. [section 'Various Properties'] [section 'Various Properties'], New York (Christie’s), 11 January 1989, no. 68, as Circle of Lucas van Valkenborch,  $ 71", 'Readable sentence': "Sold by estate of Mary Armour-Dunn et al. [section 'Various Properties'] [section 'Various Properties'], auctioned off in New York (auction house Christie’s) on 11 January 1989, no. 68, as Circle of Lucas van Valkenborch, bought for  $ 71.", 'Parsed objects': {'Source': '', 'Section of the sale': '', 'Owner name': "estate of Mary Armour-Dunn et al. [section 'Various Properties'] [section 'Various Properties']", 'Owner Birth and Death Date': '', 'Place collection was stored': '', 'Place of auction': 'New York', 'Auction house': 'Christie’s', 'Date of auction': '11 January 1989', 'Kavel': 'no. 68', 'Attribution': 'as Circle of Lucas van Valkenborch', 'Description': '', 'Pendant': '', 'Pendant extra information': '', 'Price': ' $ 71', 'Buyer': '', 'City of buyer': '', 'Supporter of buy': ''}}
# Identifier  RM0001.COLLECT.4687
# Owner  estate of Mary Armour-Dunn et al. [section 'Various Properties'] [section 'Various Properties']
# Buyer
# Price   $ 71
# Date sale  11 January 1989
# Auction house  Christie’s
#
# {'Old format': "{File RMA.} sale, the estate of Therese Lownes Noble et al.[Section 'Property of various owners'], New York (Sotheby’s), 12 June 1975, no. 184, as Jan van Bylert, $27,000, to the museum, as a gift from the Stichting tot Bevordering van de Belangen van het Rijksmuseum", 'Format': "{File RMA.} sale, the estate of Therese Lownes Noble et al.[Section 'Property of various owners'], New York (Sotheby’s), 12 June 1975, no. 184, as a gift from the Stichting tot Bevordering van de Belangen van het Rijksmuseum, $27,000, to the museum, as a gift from the Stichting tot Bevordering van de Belangen van het Rijksmuseum", 'Readable sentence': "Sold by the estate of Therese Lownes Noble et al.[Section 'Property of various owners'], auctioned off in New York (auction house Sotheby’s) on 12 June 1975, no. 184, as a gift from the Stichting tot Bevordering van de Belangen van het Rijksmuseum, bought for $27,000, sold to the museum, as a gift from the Stichting tot Bevordering van de Belangen van het Rijksmuseum.", 'Parsed objects': {'Source': '{File RMA.}', 'Section of the sale': '', 'Owner name': "the estate of Therese Lownes Noble et al.[Section 'Property of various owners']", 'Owner Birth and Death Date': '', 'Place collection was stored': '', 'Place of auction': 'New York', 'Auction house': 'Sotheby’s', 'Date of auction': '12 June 1975', 'Kavel': 'no. 184', 'Attribution': 'as a gift from the Stichting tot Bevordering van de Belangen van het Rijksmuseum', 'Description': '', 'Pendant': '', 'Pendant extra information': '', 'Price': '$27,000', 'Buyer': 'to the museum', 'City of buyer': 'as a gift from the Stichting tot Bevordering van de Belangen van het Rijksmuseum', 'Supporter of buy': ''}}
# Identifier  RM0001.COLLECT.4696
# Owner  the estate of Therese Lownes Noble et al.[Section 'Property of various owners']
# Buyer  the museum
# Price  $27,000
# Date sale  12 June 1975
# Auction house  Sotheby’s
#
# {'Old format': ' ? sale, W. Lockett Agnew, Esq. et al. [anonymous section], London (Christie’s), 15 June 1923, no. 101, £110.5, to S. J. Smith', 'Format': '? sale, W. Lockett Agnew,  Esq. et al. [anonymous section], London (Christie’s), 15 June 1923, no. 101,  £110.5, to S. J. Smith', 'Readable sentence': 'Possibly sold by W. Lockett Agnew,  Esq. et al. [anonymous section], auctioned off in London (auction house Christie’s) on 15 June 1923, no. 101, bought for  £110.5, sold to S. J. Smith.', 'Parsed objects': {'Source': '', 'Section of the sale': '', 'Owner name': 'W. Lockett Agnew,  Esq. et al. [anonymous section]', 'Owner Birth and Death Date': '', 'Place collection was stored': '', 'Place of auction': 'London', 'Auction house': 'Christie’s', 'Date of auction': '15 June 1923', 'Kavel': 'no. 101', 'Attribution': '', 'Description': '', 'Pendant': '', 'Pendant extra information': '', 'Price': ' £110.5', 'Buyer': 'to S. J. Smith', 'City of buyer': '', 'Supporter of buy': ''}}
# Identifier  RM0001.COLLECT.4703
# Owner  W. Lockett Agnew,  Esq. et al. [anonymous section]
# Buyer  S. J. Smith
# Price   £110.5
# Date sale  15 June 1923
# Auction house  Christie’s
#
# {'Old format': '{Amsterdam 1900, p. 20, no. 89.} his sale, Amsterdam (F. Muller), 16 October 1928, no. 30, fl. 44,000, to Beels (or Beets) for Sir Henri W.A. Deterding (1866-1939), London', 'Format': '{Amsterdam 1900, p. 20, no. 89.} his sale, Amsterdam (F. Muller), 16 October 1928, no. 30, fl. 44,000, to Beels (or Beets) for Sir Henri W.A. Deterding (1866-1939), London', 'Readable sentence': 'Sold by him, auctioned off in Amsterdam (auction house F. Muller) on 16 October 1928, no. 30, bought for fl. 44,000, sold to Beels (or Beets) for Sir Henri W.A. Deterding (1866-1939), London.', 'Parsed objects': {'Source': '{Amsterdam 1900, p. 20, no. 89.}', 'Section of the sale': '', 'Owner name': '', 'Owner Birth and Death Date': '', 'Place collection was stored': '', 'Place of auction': 'Amsterdam', 'Auction house': 'F. Muller', 'Date of auction': '16 October 1928', 'Kavel': 'no. 30', 'Attribution': '', 'Description': '', 'Pendant': '', 'Pendant extra information': '', 'Price': 'fl. 44,000', 'Buyer': 'to Beels (or Beets) for Sir Henri W.A. Deterding (1866-1939)', 'City of buyer': 'London', 'Supporter of buy': ''}}
# Identifier  RM0001.COLLECT.4707
# Owner
# Buyer  Beels (or Beets) for Sir Henri W.A. Deterding (1866-1939)
# Price  fl. 44,000
# Date sale  16 October 1928
# Auction house  F. Muller
#
# {'Old format': '{According to the catalogue for the sale, Charles T.D. Crews, London (Christie’s), 1 June 1915, no. 49: ‘From the collection of Sir E.J. Dean Paul, Bart., 1896. Exhibited at the New Gallery winter exhibition 1907-08’. According to the Times, 29 June 1896, unpag., ‘A very good example of A. van der Neer (…) was sold for 1,170 guineas (M. Colnaghi)’.} sale, Charles T.D. Crews (1839-1915, Portman Square, London), London (Christie’s), 1 June 1915, no. 49,{The painting is illustrated in the catalogue.} $5,510, to P. and D. Colnaghi', 'Format': '{According to the catalogue for the sale, Charles T.D. Crews, London (Christie’s), 1 June 1915, no. 49: ‘From the collection of Sir E.J. Dean Paul, Bart., 1896. Exhibited at the New Gallery winter exhibition 1907-08’. According to the Times, 29 June 1896, unpag., ‘A very good example of A. van der Neer (…) was sold for 1,170 guineas (M. Colnaghi)’.} sale, Charles T.D. Crews (1839-1915, Portman Square), London), London (Christie’s), no. 49, {The painting is illustrated in the catalogue.} $5,510, to P. and D. Colnaghi', 'Readable sentence': 'Sold by Charles T.D. Crews (1839-1915, item previously kept in Portman Square), auctioned off in London) on London (Christie’s), no. 49, bought for {The painting is illustrated in the catalogue.} $5,510, sold to P. and D. Colnaghi.', 'Parsed objects': {'Source': '{According to the catalogue for the sale, Charles T.D. Crews, London (Christie’s), 1 June 1915, no. 49: ‘From the collection of Sir E.J. Dean Paul, Bart., 1896. Exhibited at the New Gallery winter exhibition 1907-08’. According to the Times, 29 June 1896, unpag., ‘A very good example of A. van der Neer (…) was sold for 1,170 guineas (M. Colnaghi)’.}', 'Section of the sale': '', 'Owner name': 'Charles T.D. Crews', 'Owner Birth and Death Date': '1839-1915', 'Place collection was stored': 'Portman Square', 'Place of auction': 'London)', 'Auction house': '', 'Date of auction': 'London (Christie’s)', 'Kavel': 'no. 49', 'Attribution': '', 'Description': '', 'Pendant': '', 'Pendant extra information': '', 'Price': '{The painting is illustrated in the catalogue.} $5,510', 'Buyer': 'to P. and D. Colnaghi', 'City of buyer': '', 'Supporter of buy': ''}}
# Identifier  RM0001.COLLECT.4709
# Owner  Charles T.D. Crews
# Buyer  P. and D. Colnaghi
# Price  {The painting is illustrated in the catalogue.} $5,510
# Date sale
# Auction house
#
# {'Old format': ' ? sale, Rupert Mason et al. [anonymous section], London (Christie’s), 20 July 1931, no. 137 (‘A river scene, with boats and figures', 'Format': '? sale, Rupert Mason et al. [anonymous section] [anonymous section], London (Christie’s), 20 July 1931, no. 137 (‘A river scene', 'Readable sentence': 'Possibly sold by Rupert Mason et al. [anonymous section] [anonymous section], auctioned off in London (auction house Christie’s) on 20 July 1931, no. 137 (‘A river scene.', 'Parsed objects': {'Source': '', 'Section of the sale': '', 'Owner name': 'Rupert Mason et al. [anonymous section] [anonymous section]', 'Owner Birth and Death Date': '', 'Place collection was stored': '', 'Place of auction': 'London', 'Auction house': 'Christie’s', 'Date of auction': '20 July 1931', 'Kavel': 'no. 137 (‘A river scene', 'Attribution': '', 'Description': '', 'Pendant': '', 'Pendant extra information': '', 'Price': '', 'Buyer': '', 'City of buyer': '', 'Supporter of buy': ''}}
# Identifier  RM0001.COLLECT.4710
# Owner  Rupert Mason et al. [anonymous section] [anonymous section]
# Buyer
# Price
# Date sale  20 July 1931
# Auction house  Christie’s
#
# {'Old format': ' Spencer-Churchill 1961, p. 13, no. 40.} his sale, London (Christie’s), 25 February 1966, no. 27, 2800 gns, to the dealer H. Terry-Engell, London', 'Format': '{Spencer-Churchill 1961, p. 13, no. 40.} his sale, London (Christie’s), 25 February 1966, no. 27, to the dealer H. Terry-Engell, London', 'Readable sentence': 'Sold by him, auctioned off in London (auction house Christie’s) on 25 February 1966, no. 27, sold to the dealer H. Terry-Engell, London.', 'Parsed objects': {'Source': '{Spencer-Churchill 1961, p. 13, no. 40.}', 'Section of the sale': '', 'Owner name': '', 'Owner Birth and Death Date': '', 'Place collection was stored': '', 'Place of auction': 'London', 'Auction house': 'Christie’s', 'Date of auction': '25 February 1966', 'Kavel': 'no. 27', 'Attribution': '', 'Description': '', 'Pendant': '', 'Pendant extra information': '', 'Price': '', 'Buyer': 'to the dealer H. Terry-Engell', 'City of buyer': 'London', 'Supporter of buy': ''}}
# Identifier  RM0001.COLLECT.4716
# Owner
# Buyer  H. Terry-Engell
# Price
# Date sale  25 February 1966
# Auction house  Christie’s
#
# {'Old format': ' ? anonymous sale, Amsterdam (Roos), 29 October 1912, no. 110', 'Format': '? anonymous sale, Amsterdam (Roos), 29 October 1912, no. 110', 'Readable sentence': 'Possibly sold by anonymous, auctioned off in Amsterdam (auction house Roos) on 29 October 1912, no. 110.', 'Parsed objects': {'Source': '', 'Section of the sale': '', 'Owner name': '', 'Owner Birth and Death Date': '', 'Place collection was stored': '', 'Place of auction': 'Amsterdam', 'Auction house': 'Roos', 'Date of auction': '29 October 1912', 'Kavel': 'no. 110', 'Attribution': '', 'Description': '', 'Pendant': '', 'Pendant extra information': '', 'Price': '', 'Buyer': '', 'City of buyer': '', 'Supporter of buy': ''}}
# Identifier  RM0001.COLLECT.4721
# Owner
# Buyer
# Price
# Date sale  29 October 1912
# Auction house  Roos
#
# {'Old format': ' sale, Abraham Preyer (1862-1927, Amsterdam), Amsterdam (F. Muller), 8 November 1927, no. 22, with pendant, SK-A-3977, to Frederik Muller for Teixeira de Mattos', 'Format': 'sale, Abraham Preyer (1862-1927, Amsterdam), Amsterdam (F. Muller), 8 November 1927, no. 22, with pendant, to Frederik Muller for Teixeira de Mattos', 'Readable sentence': 'Sold by Abraham Preyer (1862-1927, item previously kept in Amsterdam), auctioned off in Amsterdam (auction house F. Muller) on 8 November 1927, no. 22, with pendant, sold to Frederik Muller for Teixeira de Mattos.', 'Parsed objects': {'Source': '', 'Section of the sale': '', 'Owner name': 'Abraham Preyer', 'Owner Birth and Death Date': '1862-1927', 'Place collection was stored': 'Amsterdam', 'Place of auction': 'Amsterdam', 'Auction house': 'F. Muller', 'Date of auction': '8 November 1927', 'Kavel': 'no. 22', 'Attribution': '', 'Description': '', 'Pendant': 'with pendant', 'Pendant extra information': '', 'Price': '', 'Buyer': 'to Frederik Muller for Teixeira de Mattos', 'City of buyer': '', 'Supporter of buy': ''}}
# Identifier  RM0001.COLLECT.4732
# Owner  Abraham Preyer
# Buyer  Frederik Muller for Teixeira de Mattos
# Price
# Date sale  8 November 1927
# Auction house  F. Muller
#
# {'Old format': ' sale, Abraham Preyer (1862-1927, Amsterdam), Amsterdam (F. Muller), 8 November 1927, no. 22, with pendant, SK-A-3978, to Frederik Muller for the dealer Teixeira de Mattos', 'Format': 'sale, Abraham Preyer (1862-1927, Amsterdam), Amsterdam (F. Muller), 8 November 1927, no. 22, with pendant, to Frederik Muller for the dealer Teixeira de Mattos', 'Readable sentence': 'Sold by Abraham Preyer (1862-1927, item previously kept in Amsterdam), auctioned off in Amsterdam (auction house F. Muller) on 8 November 1927, no. 22, with pendant, sold to Frederik Muller for the dealer Teixeira de Mattos.', 'Parsed objects': {'Source': '', 'Section of the sale': '', 'Owner name': 'Abraham Preyer', 'Owner Birth and Death Date': '1862-1927', 'Place collection was stored': 'Amsterdam', 'Place of auction': 'Amsterdam', 'Auction house': 'F. Muller', 'Date of auction': '8 November 1927', 'Kavel': 'no. 22', 'Attribution': '', 'Description': '', 'Pendant': 'with pendant', 'Pendant extra information': '', 'Price': '', 'Buyer': 'to Frederik Muller for the dealer Teixeira de Mattos', 'City of buyer': '', 'Supporter of buy': ''}}
# Identifier  RM0001.COLLECT.4735
# Owner  Abraham Preyer
# Buyer  Frederik Muller for the dealer Teixeira de Mattos
# Price
# Date sale  8 November 1927
# Auction house  F. Muller
#
# {'Old format': ' sale, Richard von Kaufmann (1849-1908, Berlin), Berlin (Cassirer & Helbing), 4 December 1917 sqq., no. 15, as Italienischer Meister des  14. Jahrhunderts, DM 3,500, to Prof. Dr Otto Lanz (1865-1935), Amsterdam, 1935', 'Format': 'sale, Richard von Kaufmann (1849-1908, Berlin), Berlin (Cassirer & Helbing), 4 December 1917 sqq., no. 15, as Italienischer Meister des  14. Jahrhunderts, DM 3,500, to Prof. Dr Otto Lanz (1865-1935), Amsterdam', 'Readable sentence': 'Sold by Richard von Kaufmann (1849-1908, item previously kept in Berlin), auctioned off in Berlin (auction house Cassirer & Helbing) on 4 December 1917 sqq., no. 15, as Italienischer Meister des  14. Jahrhunderts, bought for DM 3,500, sold to Prof. Dr Otto Lanz (1865-1935), Amsterdam.', 'Parsed objects': {'Source': '', 'Section of the sale': '', 'Owner name': 'Richard von Kaufmann', 'Owner Birth and Death Date': '1849-1908', 'Place collection was stored': 'Berlin', 'Place of auction': 'Berlin', 'Auction house': 'Cassirer & Helbing', 'Date of auction': '4 December 1917 sqq.', 'Kavel': 'no. 15', 'Attribution': 'as Italienischer Meister des  14. Jahrhunderts', 'Description': '', 'Pendant': '', 'Pendant extra information': '', 'Price': 'DM 3,500', 'Buyer': 'to Prof. Dr Otto Lanz (1865-1935)', 'City of buyer': 'Amsterdam', 'Supporter of buy': ''}}
# Identifier  RM0001.COLLECT.4750
# Owner  Richard von Kaufmann
# Buyer  Prof. Dr OtLanz (1865-1935)
# Price  DM 3,500
# Date sale  4 December 1917 sqq.
# Auction house  Cassirer & Helbing
#
# {'Old format': " sale, Mrs. J.S. Alston et al.[section 'Various Properties'], London (Christie’s), 17 November 1972, no. 36, fl. 31,813, to the dealer David Peel, London, for the museum, as a gift from the Commissie voor Fotoverkoop", 'Format': "sale, Mrs. J.S. Alston et al.[section 'Various Properties'] [section 'Various Properties'], London (Christie’s), 17 November 1972, no. 36, as a gift from the Commissie voor Fotoverkoop, fl. 31,813, to the dealer David Peel, London", 'Readable sentence': "Sold by Mrs. J.S. Alston et al.[section 'Various Properties'] [section 'Various Properties'], auctioned off in London (auction house Christie’s) on 17 November 1972, no. 36, as a gift from the Commissie voor Fotoverkoop, bought for fl. 31,813, sold to the dealer David Peel, London.", 'Parsed objects': {'Source': '', 'Section of the sale': '', 'Owner name': "Mrs. J.S. Alston et al.[section 'Various Properties'] [section 'Various Properties']", 'Owner Birth and Death Date': '', 'Place collection was stored': '', 'Place of auction': 'London', 'Auction house': 'Christie’s', 'Date of auction': '17 November 1972', 'Kavel': 'no. 36', 'Attribution': 'as a gift from the Commissie voor Fotoverkoop', 'Description': '', 'Pendant': '', 'Pendant extra information': '', 'Price': 'fl. 31,813', 'Buyer': 'to the dealer David Peel', 'City of buyer': 'London', 'Supporter of buy': ''}}
# Identifier  RM0001.COLLECT.4756
# Owner  Mrs. J.S. Alston et al.[section 'Various Properties'] [section 'Various Properties']
# Buyer  David Peel
# Price  fl. 31,813
# Date sale  17 November 1972
# Auction house  Christie’s
#
# ...
# Identifier  RM0001.COLLECT.5449
# Owner  widow of P. Overgauw-Beetz
# Buyer  the museum{
# Price   fl. 306
# Date sale  Amsterdam (F. Muller) 24 April 1900 sqq. (hors de catalogue)
# Auction house
#
# {'Old format': ' sale, Peter Arell Brown Widener (1834-1915, Philadelphia) et al. [section ‘collection d’un amateur Anglais’], Amsterdam (F. Muller), 30 June 1909, no. 61, fl. 200', 'Format': 'sale, Peter Arell Brown Widener,  Philadelphia) et al. [section ‘collection d’un amateur Anglais’], Amsterdam (F. Muller), 30 June 1909, no. 61,  fl. 200', 'Readable sentence': 'Sold by Peter Arell Brown Widener,  Philadelphia) et al. [section ‘collection d’un amateur Anglais’], auctioned off in Amsterdam (auction house F. Muller) on 30 June 1909, no. 61, bought for  fl. 200.', 'Parsed objects': {'Source': '', 'Section of the sale': '', 'Owner name': 'Peter Arell Brown Widener,  Philadelphia) et al. [section ‘collection d’un amateur Anglais’]', 'Owner Birth and Death Date': '', 'Place collection was stored': '', 'Place of auction': 'Amsterdam', 'Auction house': 'F. Muller', 'Date of auction': '30 June 1909', 'Kavel': 'no. 61', 'Attribution': '', 'Description': '', 'Pendant': '', 'Pendant extra information': '', 'Price': ' fl. 200', 'Buyer': '', 'City of buyer': '', 'Supporter of buy': ''}}
# Identifier  RM0001.COLLECT.5450
# Owner  Peter Arell Brown Widener,  Philadelphia) et al. [section ‘collection d’un amateur Anglais’]
# Buyer
# Price   fl. 200
# Date sale  30 June 1909
# Auction house  F. Muller
#
# {'Old format': " anonymous sale, Amsterdam (Mak van Waay/Sotheby's), 7 November 1977, no. 232, fl. 15,000, to the museum", 'Format': "anonymous sale, Amsterdam (Mak van Waay/Sotheby's), 7 November 1977, no. 232, fl. 15,000, to the museum", 'Readable sentence': "Sold by anonymous, auctioned off in Amsterdam (auction house Mak van Waay/Sotheby's) on 7 November 1977, no. 232, bought for fl. 15,000, sold to the museum.", 'Parsed objects': {'Source': '', 'Section of the sale': '', 'Owner name': '', 'Owner Birth and Death Date': '', 'Place collection was stored': '', 'Place of auction': 'Amsterdam', 'Auction house': "Mak van Waay/Sotheby's", 'Date of auction': '7 November 1977', 'Kavel': 'no. 232', 'Attribution': '', 'Description': '', 'Pendant': '', 'Pendant extra information': '', 'Price': 'fl. 15,000', 'Buyer': 'to the museum', 'City of buyer': '', 'Supporter of buy': ''}}
# Identifier  RM0001.COLLECT.5465
# Owner
# Buyer  the museum
# Price  fl. 15,000
# Date sale  7 November 1977
# Auction house  Mak van Waay/Sotheby's
#
# {'Old format': ' sale, Henry Scipio Reitlinger (1882-1950, London), London (Sotheby’s), 9 December 1953, no. 13, £ 850 to W. Sabin', 'Format': 'sale, Henry Scipio Reitlinger (1882-1950, London), London (Sotheby’s), 9 December 1953, no. 13,  £ 850 to W. Sabin, £ 850 to W. Sabin', 'Readable sentence': 'Sold by Henry Scipio Reitlinger (1882-1950, item previously kept in London), auctioned off in London (auction house Sotheby’s) on 9 December 1953, no. 13, bought for  £ 850 to W. Sabin, sold £ 850 to W. Sabin.', 'Parsed objects': {'Source': '', 'Section of the sale': '', 'Owner name': 'Henry Scipio Reitlinger', 'Owner Birth and Death Date': '1882-1950', 'Place collection was stored': 'London', 'Place of auction': 'London', 'Auction house': 'Sotheby’s', 'Date of auction': '9 December 1953', 'Kavel': 'no. 13', 'Attribution': '', 'Description': '', 'Pendant': '', 'Pendant extra information': '', 'Price': ' £ 850 to W. Sabin', 'Buyer': '£ 850 to W. Sabin', 'City of buyer': '', 'Supporter of buy': ''}}
# Identifier  RM0001.COLLECT.5483
# Owner  Henry Scipio Reitlinger
# Buyer  £ 850 W. Sabin
# Price   £ 850 to W. Sabin
# Date sale  9 December 1953
# Auction house  Sotheby’s
#
# {'Old format': 'sale, Dowager Lady Nunburnholme et al. [anonymous section],  London (Christie’s), 31 March 1933, no. 103, 300 gns', 'Format': 'sale, Dowager Lady Nunburnholme et al. [anonymous section] [anonymous section], London (Christie’s), 31 March 1933, no. 103', 'Readable sentence': 'Sold by Dowager Lady Nunburnholme et al. [anonymous section] [anonymous section], auctioned off in London (auction house Christie’s) on 31 March 1933, no. 103.', 'Parsed objects': {'Source': '', 'Section of the sale': '', 'Owner name': 'Dowager Lady Nunburnholme et al. [anonymous section] [anonymous section]', 'Owner Birth and Death Date': '', 'Place collection was stored': '', 'Place of auction': 'London', 'Auction house': 'Christie’s', 'Date of auction': '31 March 1933', 'Kavel': 'no. 103', 'Attribution': '', 'Description': '', 'Pendant': '', 'Pendant extra information': '', 'Price': '', 'Buyer': '', 'City of buyer': '', 'Supporter of buy': ''}}
# Identifier  RM0001.COLLECT.5501
# Owner  Dowager Lady Nunburnholme et al. [anonymous section] [anonymous section]
# Buyer
# Price
# Date sale  31 March 1933
# Auction house  Christie’s
#
# {'Old format': ' sale, Church of Our Lady and St Thomas of Canterbury, Harrow-on-the-Hill, London (Sotheby’s), 6 December 1967, no. 82', 'Format': 'sale, Church of Our Lady and St Thomas of Canterbury, Harrow-on-the-Hill, London (Sotheby’s), no. 82', 'Readable sentence': 'Sold by Church of Our Lady and St Thomas of Canterbury, auctioned off in Harrow-on-the-Hill on London (Sotheby’s), no. 82.', 'Parsed objects': {'Source': '', 'Section of the sale': '', 'Owner name': 'Church of Our Lady and St Thomas of Canterbury', 'Owner Birth and Death Date': '', 'Place collection was stored': '', 'Place of auction': 'Harrow-on-the-Hill', 'Auction house': '', 'Date of auction': 'London (Sotheby’s)', 'Kavel': 'no. 82', 'Attribution': '', 'Description': '', 'Pendant': '', 'Pendant extra information': '', 'Price': '', 'Buyer': '', 'City of buyer': '', 'Supporter of buy': ''}}
# Identifier  RM0001.COLLECT.5518
# Owner  Church of Our Lady and St Thomas of Canterbury
# Buyer
# Price
# Date sale
# Auction house
#
# {'Old format': ' sale, Lieutenant-Colonel Robert James Leslie Ogilby (1880-1964, London) London (Sotheby’s), 8 July 1964, no. 17, fl. 16,078.95, to the museum', 'Format': 'sale, Lieutenant-Colonel Robert James Leslie Ogilby (1880-1964, London London (Sotheby’s), 8 July 1964, no. 17,  fl. 16, to the museum', 'Readable sentence': 'Sold by Lieutenant-Colonel Robert James Leslie Ogilby (1880-1964, item previously kept in London London (Sotheby’s), auctioned off in 8 July 1964, no. 17, bought for  fl. 16, sold to the museum.', 'Parsed objects': {'Source': '', 'Section of the sale': '', 'Owner name': 'Lieutenant-Colonel Robert James Leslie Ogilby', 'Owner Birth and Death Date': '1880-1964', 'Place collection was stored': 'London London (Sotheby’s', 'Place of auction': '8 July 1964', 'Auction house': '', 'Date of auction': '', 'Kavel': 'no. 17', 'Attribution': '', 'Description': '', 'Pendant': '', 'Pendant extra information': '', 'Price': ' fl. 16', 'Buyer': 'to the museum', 'City of buyer': '', 'Supporter of buy': ''}}
# Identifier  RM0001.COLLECT.5523
# Owner  Lieutenant-Colonel Robert James Leslie Ogilby
# Buyer  the museum
# Price   fl. 16
# Date sale
# Auction house
#
# {'Old format': '{Lionel  William Inigo-Jones was the descendant of Joseph Neeld through an illegitimate daughter.} his sale, London (Christie’s), 13 July 1945, no. 42, as Titian (‘Venus, of the Villa Borghese’), £ 115  10 s, to Fenouil', 'Format': '{Lionel  William Inigo-Jones was the descendant of Joseph Neeld through an illegitimate daughter.} his sale, London (Christie’s), 13 July 1945, no. 42, as Titian (‘Venus,  £ 115  10 s, to Fenouil', 'Readable sentence': 'Sold by him, auctioned off in London (auction house Christie’s) on 13 July 1945, no. 42, as Titian (‘Venus, bought for  £ 115  10 s, sold to Fenouil.', 'Parsed objects': {'Source': '{Lionel  William Inigo-Jones was the descendant of Joseph Neeld through an illegitimate daughter.}', 'Section of the sale': '', 'Owner name': '', 'Owner Birth and Death Date': '', 'Place collection was stored': '', 'Place of auction': 'London', 'Auction house': 'Christie’s', 'Date of auction': '13 July 1945', 'Kavel': 'no. 42', 'Attribution': 'as Titian (‘Venus', 'Description': '', 'Pendant': '', 'Pendant extra information': '', 'Price': ' £ 115  10 s', 'Buyer': 'to Fenouil', 'City of buyer': '', 'Supporter of buy': ''}}
# Identifier  RM0001.COLLECT.5534
# Owner
# Buyer  Fenouil
# Price   £ 115  10 s
# Date sale  13 July 1945
# Auction house  Christie’s
#
# {'Old format': " sale, M.A.W. Volz et al. [section 'diverses provenances'], Amsterdam (Frederik Muller), 15 April 1947 sqq., no. 563, as Piazza Navona à Rome avec fontaine, fl. 260, to Prins", 'Format': "sale, M.A.W. Volz et al. [section 'diverses provenances'] [section 'diverses provenances'], Amsterdam (Frederik Muller), 15 April 1947 sqq., no. 563, as Piazza Navona à Rome avec fontaine,  fl. 260, to Prins", 'Readable sentence': "Sold by M.A.W. Volz et al. [section 'diverses provenances'] [section 'diverses provenances'], auctioned off in Amsterdam (auction house Frederik Muller) on 15 April 1947 sqq., no. 563, as Piazza Navona à Rome avec fontaine, bought for  fl. 260, sold to Prins.", 'Parsed objects': {'Source': '', 'Section of the sale': '', 'Owner name': "M.A.W. Volz et al. [section 'diverses provenances'] [section 'diverses provenances']", 'Owner Birth and Death Date': '', 'Place collection was stored': '', 'Place of auction': 'Amsterdam', 'Auction house': 'Frederik Muller', 'Date of auction': '15 April 1947 sqq.', 'Kavel': 'no. 563', 'Attribution': 'as Piazza Navona à Rome avec fontaine', 'Description': '', 'Pendant': '', 'Pendant extra information': '', 'Price': ' fl. 260', 'Buyer': 'to Prins', 'City of buyer': '', 'Supporter of buy': ''}}
# Identifier  RM0001.COLLECT.5543
# Owner  M.A.W. Volz et al. [section 'diverses provenances'] [section 'diverses provenances']
# Buyer  Prins
# Price   fl. 260
# Date sale  15 April 1947 sqq.
# Auction house  Frederik Muller
#
# {'Old format': ' sale, E.W. Johnson (†, Chichester), London (Christie’s), 16 November 1874, no. 506, to Atkins', 'Format': 'sale, E.W. Johnson, Chichester), London (Christie’s), no. 506, to Atkins', 'Readable sentence': 'Sold by E.W. Johnson, auctioned off in Chichester) on London (Christie’s), no. 506, sold to Atkins.', 'Parsed objects': {'Source': '', 'Section of the sale': '', 'Owner name': 'E.W. Johnson', 'Owner Birth and Death Date': '', 'Place collection was stored': '', 'Place of auction': 'Chichester)', 'Auction house': '', 'Date of auction': 'London (Christie’s)', 'Kavel': 'no. 506', 'Attribution': '', 'Description': '', 'Pendant': '', 'Pendant extra information': '', 'Price': '', 'Buyer': 'to Atkins', 'City of buyer': '', 'Supporter of buy': ''}}
# Identifier  RM0001.COLLECT.5562
# Owner  E.W. Johnson
# Buyer  Atkins
# Price
# Date sale
# Auction house
#
# {'Old format': ' sale, the late Matthew White Ridley Esq. et al., London (Robinson, Fisher and Harding), 11 November 1937, no. 99, as B. Cuyp', 'Format': 'sale, the late Matthew White Ridley Esq. et al., London (Robinson), Fisher and Harding), no. 99, as B. Cuyp', 'Readable sentence': 'Sold by the late Matthew White Ridley Esq. et al., auctioned off in London (auction house Robinson) on Fisher and Harding), no. 99, as B. Cuyp.', 'Parsed objects': {'Source': '', 'Section of the sale': '', 'Owner name': 'the late Matthew White Ridley Esq. et al.', 'Owner Birth and Death Date': '', 'Place collection was stored': '', 'Place of auction': 'London', 'Auction house': 'Robinson', 'Date of auction': 'Fisher and Harding)', 'Kavel': 'no. 99', 'Attribution': 'as B. Cuyp', 'Description': '', 'Pendant': '', 'Pendant extra information': '', 'Price': '', 'Buyer': '', 'City of buyer': '', 'Supporter of buy': ''}}
# Identifier  RM0001.COLLECT.5572
# Owner  the late Matthew White Ridley Esq. et al.
# Buyer
# Price
# Date sale
# Auction house  Robinson
#
# {'Old format': ' sale, Richard von Kaufmann (1849-1908, Berlin), Berlin (Cassirer & Helbing), 4 December 1917 sqq., no 60, 200,000', 'Format': 'sale, Richard von Kaufmann (1849-1908, Berlin), Berlin (Cassirer & Helbing), 4 December 1917 sqq.', 'Readable sentence': 'Sold by Richard von Kaufmann (1849-1908, item previously kept in Berlin), auctioned off in Berlin (auction house Cassirer & Helbing) on 4 December 1917 sqq..', 'Parsed objects': {'Source': '', 'Section of the sale': '', 'Owner name': 'Richard von Kaufmann', 'Owner Birth and Death Date': '1849-1908', 'Place collection was stored': 'Berlin', 'Place of auction': 'Berlin', 'Auction house': 'Cassirer & Helbing', 'Date of auction': '4 December 1917 sqq.', 'Kavel': '', 'Attribution': '', 'Description': '', 'Pendant': '', 'Pendant extra information': '', 'Price': '', 'Buyer': '', 'City of buyer': '', 'Supporter of buy': ''}}
# Identifier  RM0001.COLLECT.5578
# Owner  Richard von Kaufmann
# Buyer
# Price
# Date sale  4 December 1917 sqq.
# Auction house  Cassirer & Helbing
#
# {'Old format': ' his sale, Amsterdam (F. Muller), 30 November 1920, no. 1015, to Antoon van Welie (1866-1956), The Hague', 'Format': 'his sale, Amsterdam (F. Muller), 30 November 1920, no. 1015, to Antoon van Welie (1866-1956), The Hague', 'Readable sentence': 'Sold by him, auctioned off in Amsterdam (auction house F. Muller) on 30 November 1920, no. 1015, sold to Antoon van Welie (1866-1956), The Hague.', 'Parsed objects': {'Source': '', 'Section of the sale': '', 'Owner name': '', 'Owner Birth and Death Date': '', 'Place collection was stored': '', 'Place of auction': 'Amsterdam', 'Auction house': 'F. Muller', 'Date of auction': '30 November 1920', 'Kavel': 'no. 1015', 'Attribution': '', 'Description': '', 'Pendant': '', 'Pendant extra information': '', 'Price': '', 'Buyer': 'to Antoon van Welie (1866-1956)', 'City of buyer': 'The Hague', 'Supporter of buy': ''}}
# Identifier  RM0001.COLLECT.5627
# Owner
# Buyer  Antoon van Welie (1866-1956)
# Price
# Date sale  30 November 1920
# Auction house  F. Muller
#
# {'Old format': ' sale, Grimaldi de Cadix et al. [section Grimaldi], Amsterdam (F. Muller), 4 December 1912 sqq., no. 61 as Luca Signorelli, fl. 410, to Antoon Derkinderen (1859-1925), Amsterdam', 'Format': 'sale, Grimaldi de Cadix et al. [section Grimaldi] [section Grimaldi], Amsterdam (F. Muller), 4 December 1912 sqq., no. 61 as Luca Signorelli, no. 61 as Luca Signorelli,  fl. 410, to Antoon Derkinderen (1859-1925), Amsterdam', 'Readable sentence': 'Sold by Grimaldi de Cadix et al. [section Grimaldi] [section Grimaldi], auctioned off in Amsterdam (auction house F. Muller) on 4 December 1912 sqq., no. 61 as Luca Signorelli, no. 61 as Luca Signorelli, bought for  fl. 410, sold to Antoon Derkinderen (1859-1925), Amsterdam.', 'Parsed objects': {'Source': '', 'Section of the sale': '', 'Owner name': 'Grimaldi de Cadix et al. [section Grimaldi] [section Grimaldi]', 'Owner Birth and Death Date': '', 'Place collection was stored': '', 'Place of auction': 'Amsterdam', 'Auction house': 'F. Muller', 'Date of auction': '4 December 1912 sqq.', 'Kavel': 'no. 61 as Luca Signorelli', 'Attribution': 'no. 61 as Luca Signorelli', 'Description': '', 'Pendant': '', 'Pendant extra information': '', 'Price': ' fl. 410', 'Buyer': 'to Antoon Derkinderen (1859-1925)', 'City of buyer': 'Amsterdam', 'Supporter of buy': ''}}
# Identifier  RM0001.COLLECT.5805
# Owner  Grimaldi de Cadix et al. [section Grimaldi] [section Grimaldi]
# Buyer  Antoon Derkinderen (1859-1925)
# Price   fl. 410
# Date sale  4 December 1912 sqq.
# Auction house  F. Muller

# %%
#function for all auction items
def auction_item(item):
    """
    Parse provenance items sold at an auction and return the new proper format, the readable sentence, and the format if the item is suspicious
    """
    start_source = ''
    sale_section = ''
    owner = ''
    BDDate = ''
    place_collection = ''
    place_auction = ''
    auctionhouse = ''
    date_auction = ''
    kavel_no = ''
    attribution = ''
    description = ''
    pendant = ''
    pendant_extra = ''
    price = ''
    buyer = ''
    buyer_city = ''
    supporter = ''
    source = ''
    anonymous = False
    his = False
    her = False
    start_item = item
        
    certain_uncertain = item.split('(')
    if '?' in certain_uncertain[0]:
        #provenance data is uncertain
        proper_format = '? '
        readable_sent = 'Possibly sold by'
    else:
        #provenance data is certain
        proper_format = ''
        readable_sent = 'Sold by'
    #start_source
    source_split = item.split('}')
    if len(source_split) >1:
        if ('sale' in source_split[0] or 'Sale' in source_split[0]) and not 'sale' in source_split[1] and not 'Sale' in source_split[1]:
            return 'Wrongly assigned due to source information', 'Wrongly assigned due to source information', 'Wrongly assigned due to source information'
        if 'sale' in source_split[1]:
            start_source = source_split[0].replace('{', '').strip()
    #source
    if start_source == '':
        source_split = item.split('{')
        if len(source_split) >1:
            source = source_split[1].replace('}', '').strip()
        
    #item without source
    if start_source != '':
        item = item.replace(start_source, '').strip()
        start_source = '{'+start_source+'}'
    if source != '':
        item = item.replace(source, '').strip()
        source = '{'+source+'}'

    comma_split = item.split(',')
    #name of owner
    if 'anonymous sale' in comma_split[0]:
        anonymous = True
        owner = ''
        if 'section' in comma_split[0]:
            square_split = item.split('[')
            sale_section = square_split[1]
            sale_section = sale_section.split(']')
            sale_section = sale_section[0].strip()
    elif 'his' in comma_split[0] and 'sale' in comma_split[0]:
        his = True
        owner = ''
    elif 'her' in comma_split[0] and 'sale' in comma_split[0]:
        her = True
        owner = ''
    else:
        owner = comma_split[1].split('(')
        owner = owner[0].strip()
        
    #if et al. in owner
    if 'et al.' in owner:
        square_split = item.split('[')
        if len(square_split) >1:
            if 'section' in square_split[1]:
                square_split = square_split[1].split(']')
                owner = owner + ' [' + square_split[0].strip() + ']'
                item = item.replace(square_split[0],'')
    #new comma split in case there was a section item
    comma_split = item.split(',')
    if 'et al.' in comma_split[2]:
        owner = owner + ', ' + comma_split[2]
        owner = owner.strip()
    
    #birth/death date owner and place of collection before sale
    if owner != '':
        BDDate_item = comma_split[1]
        if '†' in BDDate_item:
            BDdate = '†'
        elif ('1' in BDDate_item or '2' in BDDate_item) and not 'collection' in comma_split[2]:
            BDsplit = BDDate_item.split('(')
            BDDate = BDsplit[1].replace(')', '').strip()
            if not BDsplit[1].endswith(')'):
                place_collection = comma_split[2].replace(')','').strip()                
    
    #place of auction and auction house
    #for anonymous sale:
    if owner == '':
        place_auction_item = comma_split[1]
        auction_split = place_auction_item.split('(')
        place_auction = auction_split[0].strip()
        if len(auction_split) >1:
            auctionhouse = auction_split[1].replace(')', '').strip()
    #for known owner
    
    if owner != '' and place_collection == '':
        if 'et al.' in owner and ',' in owner:
            place_auction_item = comma_split[3]
        else:
            place_auction_item = comma_split[2]
        auction_split = place_auction_item.split('(')
        place_auction = auction_split[0].strip()
        if len(auction_split) > 1:
            auctionhouse = auction_split[1].replace(')', '').strip()
    if owner != '' and place_collection != '':
        if 'et al.' in owner and ',' in owner:
            place_auction_item = comma_split[4]
        else:
            place_auction_item = comma_split[3]
        auction_split = place_auction_item.split('(')
        place_auction = auction_split[0].strip()
        if len(auction_split) > 1:
            auctionhouse = auction_split[1].replace(')', '').strip()
            if '1' in auctionhouse:
                date_auction = auctionhouse
                auctionhouse = ''
      
    if '1' in auctionhouse:
        date_auction = auctionhouse
        auctionhouse = ''
    #date auction
    #for anonymous sale
    if owner == '':
        if 'no.' not in comma_split[2]:
            date_auction = comma_split[2].strip()
    #for known owner
    elif owner != '' and place_collection == '' and date_auction =='':
        if 'et al.' in owner and ',' in owner:
            if 'no.' not in comma_split[4]:
                date_auction = comma_split[4].strip()
        else:
            if 'no.' not in comma_split[3]:
                date_auction = comma_split[3].strip()
    elif owner != '' and place_collection != '' and len(comma_split) >4 and date_auction =='':
        if 'et al.' in owner and ',' in owner:
            if 'no.' not in comma_split[5]:
                date_auction = comma_split[5].strip()
        else:
            if 'no.' not in comma_split[4]:
                date_auction = comma_split[4].strip()
        
    #kavel no, price, attribution, pendant, pendant extra
    for item in comma_split:
        if 'no.' in item and kavel_no == '':
            kavel_no = item.strip()
        money = (' fl. ', ' frs. ', ' bf ', '£', ' gns ', ' s ', '$', ' DM ', ' CHF ', ' CAD ', ' ATS ')
        for valuta in money:
            if valuta in item:
                price = item
                price_index = comma_split.index(price)
                if len(comma_split) > price_index+2:
                    if comma_split[price_index+1].isnumeric():
                        price = price+','+comma_split[price_index+1]
                        price = price.strip()
        if ' to ' in item:
            buyer_index = item
            buyer = item.strip()
            #is the city of the buyer specified
            buyer_index = comma_split.index(buyer_index)
            if (len(comma_split) > (buyer_index + 1)) and 'with support' not in comma_split[(buyer_index+1)]:
                buyer_city = comma_split[(buyer_index+1)].strip()
        if 'with support' in item:
            supporter = item.strip()
        if 'without attribution' in item:
            attribution = item.strip()
        if ' as ' in item:
            attribution = item.strip()
        if 'with pendant' in item:
            pendant = item.strip()
        if pendant != '':                     
            if 'no.' in item:
                item_index_1 = comma_split.index(item)
                for item in comma_split:
                    for valuta in money:
                        if valuta in item:
                            item_index_2 = comma_split.index(item)
                            pendant_extra = comma_split[int(item_index_1):item_index_2]
                            pendant_extra = ','.join(pendant_extra)
                            
    para_split = item.split('(')
    for item in para_split:
        if item.startswith("'"):
            description = item.split(')')
            description = description[0].strip()
            
    #proper format and readable sentence
    #proper format
    if start_source != '':
        proper_format = f"{start_source} {proper_format}"
    if anonymous == True and sale_section == '':
        proper_format = f"{proper_format}anonymous sale"
    if anonymous == True and sale_section != '':
        proper_format = f"{proper_format}anonymous sale [{sale_section}]"
    if his == True:
        proper_format = f"{proper_format}his sale"
    if her == True:
        proper_format = f"{proper_format}her sale"
    if anonymous == False and his == False and her == False:
        proper_format = f"{proper_format}sale"
    if owner != '' and anonymous == False and his == False and her == False:
        proper_format = f"{proper_format}, {owner}"
    if BDDate != '' and place_collection == '':
        proper_format = f"{proper_format} ({BDDate})"
    if BDDate != '' and place_collection != '':
        proper_format = f"{proper_format} ({BDDate}, {place_collection})"
    if place_auction != '':
        proper_format = f"{proper_format}, {place_auction}"
    if auctionhouse != '':
        proper_format = f"{proper_format} ({auctionhouse})"
    if date_auction != '':
        proper_format = f"{proper_format}, {date_auction}"
    if kavel_no != '':
        proper_format = f"{proper_format}, {kavel_no}"
    if attribution != '':
        proper_format = f"{proper_format}, {attribution}"
    if description != '':
        proper_format = f"{proper_format} ({description})"
    if pendant != '':
        proper_format = f"{proper_format}, {pendant}"
    if pendant_extra != '':
        proper_format = f"{proper_format}, {pendant_extra}"
    if price != '':
        proper_format = f"{proper_format}, {price}"
    if buyer != '':
        proper_format = f"{proper_format}, {buyer}"
    if buyer_city != '':
        proper_format = f"{proper_format}, {buyer_city}"
    if supporter != '':
        proper_format = f"{proper_format}, {supporter}"
    if source != '':
        proper_format = f"{proper_format} {source}"
    
    #readable sentence
    if anonymous == True and sale_section == '':
        readable_sent = f"{readable_sent} anonymous"
    if anonymous == True and sale_section != '':
        readable_sent = f"{readable_sent} anonymous [{sale_section}]"
    if his == True:
        readable_sent = f"{readable_sent} him"
    if her == True:
        readable_sent = f"{readable_sent} her"
    if anonymous == False and his == False and her == False and owner != '':
        readable_sent = f"{readable_sent} {owner}"
    if BDDate != '' and place_collection == '':
        readable_sent = f"{readable_sent} ({BDDate})"
    if BDDate != '' and place_collection != '':
        readable_sent = f"{readable_sent} ({BDDate}, item previously kept in {place_collection})"
    if place_auction != '':
        readable_sent = f"{readable_sent}, auctioned off in {place_auction}"
    if auctionhouse != '':
        readable_sent = f"{readable_sent} (auction house {auctionhouse})"
    if date_auction != '':
        readable_sent = f"{readable_sent} on {date_auction}"
    if kavel_no != '':
        readable_sent = f"{readable_sent}, {kavel_no}"
    if attribution != '':
        readable_sent = f"{readable_sent}, {attribution}"
    if description != '':
        readable_sent = f"{readable_sent} ({description})"
    if pendant != '':
        readable_sent = f"{readable_sent}, {pendant}"
    if pendant_extra != '':
        readable_sent = f"{readable_sent}, {pendant_extra}"
    if price != '':
        readable_sent = f"{readable_sent}, bought for {price}"
    if buyer != '':
        readable_sent = f"{readable_sent}, sold {buyer}"
    if buyer_city != '':
        readable_sent = f"{readable_sent}, {buyer_city}"
    if supporter != '':
        readable_sent = f"{readable_sent}, {supporter}"
    readable_sent = f"{readable_sent}."
    
    if start_source != '':
        source = start_source
    
    parsed_dict = {'Source' : source, 'Section of the sale' : sale_section, 'Owner name' : owner, 'Owner Birth and Death Date' : BDDate, 'Place collection was stored': place_collection, 'Place of auction' : place_auction, 'Auction house' : auctionhouse, 'Date of auction' : date_auction, 'Kavel' : kavel_no, 'Attribution' : attribution, 'Description' : description, 'Pendant' : pendant, 'Pendant extra information' : pendant_extra, 'Price' : price, 'Buyer' : buyer, 'City of buyer': buyer_city, 'Supporter of buy' : supporter}
    
    return proper_format, readable_sent, parsed_dict
