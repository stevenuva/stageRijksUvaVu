# %%
#imports prov for python
from prov.model import ProvDocument

rijksmuseum = ProvDocument()

# %%
rijksmuseum.add_namespace('Identifier','https://www.example.org/rijks_prov#PersistentIdentifier')# (Persistent)Identifier, refers to a specific artwork
rijksmuseum.add_namespace('Buyer','http://www.example.org/rijks_prov#Buyer')
rijksmuseum.add_namespace('Auctioned','http://www.example.org/rijks_prov#Auctioned')
rijksmuseum.add_namespace('Owner','http://www.example.org/rijks_prov#Owner')
# Out:
# <Namespace: Owner {http://www.example.org/rijks_prov#Owner}>

# %%
#import everything that's necessary
import os
from lxml import etree

#get path where provenance XML file is stored
xml_path = input('Please enter the path to the provenance XML file on your computer. ')
doc = etree.parse(xml_path)
record_elem = doc.findall('recordList/record')
#../Data/xml_data/provenance.xml
# Out:
# Please enter the path to the provenance XML file on your computer. ../Data/xml_data/provenance.xml

# %%
identifier_dict = dict()
for elem in record_elem[:401]:
    #get the identifier
    identifier = elem.find('PersistentIdentifier')
    identifier = identifier.text
    #get the provenance text
    provenance = elem.find('provenance/provenance.project.txt')
    if provenance == None:
        continue
    provenance = provenance.text
    #split the provenance text into its separate chunks
    provenance_list = provenance.split(';')
    for elem in provenance_list:
        #see what kind of element it is and go to that function
        elem_old = elem
        if 'Londen' in elem:
            elem.replace('Londen', 'London')
        if ' hrough ' in elem:
            elem.replace(' hrough ', ' through ')
        if ' throught ' in elem:
            elem.replace(' throught ', ' through ')
        if 'Christies' in elem:
            elem.replace('Christies', "Christie's")
        if 'Sothbys' in elem:
            elem.replace('Sothbys', "Sothby's")
        if 'Sale' in elem or 'sale' in elem:
            elem_new_format, elem_new_readable, parsed_dict = auction_item(elem)
        else: 
            continue
            
        format_dict = {'Old format' : elem_old, 'Format' : elem_new_format, 'Readable sentence' : elem_new_readable, 'Parsed objects': parsed_dict}
        identifier_dict[identifier] = format_dict
#print(identifier_dict)
identifiers = identifier_dict.keys()
for painting in identifiers:
    if identifier_dict[painting]['Parsed objects'] == 'Wrongly assigned due to source information':
        continue
    #print(identifier_dict[painting])
    identifier = painting
    buyer = identifier_dict[painting]['Parsed objects']['Buyer']
    if 'to the dealer' in buyer:
        buyer = buyer.replace('to the dealer ','')
    if 'to ' in buyer:
        buyer = buyer.replace('to ', '')
    if 'for the museum' in buyer:
        buyer = buyer.replace(' for the museum','')
    buyer_city = identifier_dict[painting]['Parsed objects']['City of buyer']
    if 'for the' in buyer_city:
        buyer_city = ''
    if 'as a gift' in buyer_city:
        buyer_city = ''
    price = identifier_dict[painting]['Parsed objects']['Price']
    date_sale = identifier_dict[painting]['Parsed objects']['Date of auction']
    if '1' not in date_sale:
        date_sale = ''
    auctionhouse = identifier_dict[painting]['Parsed objects']['Auction house'] 
    if price == '':
        price = 'sale price unknown'
    if buyer_city == '':
        buyer_city = '?'
    if date_sale == '':
        date_sale = '?'
    if auctionhouse == '':
        auctionhouse = '?'
    if buyer == '':
        buyer = 'anonymous sale'
   
    Persistentidentifier = 'Identifier:'+ identifier
    Agent_buyer = 'Buyer:'+buyer+',[prov:type: Person , prov:location: '+buyer_city+']' 
    Activitity_auction = 'Auctioned:'+ price +',[prov:start: '+ date_sale +' , prov:location: '+auctionhouse+']'
    print(type(Agent_buyer))
    
    e1 = rijksmuseum.entity(Persistentidentifier)
    a1 = rijksmuseum.agent(Agent_buyer)  #,'{'+'prov:type: Person', 'prov:location: '+buyer_city+'}')
    activity1 = rijksmuseum.activity('Auctioned:'+price) #,{'prov:start: '+date_sale,'prov:location: '+auctionhouse})

    rijksmuseum.wasAttributedTo(e1, a1)
    rijksmuseum.used(activity1, e1)
    rijksmuseum.wasAssociatedWith(activity1, a1)
    print(rijksmuseum.get_provn())
# Out:
# <class 'str'>
# document
#   prefix Identifier <https://www.example.org/rijks_prov#PersistentIdentifier>
#   prefix Buyer <http://www.example.org/rijks_prov#Buyer>
#   prefix Auctioned <http://www.example.org/rijks_prov#Auctioned>
#   prefix Owner <http://www.example.org/rijks_prov#Owner>
#
#   entity(Identifier:RM0001.COLLECT.2)
#   agent(Buyer:R. Noortman,[prov:type: Person , prov:location: ?])
#   activity(Auctioned:sale price unknown, -, -)
#   wasAttributedTo(Identifier:RM0001.COLLECT.2, Buyer:R. Noortman,[prov:type: Person , prov:location: ?])
#   used(Auctioned:sale price unknown, Identifier:RM0001.COLLECT.2, -)
#   wasAssociatedWith(Auctioned:sale price unknown, Buyer:R. Noortman,[prov:type: Person , prov:location: ?], -)
# endDocument
# <class 'str'>
# document
#   prefix Identifier <https://www.example.org/rijks_prov#PersistentIdentifier>
#   prefix Buyer <http://www.example.org/rijks_prov#Buyer>
#   prefix Auctioned <http://www.example.org/rijks_prov#Auctioned>
#   prefix Owner <http://www.example.org/rijks_prov#Owner>
#
#   entity(Identifier:RM0001.COLLECT.2)
#   agent(Buyer:R. Noortman,[prov:type: Person , prov:location: ?])
#   activity(Auctioned:sale price unknown, -, -)
#   wasAttributedTo(Identifier:RM0001.COLLECT.2, Buyer:R. Noortman,[prov:type: Person , prov:location: ?])
#   used(Auctioned:sale price unknown, Identifier:RM0001.COLLECT.2, -)
#   wasAssociatedWith(Auctioned:sale price unknown, Buyer:R. Noortman,[prov:type: Person , prov:location: ?], -)
#   entity(Identifier:RM0001.COLLECT.9)
#   agent(Buyer:anonymous sale,[prov:type: Person , prov:location: ?])
#   activity(Auctioned:sale price unknown, -, -)
#   wasAttributedTo(Identifier:RM0001.COLLECT.9, Buyer:anonymous sale,[prov:type: Person , prov:location: ?])
#   used(Auctioned:sale price unknown, Identifier:RM0001.COLLECT.9, -)
#   wasAssociatedWith(Auctioned:sale price unknown, Buyer:anonymous sale,[prov:type: Person , prov:location: ?], -)
# endDocument
# <class 'str'>
# document
#   prefix Identifier <https://www.example.org/rijks_prov#PersistentIdentifier>
#   prefix Buyer <http://www.example.org/rijks_prov#Buyer>
#   prefix Auctioned <http://www.example.org/rijks_prov#Auctioned>
#   prefix Owner <http://www.example.org/rijks_prov#Owner>
#
#   entity(Identifier:RM0001.COLLECT.2)
#   agent(Buyer:R. Noortman,[prov:type: Person , prov:location: ?])
#   activity(Auctioned:sale price unknown, -, -)
#   wasAttributedTo(Identifier:RM0001.COLLECT.2, Buyer:R. Noortman,[prov:type: Person , prov:location: ?])
#   used(Auctioned:sale price unknown, Identifier:RM0001.COLLECT.2, -)
#   wasAssociatedWith(Auctioned:sale price unknown, Buyer:R. Noortman,[prov:type: Person , prov:location: ?], -)
#   entity(Identifier:RM0001.COLLECT.9)
#   agent(Buyer:anonymous sale,[prov:type: Person , prov:location: ?])
#   activity(Auctioned:sale price unknown, -, -)
#   wasAttributedTo(Identifier:RM0001.COLLECT.9, Buyer:anonymous sale,[prov:type: Person , prov:location: ?])
#   used(Auctioned:sale price unknown, Identifier:RM0001.COLLECT.9, -)
#   wasAssociatedWith(Auctioned:sale price unknown, Buyer:anonymous sale,[prov:type: Person , prov:location: ?], -)
#   entity(Identifier:RM0001.COLLECT.2316)
#   agent(Buyer:Colnaghi,[prov:type: Person , prov:location: ?])
#   activity(Auctioned:£ 1,100, -, -)
#   wasAttributedTo(Identifier:RM0001.COLLECT.2316, Buyer:Colnaghi,[prov:type: Person , prov:location: ?])
#   used(Auctioned:£ 1,100, Identifier:RM0001.COLLECT.2316, -)
#   wasAssociatedWith(Auctioned:£ 1,100, Buyer:Colnaghi,[prov:type: Person , prov:location: ?], -)
# endDocument
# <class 'str'>
# document
#   prefix Identifier <https://www.example.org/rijks_prov#PersistentIdentifier>
#   prefix Buyer <http://www.example.org/rijks_prov#Buyer>
#   prefix Auctioned <http://www.example.org/rijks_prov#Auctioned>
#   prefix Owner <http://www.example.org/rijks_prov#Owner>
#
#   entity(Identifier:RM0001.COLLECT.2)
#   agent(Buyer:R. Noortman,[prov:type: Person , prov:location: ?])
#   activity(Auctioned:sale price unknown, -, -)
#   wasAttributedTo(Identifier:RM0001.COLLECT.2, Buyer:R. Noortman,[prov:type: Person , prov:location: ?])
#   used(Auctioned:sale price unknown, Identifier:RM0001.COLLECT.2, -)
#   wasAssociatedWith(Auctioned:sale price unknown, Buyer:R. Noortman,[prov:type: Person , prov:location: ?], -)
#   entity(Identifier:RM0001.COLLECT.9)
#   agent(Buyer:anonymous sale,[prov:type: Person , prov:location: ?])
#   activity(Auctioned:sale price unknown, -, -)
#   wasAttributedTo(Identifier:RM0001.COLLECT.9, Buyer:anonymous sale,[prov:type: Person , prov:location: ?])
#   used(Auctioned:sale price unknown, Identifier:RM0001.COLLECT.9, -)
#   wasAssociatedWith(Auctioned:sale price unknown, Buyer:anonymous sale,[prov:type: Person , prov:location: ?], -)
#   entity(Identifier:RM0001.COLLECT.2316)
#   agent(Buyer:Colnaghi,[prov:type: Person , prov:location: ?])
#   activity(Auctioned:£ 1,100, -, -)
#   wasAttributedTo(Identifier:RM0001.COLLECT.2316, Buyer:Colnaghi,[prov:type: Person , prov:location: ?])
#   used(Auctioned:£ 1,100, Identifier:RM0001.COLLECT.2316, -)
#   wasAssociatedWith(Auctioned:£ 1,100, Buyer:Colnaghi,[prov:type: Person , prov:location: ?], -)
#   entity(Identifier:RM0001.COLLECT.2805)
#   agent(Buyer:anonymous sale,[prov:type: Person , prov:location: ?])
#   activity(Auctioned:sale price unknown, -, -)
#   wasAttributedTo(Identifier:RM0001.COLLECT.2805, Buyer:anonymous sale,[prov:type: Person , prov:location: ?])
#   used(Auctioned:sale price unknown, Identifier:RM0001.COLLECT.2805, -)
#   wasAssociatedWith(Auctioned:sale price unknown, Buyer:anonymous sale,[prov:type: Person , prov:location: ?], -)
# endDocument
# <class 'str'>
# document
#   prefix Identifier <https://www.example.org/rijks_prov#PersistentIdentifier>
#   prefix Buyer <http://www.example.org/rijks_prov#Buyer>
#   prefix Auctioned <http://www.example.org/rijks_prov#Auctioned>
#   prefix Owner <http://www.example.org/rijks_prov#Owner>
#
#   entity(Identifier:RM0001.COLLECT.2)
#   agent(Buyer:R. Noortman,[prov:type: Person , prov:location: ?])
#   activity(Auctioned:sale price unknown, -, -)
#   wasAttributedTo(Identifier:RM0001.COLLECT.2, Buyer:R. Noortman,[prov:type: Person , prov:location: ?])
#   used(Auctioned:sale price unknown, Identifier:RM0001.COLLECT.2, -)
#   wasAssociatedWith(Auctioned:sale price unknown, Buyer:R. Noortman,[prov:type: Person , prov:location: ?], -)
#   entity(Identifier:RM0001.COLLECT.9)
#   agent(Buyer:anonymous sale,[prov:type: Person , prov:location: ?])
#   activity(Auctioned:sale price unknown, -, -)
#   wasAttributedTo(Identifier:RM0001.COLLECT.9, Buyer:anonymous sale,[prov:type: Person , prov:location: ?])
#   used(Auctioned:sale price unknown, Identifier:RM0001.COLLECT.9, -)
#   wasAssociatedWith(Auctioned:sale price unknown, Buyer:anonymous sale,[prov:type: Person , prov:location: ?], -)
#   entity(Identifier:RM0001.COLLECT.2316)
#   agent(Buyer:Colnaghi,[prov:type: Person , prov:location: ?])
#   activity(Auctioned:£ 1,100, -, -)
#   wasAttributedTo(Identifier:RM0001.COLLECT.2316, Buyer:Colnaghi,[prov:type: Person , prov:location: ?])
#   used(Auctioned:£ 1,100, Identifier:RM0001.COLLECT.2316, -)
#   wasAssociatedWith(Auctioned:£ 1,100, Buyer:Colnaghi,[prov:type: Person , prov:location: ?], -)
#   entity(Identifier:RM0001.COLLECT.2805)
#   agent(Buyer:anonymous sale,[prov:type: Person , prov:location: ?])
#   activity(Auctioned:sale price unknown, -, -)
#   wasAttributedTo(Identifier:RM0001.COLLECT.2805, Buyer:anonymous sale,[prov:type: Person , prov:location: ?])
#   used(Auctioned:sale price unknown, Identifier:RM0001.COLLECT.2805, -)
#   wasAssociatedWith(Auctioned:sale price unknown, Buyer:anonymous sale,[prov:type: Person , prov:location: ?], -)
#   entity(Identifier:RM0001.COLLECT.2807)
#   agent(Buyer:anonymous sale,[prov:type: Person , prov:location: ?])
#   activity(Auctioned:sale price unknown, -, -)
#   wasAttributedTo(Identifier:RM0001.COLLECT.2807, Buyer:anonymous sale,[prov:type: Person , prov:location: ?])
#   used(Auctioned:sale price unknown, Identifier:RM0001.COLLECT.2807, -)
#   wasAssociatedWith(Auctioned:sale price unknown, Buyer:anonymous sale,[prov:type: Person , prov:location: ?], -)
# endDocument
# <class 'str'>
# document
#   prefix Identifier <https://www.example.org/rijks_prov#PersistentIdentifier>
#   prefix Buyer <http://www.example.org/rijks_prov#Buyer>
#   prefix Auctioned <http://www.example.org/rijks_prov#Auctioned>
#   prefix Owner <http://www.example.org/rijks_prov#Owner>
#
#   entity(Identifier:RM0001.COLLECT.2)
#   agent(Buyer:R. Noortman,[prov:type: Person , prov:location: ?])
#   activity(Auctioned:sale price unknown, -, -)
#   wasAttributedTo(Identifier:RM0001.COLLECT.2, Buyer:R. Noortman,[prov:type: Person , prov:location: ?])
#   used(Auctioned:sale price unknown, Identifier:RM0001.COLLECT.2, -)
#   wasAssociatedWith(Auctioned:sale price unknown, Buyer:R. Noortman,[prov:type: Person , prov:location: ?], -)
#   entity(Identifier:RM0001.COLLECT.9)
#   agent(Buyer:anonymous sale,[prov:type: Person , prov:location: ?])
#   activity(Auctioned:sale price unknown, -, -)
#   wasAttributedTo(Identifier:RM0001.COLLECT.9, Buyer:anonymous sale,[prov:type: Person , prov:location: ?])
#   used(Auctioned:sale price unknown, Identifier:RM0001.COLLECT.9, -)
#   wasAssociatedWith(Auctioned:sale price unknown, Buyer:anonymous sale,[prov:type: Person , prov:location: ?], -)
#   entity(Identifier:RM0001.COLLECT.2316)
#   agent(Buyer:Colnaghi,[prov:type: Person , prov:location: ?])
#   activity(Auctioned:£ 1,100, -, -)
#   wasAttributedTo(Identifier:RM0001.COLLECT.2316, Buyer:Colnaghi,[prov:type: Person , prov:location: ?])
#   used(Auctioned:£ 1,100, Identifier:RM0001.COLLECT.2316, -)
#   wasAssociatedWith(Auctioned:£ 1,100, Buyer:Colnaghi,[prov:type: Person , prov:location: ?], -)
#   entity(Identifier:RM0001.COLLECT.2805)
#   agent(Buyer:anonymous sale,[prov:type: Person , prov:location: ?])
#   activity(Auctioned:sale price unknown, -, -)
#   wasAttributedTo(Identifier:RM0001.COLLECT.2805, Buyer:anonymous sale,[prov:type: Person , prov:location: ?])
#   used(Auctioned:sale price unknown, Identifier:RM0001.COLLECT.2805, -)
#   wasAssociatedWith(Auctioned:sale price unknown, Buyer:anonymous sale,[prov:type: Person , prov:location: ?], -)
#   entity(Identifier:RM0001.COLLECT.2807)
#   agent(Buyer:anonymous sale,[prov:type: Person , prov:location: ?])
#   activity(Auctioned:sale price unknown, -, -)
#   wasAttributedTo(Identifier:RM0001.COLLECT.2807, Buyer:anonymous sale,[prov:type: Person , prov:location: ?])
#   used(Auctioned:sale price unknown, Identifier:RM0001.COLLECT.2807, -)
#   wasAssociatedWith(Auctioned:sale price unknown, Buyer:anonymous sale,[prov:type: Person , prov:location: ?], -)
#   entity(Identifier:RM0001.COLLECT.3177)
#   agent(Buyer:Heilbronner,[prov:type: Person , prov:location: Berlin])
#   activity(Auctioned:DM 250,000, -, -)
#   wasAttributedTo(Identifier:RM0001.COLLECT.3177, Buyer:Heilbronner,[prov:type: Person , prov:location: Berlin])
#   used(Auctioned:DM 250,000, Identifier:RM0001.COLLECT.3177, -)
#   wasAssociatedWith(Auctioned:DM 250,000, Buyer:Heilbronner,[prov:type: Person , prov:location: Berlin], -)
# endDocument
# <class 'str'>
# document
#   prefix Identifier <https://www.example.org/rijks_prov#PersistentIdentifier>
#   prefix Buyer <http://www.example.org/rijks_prov#Buyer>
#   prefix Auctioned <http://www.example.org/rijks_prov#Auctioned>
#   prefix Owner <http://www.example.org/rijks_prov#Owner>
#
#   entity(Identifier:RM0001.COLLECT.2)
#   agent(Buyer:R. Noortman,[prov:type: Person , prov:location: ?])
#   activity(Auctioned:sale price unknown, -, -)
#   wasAttributedTo(Identifier:RM0001.COLLECT.2, Buyer:R. Noortman,[prov:type: Person , prov:location: ?])
#   used(Auctioned:sale price unknown, Identifier:RM0001.COLLECT.2, -)
#   wasAssociatedWith(Auctioned:sale price unknown, Buyer:R. Noortman,[prov:type: Person , prov:location: ?], -)
#   entity(Identifier:RM0001.COLLECT.9)
#   agent(Buyer:anonymous sale,[prov:type: Person , prov:location: ?])
#   activity(Auctioned:sale price unknown, -, -)
#   wasAttributedTo(Identifier:RM0001.COLLECT.9, Buyer:anonymous sale,[prov:type: Person , prov:location: ?])
#   used(Auctioned:sale price unknown, Identifier:RM0001.COLLECT.9, -)
#   wasAssociatedWith(Auctioned:sale price unknown, Buyer:anonymous sale,[prov:type: Person , prov:location: ?], -)
#   entity(Identifier:RM0001.COLLECT.2316)
#   agent(Buyer:Colnaghi,[prov:type: Person , prov:location: ?])
#   activity(Auctioned:£ 1,100, -, -)
#   wasAttributedTo(Identifier:RM0001.COLLECT.2316, Buyer:Colnaghi,[prov:type: Person , prov:location: ?])
#   used(Auctioned:£ 1,100, Identifier:RM0001.COLLECT.2316, -)
#   wasAssociatedWith(Auctioned:£ 1,100, Buyer:Colnaghi,[prov:type: Person , prov:location: ?], -)
#   entity(Identifier:RM0001.COLLECT.2805)
#   agent(Buyer:anonymous sale,[prov:type: Person , prov:location: ?])
#   activity(Auctioned:sale price unknown, -, -)
#   wasAttributedTo(Identifier:RM0001.COLLECT.2805, Buyer:anonymous sale,[prov:type: Person , prov:location: ?])
#   used(Auctioned:sale price unknown, Identifier:RM0001.COLLECT.2805, -)
#   wasAssociatedWith(Auctioned:sale price unknown, Buyer:anonymous sale,[prov:type: Person , prov:location: ?], -)
#   entity(Identifier:RM0001.COLLECT.2807)
#   agent(Buyer:anonymous sale,[prov:type: Person , prov:location: ?])
#   activity(Auctioned:sale price unknown, -, -)
#   wasAttributedTo(Identifier:RM0001.COLLECT.2807, Buyer:anonymous sale,[prov:type: Person , prov:location: ?])
#   used(Auctioned:sale price unknown, Identifier:RM0001.COLLECT.2807, -)
#   wasAssociatedWith(Auctioned:sale price unknown, Buyer:anonymous sale,[prov:type: Person , prov:location: ?], -)
#   entity(Identifier:RM0001.COLLECT.3177)
#   agent(Buyer:Heilbronner,[prov:type: Person , prov:location: Berlin])
#   activity(Auctioned:DM 250,000, -, -)
#   wasAttributedTo(Identifier:RM0001.COLLECT.3177, Buyer:Heilbronner,[prov:type: Person , prov:location: Berlin])
#   used(Auctioned:DM 250,000, Identifier:RM0001.COLLECT.3177, -)
#   wasAssociatedWith(Auctioned:DM 250,000, Buyer:Heilbronner,[prov:type: Person , prov:location: Berlin], -)
#   entity(Identifier:RM0001.COLLECT.3864)
#   agent(Buyer:anonymous sale,[prov:type: Person , prov:location: ?])
#   activity(Auctioned:sale price unknown, -, -)
#   wasAttributedTo(Identifier:RM0001.COLLECT.3864, Buyer:anonymous sale,[prov:type: Person , prov:location: ?])
#   used(Auctioned:sale price unknown, Identifier:RM0001.COLLECT.3864, -)
#   wasAssociatedWith(Auctioned:sale price unknown, Buyer:anonymous sale,[prov:type: Person , prov:location: ?], -)
# endDocument
# <class 'str'>
# document
#   prefix Identifier <https://www.example.org/rijks_prov#PersistentIdentifier>
#   prefix Buyer <http://www.example.org/rijks_prov#Buyer>
#   prefix Auctioned <http://www.example.org/rijks_prov#Auctioned>
#   prefix Owner <http://www.example.org/rijks_prov#Owner>
#
#   entity(Identifier:RM0001.COLLECT.2)
#   agent(Buyer:R. Noortman,[prov:type: Person , prov:location: ?])
#   activity(Auctioned:sale price unknown, -, -)
#   wasAttributedTo(Identifier:RM0001.COLLECT.2, Buyer:R. Noortman,[prov:type: Person , prov:location: ?])
#   used(Auctioned:sale price unknown, Identifier:RM0001.COLLECT.2, -)
#   wasAssociatedWith(Auctioned:sale price unknown, Buyer:R. Noortman,[prov:type: Person , prov:location: ?], -)
#   entity(Identifier:RM0001.COLLECT.9)
#   agent(Buyer:anonymous sale,[prov:type: Person , prov:location: ?])
#   activity(Auctioned:sale price unknown, -, -)
#   wasAttributedTo(Identifier:RM0001.COLLECT.9, Buyer:anonymous sale,[prov:type: Person , prov:location: ?])
#   used(Auctioned:sale price unknown, Identifier:RM0001.COLLECT.9, -)
#   wasAssociatedWith(Auctioned:sale price unknown, Buyer:anonymous sale,[prov:type: Person , prov:location: ?], -)
#   entity(Identifier:RM0001.COLLECT.2316)
#   agent(Buyer:Colnaghi,[prov:type: Person , prov:location: ?])
#   activity(Auctioned:£ 1,100, -, -)
#   wasAttributedTo(Identifier:RM0001.COLLECT.2316, Buyer:Colnaghi,[prov:type: Person , prov:location: ?])
#   used(Auctioned:£ 1,100, Identifier:RM0001.COLLECT.2316, -)
#   wasAssociatedWith(Auctioned:£ 1,100, Buyer:Colnaghi,[prov:type: Person , prov:location: ?], -)
#   entity(Identifier:RM0001.COLLECT.2805)
#   agent(Buyer:anonymous sale,[prov:type: Person , prov:location: ?])
#   activity(Auctioned:sale price unknown, -, -)
#   wasAttributedTo(Identifier:RM0001.COLLECT.2805, Buyer:anonymous sale,[prov:type: Person , prov:location: ?])
#   used(Auctioned:sale price unknown, Identifier:RM0001.COLLECT.2805, -)
#   wasAssociatedWith(Auctioned:sale price unknown, Buyer:anonymous sale,[prov:type: Person , prov:location: ?], -)
#   entity(Identifier:RM0001.COLLECT.2807)
#   agent(Buyer:anonymous sale,[prov:type: Person , prov:location: ?])
#   activity(Auctioned:sale price unknown, -, -)
#   wasAttributedTo(Identifier:RM0001.COLLECT.2807, Buyer:anonymous sale,[prov:type: Person , prov:location: ?])
#   used(Auctioned:sale price unknown, Identifier:RM0001.COLLECT.2807, -)
#   wasAssociatedWith(Auctioned:sale price unknown, Buyer:anonymous sale,[prov:type: Person , prov:location: ?], -)
#   entity(Identifier:RM0001.COLLECT.3177)
#   agent(Buyer:Heilbronner,[prov:type: Person , prov:location: Berlin])
#   activity(Auctioned:DM 250,000, -, -)
#   wasAttributedTo(Identifier:RM0001.COLLECT.3177, Buyer:Heilbronner,[prov:type: Person , prov:location: Berlin])
#   used(Auctioned:DM 250,000, Identifier:RM0001.COLLECT.3177, -)
#   wasAssociatedWith(Auctioned:DM 250,000, Buyer:Heilbronner,[prov:type: Person , prov:location: Berlin], -)
#   entity(Identifier:RM0001.COLLECT.3864)
#   agent(Buyer:anonymous sale,[prov:type: Person , prov:location: ?])
#   activity(Auctioned:sale price unknown, -, -)
#   wasAttributedTo(Identifier:RM0001.COLLECT.3864, Buyer:anonymous sale,[prov:type: Person , prov:location: ?])
#   used(Auctioned:sale price unknown, Identifier:RM0001.COLLECT.3864, -)
#   wasAssociatedWith(Auctioned:sale price unknown, Buyer:anonymous sale,[prov:type: Person , prov:location: ?], -)
#   entity(Identifier:RM0001.COLLECT.3865)
#   agent(Buyer:anonymous sale,[prov:type: Person , prov:location: ?])
#   activity(Auctioned:sale price unknown, -, -)
#   wasAttributedTo(Identifier:RM0001.COLLECT.3865, Buyer:anonymous sale,[prov:type: Person , prov:location: ?])
#   used(Auctioned:sale price unknown, Identifier:RM0001.COLLECT.3865, -)
#   wasAssociatedWith(Auctioned:sale price unknown, Buyer:anonymous sale,[prov:type: Person , prov:location: ?], -)
# endDocument
# <class 'str'>
# document
#   prefix Identifier <https://www.example.org/rijks_prov#PersistentIdentifier>
#   prefix Buyer <http://www.example.org/rijks_prov#Buyer>
#   prefix Auctioned <http://www.example.org/rijks_prov#Auctioned>
#   prefix Owner <http://www.example.org/rijks_prov#Owner>
#
#   entity(Identifier:RM0001.COLLECT.2)
#   agent(Buyer:R. Noortman,[prov:type: Person , prov:location: ?])
#   activity(Auctioned:sale price unknown, -, -)
#   wasAttributedTo(Identifier:RM0001.COLLECT.2, Buyer:R. Noortman,[prov:type: Person , prov:location: ?])
#   used(Auctioned:sale price unknown, Identifier:RM0001.COLLECT.2, -)
#   wasAssociatedWith(Auctioned:sale price unknown, Buyer:R. Noortman,[prov:type: Person , prov:location: ?], -)
#   entity(Identifier:RM0001.COLLECT.9)
#   agent(Buyer:anonymous sale,[prov:type: Person , prov:location: ?])
#   activity(Auctioned:sale price unknown, -, -)
#   wasAttributedTo(Identifier:RM0001.COLLECT.9, Buyer:anonymous sale,[prov:type: Person , prov:location: ?])
#   used(Auctioned:sale price unknown, Identifier:RM0001.COLLECT.9, -)
#   wasAssociatedWith(Auctioned:sale price unknown, Buyer:anonymous sale,[prov:type: Person , prov:location: ?], -)
#   entity(Identifier:RM0001.COLLECT.2316)
#   agent(Buyer:Colnaghi,[prov:type: Person , prov:location: ?])
#   activity(Auctioned:£ 1,100, -, -)
#   wasAttributedTo(Identifier:RM0001.COLLECT.2316, Buyer:Colnaghi,[prov:type: Person , prov:location: ?])
#   used(Auctioned:£ 1,100, Identifier:RM0001.COLLECT.2316, -)
#   wasAssociatedWith(Auctioned:£ 1,100, Buyer:Colnaghi,[prov:type: Person , prov:location: ?], -)
#   entity(Identifier:RM0001.COLLECT.2805)
#   agent(Buyer:anonymous sale,[prov:type: Person , prov:location: ?])
#   activity(Auctioned:sale price unknown, -, -)
#   wasAttributedTo(Identifier:RM0001.COLLECT.2805, Buyer:anonymous sale,[prov:type: Person , prov:location: ?])
#   used(Auctioned:sale price unknown, Identifier:RM0001.COLLECT.2805, -)
#   wasAssociatedWith(Auctioned:sale price unknown, Buyer:anonymous sale,[prov:type: Person , prov:location: ?], -)
#   entity(Identifier:RM0001.COLLECT.2807)
#   agent(Buyer:anonymous sale,[prov:type: Person , prov:location: ?])
#   activity(Auctioned:sale price unknown, -, -)
#   wasAttributedTo(Identifier:RM0001.COLLECT.2807, Buyer:anonymous sale,[prov:type: Person , prov:location: ?])
#   used(Auctioned:sale price unknown, Identifier:RM0001.COLLECT.2807, -)
#   wasAssociatedWith(Auctioned:sale price unknown, Buyer:anonymous sale,[prov:type: Person , prov:location: ?], -)
#   entity(Identifier:RM0001.COLLECT.3177)
#   agent(Buyer:Heilbronner,[prov:type: Person , prov:location: Berlin])
#   activity(Auctioned:DM 250,000, -, -)
#   wasAttributedTo(Identifier:RM0001.COLLECT.3177, Buyer:Heilbronner,[prov:type: Person , prov:location: Berlin])
#   used(Auctioned:DM 250,000, Identifier:RM0001.COLLECT.3177, -)
#   wasAssociatedWith(Auctioned:DM 250,000, Buyer:Heilbronner,[prov:type: Person , prov:location: Berlin], -)
#   entity(Identifier:RM0001.COLLECT.3864)
#   agent(Buyer:anonymous sale,[prov:type: Person , prov:location: ?])
#   activity(Auctioned:sale price unknown, -, -)
#   wasAttributedTo(Identifier:RM0001.COLLECT.3864, Buyer:anonymous sale,[prov:type: Person , prov:location: ?])
#   used(Auctioned:sale price unknown, Identifier:RM0001.COLLECT.3864, -)
#   wasAssociatedWith(Auctioned:sale price unknown, Buyer:anonymous sale,[prov:type: Person , prov:location: ?], -)
#   entity(Identifier:RM0001.COLLECT.3865)
#   agent(Buyer:anonymous sale,[prov:type: Person , prov:location: ?])
#   activity(Auctioned:sale price unknown, -, -)
#   wasAttributedTo(Identifier:RM0001.COLLECT.3865, Buyer:anonymous sale,[prov:type: Person , prov:location: ?])
#   used(Auctioned:sale price unknown, Identifier:RM0001.COLLECT.3865, -)
#   wasAssociatedWith(Auctioned:sale price unknown, Buyer:anonymous sale,[prov:type: Person , prov:location: ?], -)
#   entity(Identifier:RM0001.COLLECT.4468)
#   agent(Buyer:anonymous sale,[prov:type: Person , prov:location: ?])
#   activity(Auctioned:sale price unknown, -, -)
#   wasAttributedTo(Identifier:RM0001.COLLECT.4468, Buyer:anonymous sale,[prov:type: Person , prov:location: ?])
#   used(Auctioned:sale price unknown, Identifier:RM0001.COLLECT.4468, -)
#   wasAssociatedWith(Auctioned:sale price unknown, Buyer:anonymous sale,[prov:type: Person , prov:location: ?], -)
# endDocument
# <class 'str'>
# document
#   prefix Identifier <https://www.example.org/rijks_prov#PersistentIdentifier>
#   prefix Buyer <http://www.example.org/rijks_prov#Buyer>
#   prefix Auctioned <http://www.example.org/rijks_prov#Auctioned>
#   prefix Owner <http://www.example.org/rijks_prov#Owner>
#
#   entity(Identifier:RM0001.COLLECT.2)
#   agent(Buyer:R. Noortman,[prov:type: Person , prov:location: ?])
#   activity(Auctioned:sale price unknown, -, -)
#   wasAttributedTo(Identifier:RM0001.COLLECT.2, Buyer:R. Noortman,[prov:type: Person , prov:location: ?])
#   used(Auctioned:sale price unknown, Identifier:RM0001.COLLECT.2, -)
#   wasAssociatedWith(Auctioned:sale price unknown, Buyer:R. Noortman,[prov:type: Person , prov:location: ?], -)
#   entity(Identifier:RM0001.COLLECT.9)
#   agent(Buyer:anonymous sale,[prov:type: Person , prov:location: ?])
#   activity(Auctioned:sale price unknown, -, -)
#   wasAttributedTo(Identifier:RM0001.COLLECT.9, Buyer:anonymous sale,[prov:type: Person , prov:location: ?])
#   used(Auctioned:sale price unknown, Identifier:RM0001.COLLECT.9, -)
#   wasAssociatedWith(Auctioned:sale price unknown, Buyer:anonymous sale,[prov:type: Person , prov:location: ?], -)
#   entity(Identifier:RM0001.COLLECT.2316)
#   agent(Buyer:Colnaghi,[prov:type: Person , prov:location: ?])
#   activity(Auctioned:£ 1,100, -, -)
#   wasAttributedTo(Identifier:RM0001.COLLECT.2316, Buyer:Colnaghi,[prov:type: Person , prov:location: ?])
#   used(Auctioned:£ 1,100, Identifier:RM0001.COLLECT.2316, -)
#   wasAssociatedWith(Auctioned:£ 1,100, Buyer:Colnaghi,[prov:type: Person , prov:location: ?], -)
#   entity(Identifier:RM0001.COLLECT.2805)
#   agent(Buyer:anonymous sale,[prov:type: Person , prov:location: ?])
#   activity(Auctioned:sale price unknown, -, -)
#   wasAttributedTo(Identifier:RM0001.COLLECT.2805, Buyer:anonymous sale,[prov:type: Person , prov:location: ?])
#   used(Auctioned:sale price unknown, Identifier:RM0001.COLLECT.2805, -)
#   wasAssociatedWith(Auctioned:sale price unknown, Buyer:anonymous sale,[prov:type: Person , prov:location: ?], -)
#   entity(Identifier:RM0001.COLLECT.2807)
#   agent(Buyer:anonymous sale,[prov:type: Person , prov:location: ?])
#   activity(Auctioned:sale price unknown, -, -)
#   wasAttributedTo(Identifier:RM0001.COLLECT.2807, Buyer:anonymous sale,[prov:type: Person , prov:location: ?])
#   used(Auctioned:sale price unknown, Identifier:RM0001.COLLECT.2807, -)
#   wasAssociatedWith(Auctioned:sale price unknown, Buyer:anonymous sale,[prov:type: Person , prov:location: ?], -)
#   entity(Identifier:RM0001.COLLECT.3177)
#   agent(Buyer:Heilbronner,[prov:type: Person , prov:location: Berlin])
#   activity(Auctioned:DM 250,000, -, -)
#   wasAttributedTo(Identifier:RM0001.COLLECT.3177, Buyer:Heilbronner,[prov:type: Person , prov:location: Berlin])
#   used(Auctioned:DM 250,000, Identifier:RM0001.COLLECT.3177, -)
#   wasAssociatedWith(Auctioned:DM 250,000, Buyer:Heilbronner,[prov:type: Person , prov:location: Berlin], -)
#   entity(Identifier:RM0001.COLLECT.3864)
#   agent(Buyer:anonymous sale,[prov:type: Person , prov:location: ?])
#   activity(Auctioned:sale price unknown, -, -)
#   wasAttributedTo(Identifier:RM0001.COLLECT.3864, Buyer:anonymous sale,[prov:type: Person , prov:location: ?])
#   used(Auctioned:sale price unknown, Identifier:RM0001.COLLECT.3864, -)
#   wasAssociatedWith(Auctioned:sale price unknown, Buyer:anonymous sale,[prov:type: Person , prov:location: ?], -)
#   entity(Identifier:RM0001.COLLECT.3865)
#   agent(Buyer:anonymous sale,[prov:type: Person , prov:location: ?])
#   activity(Auctioned:sale price unknown, -, -)
#   wasAttributedTo(Identifier:RM0001.COLLECT.3865, Buyer:anonymous sale,[prov:type: Person , prov:location: ?])
#   used(Auctioned:sale price unknown, Identifier:RM0001.COLLECT.3865, -)
#   wasAssociatedWith(Auctioned:sale price unknown, Buyer:anonymous sale,[prov:type: Person , prov:location: ?], -)
#   entity(Identifier:RM0001.COLLECT.4468)
#   agent(Buyer:anonymous sale,[prov:type: Person , prov:location: ?])
#   activity(Auctioned:sale price unknown, -, -)
#   wasAttributedTo(Identifier:RM0001.COLLECT.4468, Buyer:anonymous sale,[prov:type: Person , prov:location: ?])
#   used(Auctioned:sale price unknown, Identifier:RM0001.COLLECT.4468, -)
#   wasAssociatedWith(Auctioned:sale price unknown, Buyer:anonymous sale,[prov:type: Person , prov:location: ?], -)
#   entity(Identifier:RM0001.COLLECT.4553)
#   agent(Buyer:anonymous sale,[prov:type: Person , prov:location: ?])
#   activity(Auctioned:sale price unknown, -, -)
#   wasAttributedTo(Identifier:RM0001.COLLECT.4553, Buyer:anonymous sale,[prov:type: Person , prov:location: ?])
#   used(Auctioned:sale price unknown, Identifier:RM0001.COLLECT.4553, -)
#   wasAssociatedWith(Auctioned:sale price unknown, Buyer:anonymous sale,[prov:type: Person , prov:location: ?], -)
# endDocument
# <class 'str'>
# document
#   prefix Identifier <https://www.example.org/rijks_prov#PersistentIdentifier>
#   prefix Buyer <http://www.example.org/rijks_prov#Buyer>
#   prefix Auctioned <http://www.example.org/rijks_prov#Auctioned>
#   prefix Owner <http://www.example.org/rijks_prov#Owner>
#
#   entity(Identifier:RM0001.COLLECT.2)
#   agent(Buyer:R. Noortman,[prov:type: Person , prov:location: ?])
#   activity(Auctioned:sale price unknown, -, -)
#   wasAttributedTo(Identifier:RM0001.COLLECT.2, Buyer:R. Noortman,[prov:type: Person , prov:location: ?])
#   used(Auctioned:sale price unknown, Identifier:RM0001.COLLECT.2, -)
#   wasAssociatedWith(Auctioned:sale price unknown, Buyer:R. Noortman,[prov:type: Person , prov:location: ?], -)
#   entity(Identifier:RM0001.COLLECT.9)
#   agent(Buyer:anonymous sale,[prov:type: Person , prov:location: ?])
#   activity(Auctioned:sale price unknown, -, -)
#   wasAttributedTo(Identifier:RM0001.COLLECT.9, Buyer:anonymous sale,[prov:type: Person , prov:location: ?])
#   used(Auctioned:sale price unknown, Identifier:RM0001.COLLECT.9, -)
#   wasAssociatedWith(Auctioned:sale price unknown, Buyer:anonymous sale,[prov:type: Person , prov:location: ?], -)
#   entity(Identifier:RM0001.COLLECT.2316)
#   agent(Buyer:Colnaghi,[prov:type: Person , prov:location: ?])
#   activity(Auctioned:£ 1,100, -, -)
#   wasAttributedTo(Identifier:RM0001.COLLECT.2316, Buyer:Colnaghi,[prov:type: Person , prov:location: ?])
#   used(Auctioned:£ 1,100, Identifier:RM0001.COLLECT.2316, -)
#   wasAssociatedWith(Auctioned:£ 1,100, Buyer:Colnaghi,[prov:type: Person , prov:location: ?], -)
#   entity(Identifier:RM0001.COLLECT.2805)
#   agent(Buyer:anonymous sale,[prov:type: Person , prov:location: ?])
#   activity(Auctioned:sale price unknown, -, -)
#   wasAttributedTo(Identifier:RM0001.COLLECT.2805, Buyer:anonymous sale,[prov:type: Person , prov:location: ?])
#   used(Auctioned:sale price unknown, Identifier:RM0001.COLLECT.2805, -)
#   wasAssociatedWith(Auctioned:sale price unknown, Buyer:anonymous sale,[prov:type: Person , prov:location: ?], -)
#   entity(Identifier:RM0001.COLLECT.2807)
#   agent(Buyer:anonymous sale,[prov:type: Person , prov:location: ?])
#   activity(Auctioned:sale price unknown, -, -)
#   wasAttributedTo(Identifier:RM0001.COLLECT.2807, Buyer:anonymous sale,[prov:type: Person , prov:location: ?])
#   used(Auctioned:sale price unknown, Identifier:RM0001.COLLECT.2807, -)
#   wasAssociatedWith(Auctioned:sale price unknown, Buyer:anonymous sale,[prov:type: Person , prov:location: ?], -)
#   entity(Identifier:RM0001.COLLECT.3177)
#   agent(Buyer:Heilbronner,[prov:type: Person , prov:location: Berlin])
#   activity(Auctioned:DM 250,000, -, -)
#   wasAttributedTo(Identifier:RM0001.COLLECT.3177, Buyer:Heilbronner,[prov:type: Person , prov:location: Berlin])
#   used(Auctioned:DM 250,000, Identifier:RM0001.COLLECT.3177, -)
#   wasAssociatedWith(Auctioned:DM 250,000, Buyer:Heilbronner,[prov:type: Person , prov:location: Berlin], -)
#   entity(Identifier:RM0001.COLLECT.3864)
#   agent(Buyer:anonymous sale,[prov:type: Person , prov:location: ?])
#   activity(Auctioned:sale price unknown, -, -)
#   wasAttributedTo(Identifier:RM0001.COLLECT.3864, Buyer:anonymous sale,[prov:type: Person , prov:location: ?])
#   used(Auctioned:sale price unknown, Identifier:RM0001.COLLECT.3864, -)
#   wasAssociatedWith(Auctioned:sale price unknown, Buyer:anonymous sale,[prov:type: Person , prov:location: ?], -)
#   entity(Identifier:RM0001.COLLECT.3865)
#   agent(Buyer:anonymous sale,[prov:type: Person , prov:location: ?])
#   activity(Auctioned:sale price unknown, -, -)
#   wasAttributedTo(Identifier:RM0001.COLLECT.3865, Buyer:anonymous sale,[prov:type: Person , prov:location: ?])
#   used(Auctioned:sale price unknown, Identifier:RM0001.COLLECT.3865, -)
#   wasAssociatedWith(Auctioned:sale price unknown, Buyer:anonymous sale,[prov:type: Person , prov:location: ?], -)
#   entity(Identifier:RM0001.COLLECT.4468)
#   agent(Buyer:anonymous sale,[prov:type: Person , prov:location: ?])
#   activity(Auctioned:sale price unknown, -, -)
#   wasAttributedTo(Identifier:RM0001.COLLECT.4468, Buyer:anonymous sale,[prov:type: Person , prov:location: ?])
#   used(Auctioned:sale price unknown, Identifier:RM0001.COLLECT.4468, -)
#   wasAssociatedWith(Auctioned:sale price unknown, Buyer:anonymous sale,[prov:type: Person , prov:location: ?], -)
#   entity(Identifier:RM0001.COLLECT.4553)
#   agent(Buyer:anonymous sale,[prov:type: Person , prov:location: ?])
#   activity(Auctioned:sale price unknown, -, -)
#   wasAttributedTo(Identifier:RM0001.COLLECT.4553, Buyer:anonymous sale,[prov:type: Person , prov:location: ?])
#   used(Auctioned:sale price unknown, Identifier:RM0001.COLLECT.4553, -)
#   wasAssociatedWith(Auctioned:sale price unknown, Buyer:anonymous sale,[prov:type: Person , prov:location: ?], -)
#   entity(Identifier:RM0001.COLLECT.4565)
#   agent(Buyer:the Rijksmuseum-Stichting,[prov:type: Person , prov:location: ?])
#   activity(Auctioned:DM 5,600, -, -)
#   wasAttributedTo(Identifier:RM0001.COLLECT.4565, Buyer:the Rijksmuseum-Stichting,[prov:type: Person , prov:location: ?])
#   used(Auctioned:DM 5,600, Identifier:RM0001.COLLECT.4565, -)
#   wasAssociatedWith(Auctioned:DM 5,600, Buyer:the Rijksmuseum-Stichting,[prov:type: Person , prov:location: ?], -)
# endDocument
# <class 'str'>
# document
#   prefix Identifier <https://www.example.org/rijks_prov#PersistentIdentifier>
#   prefix Buyer <http://www.example.org/rijks_prov#Buyer>
#   prefix Auctioned <http://www.example.org/rijks_prov#Auctioned>
#   prefix Owner <http://www.example.org/rijks_prov#Owner>
#
#   entity(Identifier:RM0001.COLLECT.2)
#   agent(Buyer:R. Noortman,[prov:type: Person , prov:location: ?])
#   activity(Auctioned:sale price unknown, -, -)
#   wasAttributedTo(Identifier:RM0001.COLLECT.2, Buyer:R. Noortman,[prov:type: Person , prov:location: ?])
#   used(Auctioned:sale price unknown, Identifier:RM0001.COLLECT.2, -)
#   wasAssociatedWith(Auctioned:sale price unknown, Buyer:R. Noortman,[prov:type: Person , prov:location: ?], -)
#   entity(Identifier:RM0001.COLLECT.9)
#   agent(Buyer:anonymous sale,[prov:type: Person , prov:location: ?])
#   activity(Auctioned:sale price unknown, -, -)
#   wasAttributedTo(Identifier:RM0001.COLLECT.9, Buyer:anonymous sale,[prov:type: Person , prov:location: ?])
#   used(Auctioned:sale price unknown, Identifier:RM0001.COLLECT.9, -)
#   wasAssociatedWith(Auctioned:sale price unknown, Buyer:anonymous sale,[prov:type: Person , prov:location: ?], -)
#   entity(Identifier:RM0001.COLLECT.2316)
#   agent(Buyer:Colnaghi,[prov:type: Person , prov:location: ?])
#   activity(Auctioned:£ 1,100, -, -)
#   wasAttributedTo(Identifier:RM0001.COLLECT.2316, Buyer:Colnaghi,[prov:type: Person , prov:location: ?])
#   used(Auctioned:£ 1,100, Identifier:RM0001.COLLECT.2316, -)
#   wasAssociatedWith(Auctioned:£ 1,100, Buyer:Colnaghi,[prov:type: Person , prov:location: ?], -)
#   entity(Identifier:RM0001.COLLECT.2805)
#   agent(Buyer:anonymous sale,[prov:type: Person , prov:location: ?])
#   activity(Auctioned:sale price unknown, -, -)
#   wasAttributedTo(Identifier:RM0001.COLLECT.2805, Buyer:anonymous sale,[prov:type: Person , prov:location: ?])
#   used(Auctioned:sale price unknown, Identifier:RM0001.COLLECT.2805, -)
#   wasAssociatedWith(Auctioned:sale price unknown, Buyer:anonymous sale,[prov:type: Person , prov:location: ?], -)
#   entity(Identifier:RM0001.COLLECT.2807)
#   agent(Buyer:anonymous sale,[prov:type: Person , prov:location: ?])
#   activity(Auctioned:sale price unknown, -, -)
#   wasAttributedTo(Identifier:RM0001.COLLECT.2807, Buyer:anonymous sale,[prov:type: Person , prov:location: ?])
#   used(Auctioned:sale price unknown, Identifier:RM0001.COLLECT.2807, -)
#   wasAssociatedWith(Auctioned:sale price unknown, Buyer:anonymous sale,[prov:type: Person , prov:location: ?], -)
#   entity(Identifier:RM0001.COLLECT.3177)
#   agent(Buyer:Heilbronner,[prov:type: Person , prov:location: Berlin])
#   activity(Auctioned:DM 250,000, -, -)
#   wasAttributedTo(Identifier:RM0001.COLLECT.3177, Buyer:Heilbronner,[prov:type: Person , prov:location: Berlin])
#   used(Auctioned:DM 250,000, Identifier:RM0001.COLLECT.3177, -)
#   wasAssociatedWith(Auctioned:DM 250,000, Buyer:Heilbronner,[prov:type: Person , prov:location: Berlin], -)
#   entity(Identifier:RM0001.COLLECT.3864)
#   agent(Buyer:anonymous sale,[prov:type: Person , prov:location: ?])
#   activity(Auctioned:sale price unknown, -, -)
#   wasAttributedTo(Identifier:RM0001.COLLECT.3864, Buyer:anonymous sale,[prov:type: Person , prov:location: ?])
#   used(Auctioned:sale price unknown, Identifier:RM0001.COLLECT.3864, -)
#   wasAssociatedWith(Auctioned:sale price unknown, Buyer:anonymous sale,[prov:type: Person , prov:location: ?], -)
#   entity(Identifier:RM0001.COLLECT.3865)
#   agent(Buyer:anonymous sale,[prov:type: Person , prov:location: ?])
#   activity(Auctioned:sale price unknown, -, -)
#   wasAttributedTo(Identifier:RM0001.COLLECT.3865, Buyer:anonymous sale,[prov:type: Person , prov:location: ?])
#   used(Auctioned:sale price unknown, Identifier:RM0001.COLLECT.3865, -)
#   wasAssociatedWith(Auctioned:sale price unknown, Buyer:anonymous sale,[prov:type: Person , prov:location: ?], -)
#   entity(Identifier:RM0001.COLLECT.4468)
#   agent(Buyer:anonymous sale,[prov:type: Person , prov:location: ?])
#   activity(Auctioned:sale price unknown, -, -)
#   wasAttributedTo(Identifier:RM0001.COLLECT.4468, Buyer:anonymous sale,[prov:type: Person , prov:location: ?])
#   used(Auctioned:sale price unknown, Identifier:RM0001.COLLECT.4468, -)
#   wasAssociatedWith(Auctioned:sale price unknown, Buyer:anonymous sale,[prov:type: Person , prov:location: ?], -)
#   entity(Identifier:RM0001.COLLECT.4553)
#   agent(Buyer:anonymous sale,[prov:type: Person , prov:location: ?])
#   activity(Auctioned:sale price unknown, -, -)
#   wasAttributedTo(Identifier:RM0001.COLLECT.4553, Buyer:anonymous sale,[prov:type: Person , prov:location: ?])
#   used(Auctioned:sale price unknown, Identifier:RM0001.COLLECT.4553, -)
#   wasAssociatedWith(Auctioned:sale price unknown, Buyer:anonymous sale,[prov:type: Person , prov:location: ?], -)
#   entity(Identifier:RM0001.COLLECT.4565)
#   agent(Buyer:the Rijksmuseum-Stichting,[prov:type: Person , prov:location: ?])
#   activity(Auctioned:DM 5,600, -, -)
#   wasAttributedTo(Identifier:RM0001.COLLECT.4565, Buyer:the Rijksmuseum-Stichting,[prov:type: Person , prov:location: ?])
#   used(Auctioned:DM 5,600, Identifier:RM0001.COLLECT.4565, -)
#   wasAssociatedWith(Auctioned:DM 5,600, Buyer:the Rijksmuseum-Stichting,[prov:type: Person , prov:location: ?], -)
#   entity(Identifier:RM0001.COLLECT.4566)
#   agent(Buyer:the Rijksmuseum-Stichting,[prov:type: Person , prov:location: ?])
#   activity(Auctioned:DM 5,600, -, -)
#   wasAttributedTo(Identifier:RM0001.COLLECT.4566, Buyer:the Rijksmuseum-Stichting,[prov:type: Person , prov:location: ?])
#   used(Auctioned:DM 5,600, Identifier:RM0001.COLLECT.4566, -)
#   wasAssociatedWith(Auctioned:DM 5,600, Buyer:the Rijksmuseum-Stichting,[prov:type: Person , prov:location: ?], -)
# endDocument
# <class 'str'>
# document
#   prefix Identifier <https://www.example.org/rijks_prov#PersistentIdentifier>
#   prefix Buyer <http://www.example.org/rijks_prov#Buyer>
#   prefix Auctioned <http://www.example.org/rijks_prov#Auctioned>
#   prefix Owner <http://www.example.org/rijks_prov#Owner>
#
#   entity(Identifier:RM0001.COLLECT.2)
#   agent(Buyer:R. Noortman,[prov:type: Person , prov:location: ?])
#   activity(Auctioned:sale price unknown, -, -)
#   wasAttributedTo(Identifier:RM0001.COLLECT.2, Buyer:R. Noortman,[prov:type: Person , prov:location: ?])
#   used(Auctioned:sale price unknown, Identifier:RM0001.COLLECT.2, -)
#   wasAssociatedWith(Auctioned:sale price unknown, Buyer:R. Noortman,[prov:type: Person , prov:location: ?], -)
#   entity(Identifier:RM0001.COLLECT.9)
#   agent(Buyer:anonymous sale,[prov:type: Person , prov:location: ?])
#   activity(Auctioned:sale price unknown, -, -)
#   wasAttributedTo(Identifier:RM0001.COLLECT.9, Buyer:anonymous sale,[prov:type: Person , prov:location: ?])
#   used(Auctioned:sale price unknown, Identifier:RM0001.COLLECT.9, -)
#   wasAssociatedWith(Auctioned:sale price unknown, Buyer:anonymous sale,[prov:type: Person , prov:location: ?], -)
#   entity(Identifier:RM0001.COLLECT.2316)
#   agent(Buyer:Colnaghi,[prov:type: Person , prov:location: ?])
#   activity(Auctioned:£ 1,100, -, -)
#   wasAttributedTo(Identifier:RM0001.COLLECT.2316, Buyer:Colnaghi,[prov:type: Person , prov:location: ?])
#   used(Auctioned:£ 1,100, Identifier:RM0001.COLLECT.2316, -)
#   wasAssociatedWith(Auctioned:£ 1,100, Buyer:Colnaghi,[prov:type: Person , prov:location: ?], -)
#   entity(Identifier:RM0001.COLLECT.2805)
#   agent(Buyer:anonymous sale,[prov:type: Person , prov:location: ?])
#   activity(Auctioned:sale price unknown, -, -)
#   wasAttributedTo(Identifier:RM0001.COLLECT.2805, Buyer:anonymous sale,[prov:type: Person , prov:location: ?])
#   used(Auctioned:sale price unknown, Identifier:RM0001.COLLECT.2805, -)
#   wasAssociatedWith(Auctioned:sale price unknown, Buyer:anonymous sale,[prov:type: Person , prov:location: ?], -)
#   entity(Identifier:RM0001.COLLECT.2807)
#   agent(Buyer:anonymous sale,[prov:type: Person , prov:location: ?])
#   activity(Auctioned:sale price unknown, -, -)
#   wasAttributedTo(Identifier:RM0001.COLLECT.2807, Buyer:anonymous sale,[prov:type: Person , prov:location: ?])
#   used(Auctioned:sale price unknown, Identifier:RM0001.COLLECT.2807, -)
#   wasAssociatedWith(Auctioned:sale price unknown, Buyer:anonymous sale,[prov:type: Person , prov:location: ?], -)
#   entity(Identifier:RM0001.COLLECT.3177)
#   agent(Buyer:Heilbronner,[prov:type: Person , prov:location: Berlin])
#   activity(Auctioned:DM 250,000, -, -)
#   wasAttributedTo(Identifier:RM0001.COLLECT.3177, Buyer:Heilbronner,[prov:type: Person , prov:location: Berlin])
#   used(Auctioned:DM 250,000, Identifier:RM0001.COLLECT.3177, -)
#   wasAssociatedWith(Auctioned:DM 250,000, Buyer:Heilbronner,[prov:type: Person , prov:location: Berlin], -)
#   entity(Identifier:RM0001.COLLECT.3864)
#   agent(Buyer:anonymous sale,[prov:type: Person , prov:location: ?])
#   activity(Auctioned:sale price unknown, -, -)
#   wasAttributedTo(Identifier:RM0001.COLLECT.3864, Buyer:anonymous sale,[prov:type: Person , prov:location: ?])
#   used(Auctioned:sale price unknown, Identifier:RM0001.COLLECT.3864, -)
#   wasAssociatedWith(Auctioned:sale price unknown, Buyer:anonymous sale,[prov:type: Person , prov:location: ?], -)
#   entity(Identifier:RM0001.COLLECT.3865)
#   agent(Buyer:anonymous sale,[prov:type: Person , prov:location: ?])
#   activity(Auctioned:sale price unknown, -, -)
#   wasAttributedTo(Identifier:RM0001.COLLECT.3865, Buyer:anonymous sale,[prov:type: Person , prov:location: ?])
#   used(Auctioned:sale price unknown, Identifier:RM0001.COLLECT.3865, -)
#   wasAssociatedWith(Auctioned:sale price unknown, Buyer:anonymous sale,[prov:type: Person , prov:location: ?], -)
#   entity(Identifier:RM0001.COLLECT.4468)
#   agent(Buyer:anonymous sale,[prov:type: Person , prov:location: ?])
#   activity(Auctioned:sale price unknown, -, -)
#   wasAttributedTo(Identifier:RM0001.COLLECT.4468, Buyer:anonymous sale,[prov:type: Person , prov:location: ?])
#   used(Auctioned:sale price unknown, Identifier:RM0001.COLLECT.4468, -)
#   wasAssociatedWith(Auctioned:sale price unknown, Buyer:anonymous sale,[prov:type: Person , prov:location: ?], -)
#   entity(Identifier:RM0001.COLLECT.4553)
#   agent(Buyer:anonymous sale,[prov:type: Person , prov:location: ?])
#   activity(Auctioned:sale price unknown, -, -)
#   wasAttributedTo(Identifier:RM0001.COLLECT.4553, Buyer:anonymous sale,[prov:type: Person , prov:location: ?])
#   used(Auctioned:sale price unknown, Identifier:RM0001.COLLECT.4553, -)
#   wasAssociatedWith(Auctioned:sale price unknown, Buyer:anonymous sale,[prov:type: Person , prov:location: ?], -)
#   entity(Identifier:RM0001.COLLECT.4565)
#   agent(Buyer:the Rijksmuseum-Stichting,[prov:type: Person , prov:location: ?])
#   activity(Auctioned:DM 5,600, -, -)
#   wasAttributedTo(Identifier:RM0001.COLLECT.4565, Buyer:the Rijksmuseum-Stichting,[prov:type: Person , prov:location: ?])
#   used(Auctioned:DM 5,600, Identifier:RM0001.COLLECT.4565, -)
#   wasAssociatedWith(Auctioned:DM 5,600, Buyer:the Rijksmuseum-Stichting,[prov:type: Person , prov:location: ?], -)
#   entity(Identifier:RM0001.COLLECT.4566)
#   agent(Buyer:the Rijksmuseum-Stichting,[prov:type: Person , prov:location: ?])
#   activity(Auctioned:DM 5,600, -, -)
#   wasAttributedTo(Identifier:RM0001.COLLECT.4566, Buyer:the Rijksmuseum-Stichting,[prov:type: Person , prov:location: ?])
#   used(Auctioned:DM 5,600, Identifier:RM0001.COLLECT.4566, -)
#   wasAssociatedWith(Auctioned:DM 5,600, Buyer:the Rijksmuseum-Stichting,[prov:type: Person , prov:location: ?], -)
#   entity(Identifier:RM0001.COLLECT.4581)
#   agent(Buyer:Adolph Staring van de Wildenborch (1890-1980),[prov:type: Person , prov:location: Deventer])
#   activity(Auctioned: fl. 60, -, -)
#   wasAttributedTo(Identifier:RM0001.COLLECT.4581, Buyer:Adolph Staring van de Wildenborch (1890-1980),[prov:type: Person , prov:location: Deventer])
#   used(Auctioned: fl. 60, Identifier:RM0001.COLLECT.4581, -)
#   wasAssociatedWith(Auctioned: fl. 60, Buyer:Adolph Staring van de Wildenborch (1890-1980),[prov:type: Person , prov:location: Deventer], -)
# endDocument
# <class 'str'>
# document
#   prefix Identifier <https://www.example.org/rijks_prov#PersistentIdentifier>
#   prefix Buyer <http://www.example.org/rijks_prov#Buyer>
#   prefix Auctioned <http://www.example.org/rijks_prov#Auctioned>
#   prefix Owner <http://www.example.org/rijks_prov#Owner>
#
#   entity(Identifier:RM0001.COLLECT.2)
#   agent(Buyer:R. Noortman,[prov:type: Person , prov:location: ?])
#   activity(Auctioned:sale price unknown, -, -)
#   wasAttributedTo(Identifier:RM0001.COLLECT.2, Buyer:R. Noortman,[prov:type: Person , prov:location: ?])
#   used(Auctioned:sale price unknown, Identifier:RM0001.COLLECT.2, -)
#   wasAssociatedWith(Auctioned:sale price unknown, Buyer:R. Noortman,[prov:type: Person , prov:location: ?], -)
#   entity(Identifier:RM0001.COLLECT.9)
#   agent(Buyer:anonymous sale,[prov:type: Person , prov:location: ?])
#   activity(Auctioned:sale price unknown, -, -)
#   wasAttributedTo(Identifier:RM0001.COLLECT.9, Buyer:anonymous sale,[prov:type: Person , prov:location: ?])
#   used(Auctioned:sale price unknown, Identifier:RM0001.COLLECT.9, -)
#   wasAssociatedWith(Auctioned:sale price unknown, Buyer:anonymous sale,[prov:type: Person , prov:location: ?], -)
#   entity(Identifier:RM0001.COLLECT.2316)
#   agent(Buyer:Colnaghi,[prov:type: Person , prov:location: ?])
#   activity(Auctioned:£ 1,100, -, -)
#   wasAttributedTo(Identifier:RM0001.COLLECT.2316, Buyer:Colnaghi,[prov:type: Person , prov:location: ?])
#   used(Auctioned:£ 1,100, Identifier:RM0001.COLLECT.2316, -)
#   wasAssociatedWith(Auctioned:£ 1,100, Buyer:Colnaghi,[prov:type: Person , prov:location: ?], -)
#   entity(Identifier:RM0001.COLLECT.2805)
#   agent(Buyer:anonymous sale,[prov:type: Person , prov:location: ?])
#   activity(Auctioned:sale price unknown, -, -)
#   wasAttributedTo(Identifier:RM0001.COLLECT.2805, Buyer:anonymous sale,[prov:type: Person , prov:location: ?])
#   used(Auctioned:sale price unknown, Identifier:RM0001.COLLECT.2805, -)
#   wasAssociatedWith(Auctioned:sale price unknown, Buyer:anonymous sale,[prov:type: Person , prov:location: ?], -)
#   entity(Identifier:RM0001.COLLECT.2807)
#   agent(Buyer:anonymous sale,[prov:type: Person , prov:location: ?])
#   activity(Auctioned:sale price unknown, -, -)
#   wasAttributedTo(Identifier:RM0001.COLLECT.2807, Buyer:anonymous sale,[prov:type: Person , prov:location: ?])
#   used(Auctioned:sale price unknown, Identifier:RM0001.COLLECT.2807, -)
#   wasAssociatedWith(Auctioned:sale price unknown, Buyer:anonymous sale,[prov:type: Person , prov:location: ?], -)
#   entity(Identifier:RM0001.COLLECT.3177)
#   agent(Buyer:Heilbronner,[prov:type: Person , prov:location: Berlin])
#   activity(Auctioned:DM 250,000, -, -)
#   wasAttributedTo(Identifier:RM0001.COLLECT.3177, Buyer:Heilbronner,[prov:type: Person , prov:location: Berlin])
#   used(Auctioned:DM 250,000, Identifier:RM0001.COLLECT.3177, -)
#   wasAssociatedWith(Auctioned:DM 250,000, Buyer:Heilbronner,[prov:type: Person , prov:location: Berlin], -)
#   entity(Identifier:RM0001.COLLECT.3864)
#   agent(Buyer:anonymous sale,[prov:type: Person , prov:location: ?])
#   activity(Auctioned:sale price unknown, -, -)
#   wasAttributedTo(Identifier:RM0001.COLLECT.3864, Buyer:anonymous sale,[prov:type: Person , prov:location: ?])
#   used(Auctioned:sale price unknown, Identifier:RM0001.COLLECT.3864, -)
#   wasAssociatedWith(Auctioned:sale price unknown, Buyer:anonymous sale,[prov:type: Person , prov:location: ?], -)
#   entity(Identifier:RM0001.COLLECT.3865)
#   agent(Buyer:anonymous sale,[prov:type: Person , prov:location: ?])
#   activity(Auctioned:sale price unknown, -, -)
#   wasAttributedTo(Identifier:RM0001.COLLECT.3865, Buyer:anonymous sale,[prov:type: Person , prov:location: ?])
#   used(Auctioned:sale price unknown, Identifier:RM0001.COLLECT.3865, -)
# ...
#   activity(Auctioned:gns 2,200, -, -)
#   wasAttributedTo(Identifier:RM0001.COLLECT.5219, Buyer:the museum with support from the Vereniging Rembrandt and Dr Abraham Bredius,[prov:type: Person , prov:location: ?])
#   used(Auctioned:gns 2,200, Identifier:RM0001.COLLECT.5219, -)
#   wasAssociatedWith(Auctioned:gns 2,200, Buyer:the museum with support from the Vereniging Rembrandt and Dr Abraham Bredius,[prov:type: Person , prov:location: ?], -)
#   entity(Identifier:RM0001.COLLECT.5222)
#   agent(Buyer:anonymous sale,[prov:type: Person , prov:location: ?])
#   activity(Auctioned: frs. 500, -, -)
#   wasAttributedTo(Identifier:RM0001.COLLECT.5222, Buyer:anonymous sale,[prov:type: Person , prov:location: ?])
#   used(Auctioned: frs. 500, Identifier:RM0001.COLLECT.5222, -)
#   wasAssociatedWith(Auctioned: frs. 500, Buyer:anonymous sale,[prov:type: Person , prov:location: ?], -)
#   entity(Identifier:RM0001.COLLECT.5224)
#   agent(Buyer:Marcelle Bousaci,[prov:type: Person , prov:location: ?])
#   activity(Auctioned:frs. 7,800, -, -)
#   wasAttributedTo(Identifier:RM0001.COLLECT.5224, Buyer:Marcelle Bousaci,[prov:type: Person , prov:location: ?])
#   used(Auctioned:frs. 7,800, Identifier:RM0001.COLLECT.5224, -)
#   wasAssociatedWith(Auctioned:frs. 7,800, Buyer:Marcelle Bousaci,[prov:type: Person , prov:location: ?], -)
#   entity(Identifier:RM0001.COLLECT.5226)
#   agent(Buyer:Fritz Mannheimer (1890-1939),[prov:type: Person , prov:location: 20 Hobbemastraat])
#   activity(Auctioned:fl. 88,000, -, -)
#   wasAttributedTo(Identifier:RM0001.COLLECT.5226, Buyer:Fritz Mannheimer (1890-1939),[prov:type: Person , prov:location: 20 Hobbemastraat])
#   used(Auctioned:fl. 88,000, Identifier:RM0001.COLLECT.5226, -)
#   wasAssociatedWith(Auctioned:fl. 88,000, Buyer:Fritz Mannheimer (1890-1939),[prov:type: Person , prov:location: 20 Hobbemastraat], -)
#   entity(Identifier:RM0001.COLLECT.5227)
#   agent(Buyer:anonymous sale,[prov:type: Person , prov:location: ?])
#   activity(Auctioned:sale price unknown, -, -)
#   wasAttributedTo(Identifier:RM0001.COLLECT.5227, Buyer:anonymous sale,[prov:type: Person , prov:location: ?])
#   used(Auctioned:sale price unknown, Identifier:RM0001.COLLECT.5227, -)
#   wasAssociatedWith(Auctioned:sale price unknown, Buyer:anonymous sale,[prov:type: Person , prov:location: ?], -)
#   entity(Identifier:RM0001.COLLECT.5236)
#   agent(Buyer:Daan H. Cevat,[prov:type: Person , prov:location: St Peter Port])
#   activity(Auctioned:£ 1,700, -, -)
#   wasAttributedTo(Identifier:RM0001.COLLECT.5236, Buyer:Daan H. Cevat,[prov:type: Person , prov:location: St Peter Port])
#   used(Auctioned:£ 1,700, Identifier:RM0001.COLLECT.5236, -)
#   wasAssociatedWith(Auctioned:£ 1,700, Buyer:Daan H. Cevat,[prov:type: Person , prov:location: St Peter Port], -)
#   entity(Identifier:RM0001.COLLECT.5239)
#   agent(Buyer:anonymous sale,[prov:type: Person , prov:location: ?])
#   activity(Auctioned:sale price unknown, -, -)
#   wasAttributedTo(Identifier:RM0001.COLLECT.5239, Buyer:anonymous sale,[prov:type: Person , prov:location: ?])
#   used(Auctioned:sale price unknown, Identifier:RM0001.COLLECT.5239, -)
#   wasAssociatedWith(Auctioned:sale price unknown, Buyer:anonymous sale,[prov:type: Person , prov:location: ?], -)
#   entity(Identifier:RM0001.COLLECT.5241)
#   agent(Buyer:anonymous sale,[prov:type: Person , prov:location: ?])
#   activity(Auctioned:sale price unknown, -, -)
#   wasAttributedTo(Identifier:RM0001.COLLECT.5241, Buyer:anonymous sale,[prov:type: Person , prov:location: ?])
#   used(Auctioned:sale price unknown, Identifier:RM0001.COLLECT.5241, -)
#   wasAssociatedWith(Auctioned:sale price unknown, Buyer:anonymous sale,[prov:type: Person , prov:location: ?], -)
#   entity(Identifier:RM0001.COLLECT.5242)
#   agent(Buyer:anonymous sale,[prov:type: Person , prov:location: ?])
#   activity(Auctioned:sale price unknown, -, -)
#   wasAttributedTo(Identifier:RM0001.COLLECT.5242, Buyer:anonymous sale,[prov:type: Person , prov:location: ?])
#   used(Auctioned:sale price unknown, Identifier:RM0001.COLLECT.5242, -)
#   wasAssociatedWith(Auctioned:sale price unknown, Buyer:anonymous sale,[prov:type: Person , prov:location: ?], -)
#   entity(Identifier:RM0001.COLLECT.5243)
#   agent(Buyer:anonymous sale,[prov:type: Person , prov:location: ?])
#   activity(Auctioned:sale price unknown, -, -)
#   wasAttributedTo(Identifier:RM0001.COLLECT.5243, Buyer:anonymous sale,[prov:type: Person , prov:location: ?])
#   used(Auctioned:sale price unknown, Identifier:RM0001.COLLECT.5243, -)
#   wasAssociatedWith(Auctioned:sale price unknown, Buyer:anonymous sale,[prov:type: Person , prov:location: ?], -)
#   entity(Identifier:RM0001.COLLECT.5258)
#   agent(Buyer:the museum,[prov:type: Person , prov:location: ?])
#   activity(Auctioned:fl. 11,000, -, -)
#   wasAttributedTo(Identifier:RM0001.COLLECT.5258, Buyer:the museum,[prov:type: Person , prov:location: ?])
#   used(Auctioned:fl. 11,000, Identifier:RM0001.COLLECT.5258, -)
#   wasAssociatedWith(Auctioned:fl. 11,000, Buyer:the museum,[prov:type: Person , prov:location: ?], -)
#   entity(Identifier:RM0001.COLLECT.5270)
#   agent(Buyer:Dr Simon Hijman Levie (1925-?),[prov:type: Person , prov:location: Amsterdam])
#   activity(Auctioned:$20,900, -, -)
#   wasAttributedTo(Identifier:RM0001.COLLECT.5270, Buyer:Dr Simon Hijman Levie (1925-?),[prov:type: Person , prov:location: Amsterdam])
#   used(Auctioned:$20,900, Identifier:RM0001.COLLECT.5270, -)
#   wasAssociatedWith(Auctioned:$20,900, Buyer:Dr Simon Hijman Levie (1925-?),[prov:type: Person , prov:location: Amsterdam], -)
#   entity(Identifier:RM0001.COLLECT.5272)
#   agent(Buyer:B. Houthakker,[prov:type: Person , prov:location: ?])
#   activity(Auctioned:fl. 1,400, -, -)
#   wasAttributedTo(Identifier:RM0001.COLLECT.5272, Buyer:B. Houthakker,[prov:type: Person , prov:location: ?])
#   used(Auctioned:fl. 1,400, Identifier:RM0001.COLLECT.5272, -)
#   wasAssociatedWith(Auctioned:fl. 1,400, Buyer:B. Houthakker,[prov:type: Person , prov:location: ?], -)
#   entity(Identifier:RM0001.COLLECT.5340)
#   agent(Buyer:N. Beets,[prov:type: Person , prov:location: ?])
#   activity(Auctioned:fl. 35,000, -, -)
#   wasAttributedTo(Identifier:RM0001.COLLECT.5340, Buyer:N. Beets,[prov:type: Person , prov:location: ?])
#   used(Auctioned:fl. 35,000, Identifier:RM0001.COLLECT.5340, -)
#   wasAssociatedWith(Auctioned:fl. 35,000, Buyer:N. Beets,[prov:type: Person , prov:location: ?], -)
#   entity(Identifier:RM0001.COLLECT.5389)
#   agent(Buyer:anonymous sale,[prov:type: Person , prov:location: ?])
#   activity(Auctioned: fl. 1, -, -)
#   wasAttributedTo(Identifier:RM0001.COLLECT.5389, Buyer:anonymous sale,[prov:type: Person , prov:location: ?])
#   used(Auctioned: fl. 1, Identifier:RM0001.COLLECT.5389, -)
#   wasAssociatedWith(Auctioned: fl. 1, Buyer:anonymous sale,[prov:type: Person , prov:location: ?], -)
#   entity(Identifier:RM0001.COLLECT.5403)
#   agent(Buyer:the museum,[prov:type: Person , prov:location: ?])
#   activity(Auctioned:fl. 5,000, -, -)
#   wasAttributedTo(Identifier:RM0001.COLLECT.5403, Buyer:the museum,[prov:type: Person , prov:location: ?])
#   used(Auctioned:fl. 5,000, Identifier:RM0001.COLLECT.5403, -)
#   wasAssociatedWith(Auctioned:fl. 5,000, Buyer:the museum,[prov:type: Person , prov:location: ?], -)
#   entity(Identifier:RM0001.COLLECT.5417)
#   agent(Buyer:the museum,[prov:type: Person , prov:location: ?])
#   activity(Auctioned:fl. 24,000, -, -)
#   wasAttributedTo(Identifier:RM0001.COLLECT.5417, Buyer:the museum,[prov:type: Person , prov:location: ?])
#   used(Auctioned:fl. 24,000, Identifier:RM0001.COLLECT.5417, -)
#   wasAssociatedWith(Auctioned:fl. 24,000, Buyer:the museum,[prov:type: Person , prov:location: ?], -)
#   entity(Identifier:RM0001.COLLECT.5427)
#   agent(Buyer:the museum,[prov:type: Person , prov:location: ?])
#   activity(Auctioned: fl. 260, -, -)
#   wasAttributedTo(Identifier:RM0001.COLLECT.5427, Buyer:the museum,[prov:type: Person , prov:location: ?])
#   used(Auctioned: fl. 260, Identifier:RM0001.COLLECT.5427, -)
#   wasAssociatedWith(Auctioned: fl. 260, Buyer:the museum,[prov:type: Person , prov:location: ?], -)
#   entity(Identifier:RM0001.COLLECT.5435)
#   agent(Buyer:the museum,[prov:type: Person , prov:location: ?])
#   activity(Auctioned:fl. 9,000, -, -)
#   wasAttributedTo(Identifier:RM0001.COLLECT.5435, Buyer:the museum,[prov:type: Person , prov:location: ?])
#   used(Auctioned:fl. 9,000, Identifier:RM0001.COLLECT.5435, -)
#   wasAssociatedWith(Auctioned:fl. 9,000, Buyer:the museum,[prov:type: Person , prov:location: ?], -)
#   entity(Identifier:RM0001.COLLECT.5440)
#   agent(Buyer:the museum,[prov:type: Person , prov:location: ?])
#   activity(Auctioned:fl. 5,500, -, -)
#   wasAttributedTo(Identifier:RM0001.COLLECT.5440, Buyer:the museum,[prov:type: Person , prov:location: ?])
#   used(Auctioned:fl. 5,500, Identifier:RM0001.COLLECT.5440, -)
#   wasAssociatedWith(Auctioned:fl. 5,500, Buyer:the museum,[prov:type: Person , prov:location: ?], -)
#   entity(Identifier:RM0001.COLLECT.5446)
#   agent(Buyer:anonymous sale,[prov:type: Person , prov:location: ?])
#   activity(Auctioned:sale price unknown, -, -)
#   wasAttributedTo(Identifier:RM0001.COLLECT.5446, Buyer:anonymous sale,[prov:type: Person , prov:location: ?])
#   used(Auctioned:sale price unknown, Identifier:RM0001.COLLECT.5446, -)
#   wasAssociatedWith(Auctioned:sale price unknown, Buyer:anonymous sale,[prov:type: Person , prov:location: ?], -)
#   entity(Identifier:RM0001.COLLECT.5448)
#   agent(Buyer:Jonkheer Dr Jan Pieter Six (1824-99),[prov:type: Person , prov:location: ?])
#   activity(Auctioned: fl. 16, -, -)
#   wasAttributedTo(Identifier:RM0001.COLLECT.5448, Buyer:Jonkheer Dr Jan Pieter Six (1824-99),[prov:type: Person , prov:location: ?])
#   used(Auctioned: fl. 16, Identifier:RM0001.COLLECT.5448, -)
#   wasAssociatedWith(Auctioned: fl. 16, Buyer:Jonkheer Dr Jan Pieter Six (1824-99),[prov:type: Person , prov:location: ?], -)
#   entity(Identifier:RM0001.COLLECT.5449)
#   agent(Buyer:the museum{,[prov:type: Person , prov:location: ?])
#   activity(Auctioned: fl. 306, -, -)
#   wasAttributedTo(Identifier:RM0001.COLLECT.5449, Buyer:the museum{,[prov:type: Person , prov:location: ?])
#   used(Auctioned: fl. 306, Identifier:RM0001.COLLECT.5449, -)
#   wasAssociatedWith(Auctioned: fl. 306, Buyer:the museum{,[prov:type: Person , prov:location: ?], -)
#   entity(Identifier:RM0001.COLLECT.5450)
#   agent(Buyer:anonymous sale,[prov:type: Person , prov:location: ?])
#   activity(Auctioned: fl. 200, -, -)
#   wasAttributedTo(Identifier:RM0001.COLLECT.5450, Buyer:anonymous sale,[prov:type: Person , prov:location: ?])
#   used(Auctioned: fl. 200, Identifier:RM0001.COLLECT.5450, -)
#   wasAssociatedWith(Auctioned: fl. 200, Buyer:anonymous sale,[prov:type: Person , prov:location: ?], -)
#   entity(Identifier:RM0001.COLLECT.5465)
#   agent(Buyer:the museum,[prov:type: Person , prov:location: ?])
#   activity(Auctioned:fl. 15,000, -, -)
#   wasAttributedTo(Identifier:RM0001.COLLECT.5465, Buyer:the museum,[prov:type: Person , prov:location: ?])
#   used(Auctioned:fl. 15,000, Identifier:RM0001.COLLECT.5465, -)
#   wasAssociatedWith(Auctioned:fl. 15,000, Buyer:the museum,[prov:type: Person , prov:location: ?], -)
#   entity(Identifier:RM0001.COLLECT.5483)
#   agent(Buyer:£ 850 W. Sabin,[prov:type: Person , prov:location: ?])
#   activity(Auctioned: £ 850 to W. Sabin, -, -)
#   wasAttributedTo(Identifier:RM0001.COLLECT.5483, Buyer:£ 850 W. Sabin,[prov:type: Person , prov:location: ?])
#   used(Auctioned: £ 850 to W. Sabin, Identifier:RM0001.COLLECT.5483, -)
#   wasAssociatedWith(Auctioned: £ 850 to W. Sabin, Buyer:£ 850 W. Sabin,[prov:type: Person , prov:location: ?], -)
#   entity(Identifier:RM0001.COLLECT.5501)
#   agent(Buyer:anonymous sale,[prov:type: Person , prov:location: ?])
#   activity(Auctioned:sale price unknown, -, -)
#   wasAttributedTo(Identifier:RM0001.COLLECT.5501, Buyer:anonymous sale,[prov:type: Person , prov:location: ?])
#   used(Auctioned:sale price unknown, Identifier:RM0001.COLLECT.5501, -)
#   wasAssociatedWith(Auctioned:sale price unknown, Buyer:anonymous sale,[prov:type: Person , prov:location: ?], -)
#   entity(Identifier:RM0001.COLLECT.5518)
#   agent(Buyer:anonymous sale,[prov:type: Person , prov:location: ?])
#   activity(Auctioned:sale price unknown, -, -)
#   wasAttributedTo(Identifier:RM0001.COLLECT.5518, Buyer:anonymous sale,[prov:type: Person , prov:location: ?])
#   used(Auctioned:sale price unknown, Identifier:RM0001.COLLECT.5518, -)
#   wasAssociatedWith(Auctioned:sale price unknown, Buyer:anonymous sale,[prov:type: Person , prov:location: ?], -)
#   entity(Identifier:RM0001.COLLECT.5523)
#   agent(Buyer:the museum,[prov:type: Person , prov:location: ?])
#   activity(Auctioned: fl. 16, -, -)
#   wasAttributedTo(Identifier:RM0001.COLLECT.5523, Buyer:the museum,[prov:type: Person , prov:location: ?])
#   used(Auctioned: fl. 16, Identifier:RM0001.COLLECT.5523, -)
#   wasAssociatedWith(Auctioned: fl. 16, Buyer:the museum,[prov:type: Person , prov:location: ?], -)
#   entity(Identifier:RM0001.COLLECT.5534)
#   agent(Buyer:Fenouil,[prov:type: Person , prov:location: ?])
#   activity(Auctioned: £ 115  10 s, -, -)
#   wasAttributedTo(Identifier:RM0001.COLLECT.5534, Buyer:Fenouil,[prov:type: Person , prov:location: ?])
#   used(Auctioned: £ 115  10 s, Identifier:RM0001.COLLECT.5534, -)
#   wasAssociatedWith(Auctioned: £ 115  10 s, Buyer:Fenouil,[prov:type: Person , prov:location: ?], -)
#   entity(Identifier:RM0001.COLLECT.5543)
#   agent(Buyer:Prins,[prov:type: Person , prov:location: ?])
#   activity(Auctioned: fl. 260, -, -)
#   wasAttributedTo(Identifier:RM0001.COLLECT.5543, Buyer:Prins,[prov:type: Person , prov:location: ?])
#   used(Auctioned: fl. 260, Identifier:RM0001.COLLECT.5543, -)
#   wasAssociatedWith(Auctioned: fl. 260, Buyer:Prins,[prov:type: Person , prov:location: ?], -)
#   entity(Identifier:RM0001.COLLECT.5562)
#   agent(Buyer:Atkins,[prov:type: Person , prov:location: ?])
#   activity(Auctioned:sale price unknown, -, -)
#   wasAttributedTo(Identifier:RM0001.COLLECT.5562, Buyer:Atkins,[prov:type: Person , prov:location: ?])
#   used(Auctioned:sale price unknown, Identifier:RM0001.COLLECT.5562, -)
#   wasAssociatedWith(Auctioned:sale price unknown, Buyer:Atkins,[prov:type: Person , prov:location: ?], -)
#   entity(Identifier:RM0001.COLLECT.5572)
#   agent(Buyer:anonymous sale,[prov:type: Person , prov:location: ?])
#   activity(Auctioned:sale price unknown, -, -)
#   wasAttributedTo(Identifier:RM0001.COLLECT.5572, Buyer:anonymous sale,[prov:type: Person , prov:location: ?])
#   used(Auctioned:sale price unknown, Identifier:RM0001.COLLECT.5572, -)
#   wasAssociatedWith(Auctioned:sale price unknown, Buyer:anonymous sale,[prov:type: Person , prov:location: ?], -)
#   entity(Identifier:RM0001.COLLECT.5578)
#   agent(Buyer:anonymous sale,[prov:type: Person , prov:location: ?])
#   activity(Auctioned:sale price unknown, -, -)
#   wasAttributedTo(Identifier:RM0001.COLLECT.5578, Buyer:anonymous sale,[prov:type: Person , prov:location: ?])
#   used(Auctioned:sale price unknown, Identifier:RM0001.COLLECT.5578, -)
#   wasAssociatedWith(Auctioned:sale price unknown, Buyer:anonymous sale,[prov:type: Person , prov:location: ?], -)
#   entity(Identifier:RM0001.COLLECT.5627)
#   agent(Buyer:Antoon van Welie (1866-1956),[prov:type: Person , prov:location: The Hague])
#   activity(Auctioned:sale price unknown, -, -)
#   wasAttributedTo(Identifier:RM0001.COLLECT.5627, Buyer:Antoon van Welie (1866-1956),[prov:type: Person , prov:location: The Hague])
#   used(Auctioned:sale price unknown, Identifier:RM0001.COLLECT.5627, -)
#   wasAssociatedWith(Auctioned:sale price unknown, Buyer:Antoon van Welie (1866-1956),[prov:type: Person , prov:location: The Hague], -)
#   entity(Identifier:RM0001.COLLECT.5805)
#   agent(Buyer:Antoon Derkinderen (1859-1925),[prov:type: Person , prov:location: Amsterdam])
#   activity(Auctioned: fl. 410, -, -)
#   wasAttributedTo(Identifier:RM0001.COLLECT.5805, Buyer:Antoon Derkinderen (1859-1925),[prov:type: Person , prov:location: Amsterdam])
#   used(Auctioned: fl. 410, Identifier:RM0001.COLLECT.5805, -)
#   wasAssociatedWith(Auctioned: fl. 410, Buyer:Antoon Derkinderen (1859-1925),[prov:type: Person , prov:location: Amsterdam], -)
# endDocument

# %%
rijksmuseum.serialize('test_file', format='rdf', rdf_format='ttl')
# Out:
# http://www.example.org/rijks_prov#BuyerR. Noortman,[prov:type: Person , prov:location: ?] does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Auctionedsale price unknown does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#BuyerR. Noortman,[prov:type: Person , prov:location: ?] does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#BuyerR. Noortman,[prov:type: Person , prov:location: ?] does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#BuyerR. Noortman,[prov:type: Person , prov:location: ?] does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#BuyerR. Noortman,[prov:type: Person , prov:location: ?] does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Auctionedsale price unknown does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Auctionedsale price unknown does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Auctionedsale price unknown does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Auctionedsale price unknown does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Auctionedsale price unknown does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Auctionedsale price unknown does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#BuyerR. Noortman,[prov:type: Person , prov:location: ?] does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Auctionedsale price unknown does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#BuyerR. Noortman,[prov:type: Person , prov:location: ?] does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Auctionedsale price unknown does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#BuyerR. Noortman,[prov:type: Person , prov:location: ?] does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Auctionedsale price unknown does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#BuyerR. Noortman,[prov:type: Person , prov:location: ?] does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Auctionedsale price unknown does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#BuyerR. Noortman,[prov:type: Person , prov:location: ?] does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Buyeranonymous sale,[prov:type: Person , prov:location: ?] does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Auctionedsale price unknown does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Buyeranonymous sale,[prov:type: Person , prov:location: ?] does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Buyeranonymous sale,[prov:type: Person , prov:location: ?] does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Buyeranonymous sale,[prov:type: Person , prov:location: ?] does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Buyeranonymous sale,[prov:type: Person , prov:location: ?] does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Auctionedsale price unknown does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Auctionedsale price unknown does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Auctionedsale price unknown does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Auctionedsale price unknown does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Auctionedsale price unknown does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Auctionedsale price unknown does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Buyeranonymous sale,[prov:type: Person , prov:location: ?] does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Auctionedsale price unknown does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Buyeranonymous sale,[prov:type: Person , prov:location: ?] does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Auctionedsale price unknown does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Buyeranonymous sale,[prov:type: Person , prov:location: ?] does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Auctionedsale price unknown does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Buyeranonymous sale,[prov:type: Person , prov:location: ?] does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Auctionedsale price unknown does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Buyeranonymous sale,[prov:type: Person , prov:location: ?] does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#BuyerColnaghi,[prov:type: Person , prov:location: ?] does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Auctioned£ 1,100 does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#BuyerColnaghi,[prov:type: Person , prov:location: ?] does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#BuyerColnaghi,[prov:type: Person , prov:location: ?] does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#BuyerColnaghi,[prov:type: Person , prov:location: ?] does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#BuyerColnaghi,[prov:type: Person , prov:location: ?] does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Auctioned£ 1,100 does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Auctioned£ 1,100 does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Auctioned£ 1,100 does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Auctioned£ 1,100 does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Auctioned£ 1,100 does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Auctioned£ 1,100 does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#BuyerColnaghi,[prov:type: Person , prov:location: ?] does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Auctioned£ 1,100 does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#BuyerColnaghi,[prov:type: Person , prov:location: ?] does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Auctioned£ 1,100 does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#BuyerColnaghi,[prov:type: Person , prov:location: ?] does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Auctioned£ 1,100 does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#BuyerColnaghi,[prov:type: Person , prov:location: ?] does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Auctioned£ 1,100 does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#BuyerColnaghi,[prov:type: Person , prov:location: ?] does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Buyeranonymous sale,[prov:type: Person , prov:location: ?] does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Auctionedsale price unknown does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Buyeranonymous sale,[prov:type: Person , prov:location: ?] does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Buyeranonymous sale,[prov:type: Person , prov:location: ?] does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Buyeranonymous sale,[prov:type: Person , prov:location: ?] does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Buyeranonymous sale,[prov:type: Person , prov:location: ?] does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Auctionedsale price unknown does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Auctionedsale price unknown does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Auctionedsale price unknown does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Auctionedsale price unknown does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Auctionedsale price unknown does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Auctionedsale price unknown does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Buyeranonymous sale,[prov:type: Person , prov:location: ?] does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Auctionedsale price unknown does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Buyeranonymous sale,[prov:type: Person , prov:location: ?] does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Auctionedsale price unknown does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Buyeranonymous sale,[prov:type: Person , prov:location: ?] does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Auctionedsale price unknown does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Buyeranonymous sale,[prov:type: Person , prov:location: ?] does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Auctionedsale price unknown does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Buyeranonymous sale,[prov:type: Person , prov:location: ?] does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Buyeranonymous sale,[prov:type: Person , prov:location: ?] does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Auctionedsale price unknown does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Buyeranonymous sale,[prov:type: Person , prov:location: ?] does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Buyeranonymous sale,[prov:type: Person , prov:location: ?] does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Buyeranonymous sale,[prov:type: Person , prov:location: ?] does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Buyeranonymous sale,[prov:type: Person , prov:location: ?] does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Auctionedsale price unknown does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Auctionedsale price unknown does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Auctionedsale price unknown does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Auctionedsale price unknown does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Auctionedsale price unknown does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Auctionedsale price unknown does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Buyeranonymous sale,[prov:type: Person , prov:location: ?] does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Auctionedsale price unknown does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Buyeranonymous sale,[prov:type: Person , prov:location: ?] does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Auctionedsale price unknown does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Buyeranonymous sale,[prov:type: Person , prov:location: ?] does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Auctionedsale price unknown does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Buyeranonymous sale,[prov:type: Person , prov:location: ?] does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Auctionedsale price unknown does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Buyeranonymous sale,[prov:type: Person , prov:location: ?] does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#BuyerHeilbronner,[prov:type: Person , prov:location: Berlin] does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#AuctionedDM 250,000 does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#BuyerHeilbronner,[prov:type: Person , prov:location: Berlin] does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#BuyerHeilbronner,[prov:type: Person , prov:location: Berlin] does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#BuyerHeilbronner,[prov:type: Person , prov:location: Berlin] does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#BuyerHeilbronner,[prov:type: Person , prov:location: Berlin] does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#AuctionedDM 250,000 does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#AuctionedDM 250,000 does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#AuctionedDM 250,000 does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#AuctionedDM 250,000 does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#AuctionedDM 250,000 does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#AuctionedDM 250,000 does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#BuyerHeilbronner,[prov:type: Person , prov:location: Berlin] does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#AuctionedDM 250,000 does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#BuyerHeilbronner,[prov:type: Person , prov:location: Berlin] does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#AuctionedDM 250,000 does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#BuyerHeilbronner,[prov:type: Person , prov:location: Berlin] does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#AuctionedDM 250,000 does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#BuyerHeilbronner,[prov:type: Person , prov:location: Berlin] does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#AuctionedDM 250,000 does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#BuyerHeilbronner,[prov:type: Person , prov:location: Berlin] does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Buyeranonymous sale,[prov:type: Person , prov:location: ?] does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Auctionedsale price unknown does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Buyeranonymous sale,[prov:type: Person , prov:location: ?] does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Buyeranonymous sale,[prov:type: Person , prov:location: ?] does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Buyeranonymous sale,[prov:type: Person , prov:location: ?] does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Buyeranonymous sale,[prov:type: Person , prov:location: ?] does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Auctionedsale price unknown does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Auctionedsale price unknown does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Auctionedsale price unknown does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Auctionedsale price unknown does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Auctionedsale price unknown does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Auctionedsale price unknown does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Buyeranonymous sale,[prov:type: Person , prov:location: ?] does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Auctionedsale price unknown does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Buyeranonymous sale,[prov:type: Person , prov:location: ?] does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Auctionedsale price unknown does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Buyeranonymous sale,[prov:type: Person , prov:location: ?] does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Auctionedsale price unknown does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Buyeranonymous sale,[prov:type: Person , prov:location: ?] does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Auctionedsale price unknown does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Buyeranonymous sale,[prov:type: Person , prov:location: ?] does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Buyeranonymous sale,[prov:type: Person , prov:location: ?] does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Auctionedsale price unknown does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Buyeranonymous sale,[prov:type: Person , prov:location: ?] does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Buyeranonymous sale,[prov:type: Person , prov:location: ?] does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Buyeranonymous sale,[prov:type: Person , prov:location: ?] does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Buyeranonymous sale,[prov:type: Person , prov:location: ?] does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Auctionedsale price unknown does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Auctionedsale price unknown does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Auctionedsale price unknown does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Auctionedsale price unknown does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Auctionedsale price unknown does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Auctionedsale price unknown does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Buyeranonymous sale,[prov:type: Person , prov:location: ?] does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Auctionedsale price unknown does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Buyeranonymous sale,[prov:type: Person , prov:location: ?] does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Auctionedsale price unknown does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Buyeranonymous sale,[prov:type: Person , prov:location: ?] does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Auctionedsale price unknown does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Buyeranonymous sale,[prov:type: Person , prov:location: ?] does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Auctionedsale price unknown does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Buyeranonymous sale,[prov:type: Person , prov:location: ?] does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Buyeranonymous sale,[prov:type: Person , prov:location: ?] does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Auctionedsale price unknown does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Buyeranonymous sale,[prov:type: Person , prov:location: ?] does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Buyeranonymous sale,[prov:type: Person , prov:location: ?] does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Buyeranonymous sale,[prov:type: Person , prov:location: ?] does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Buyeranonymous sale,[prov:type: Person , prov:location: ?] does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Auctionedsale price unknown does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Auctionedsale price unknown does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Auctionedsale price unknown does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Auctionedsale price unknown does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Auctionedsale price unknown does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Auctionedsale price unknown does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Buyeranonymous sale,[prov:type: Person , prov:location: ?] does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Auctionedsale price unknown does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Buyeranonymous sale,[prov:type: Person , prov:location: ?] does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Auctionedsale price unknown does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Buyeranonymous sale,[prov:type: Person , prov:location: ?] does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Auctionedsale price unknown does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Buyeranonymous sale,[prov:type: Person , prov:location: ?] does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Auctionedsale price unknown does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Buyeranonymous sale,[prov:type: Person , prov:location: ?] does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Buyeranonymous sale,[prov:type: Person , prov:location: ?] does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Auctionedsale price unknown does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Buyeranonymous sale,[prov:type: Person , prov:location: ?] does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Buyeranonymous sale,[prov:type: Person , prov:location: ?] does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Buyeranonymous sale,[prov:type: Person , prov:location: ?] does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Buyeranonymous sale,[prov:type: Person , prov:location: ?] does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Auctionedsale price unknown does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Auctionedsale price unknown does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Auctionedsale price unknown does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Auctionedsale price unknown does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Auctionedsale price unknown does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Auctionedsale price unknown does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Buyeranonymous sale,[prov:type: Person , prov:location: ?] does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Auctionedsale price unknown does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Buyeranonymous sale,[prov:type: Person , prov:location: ?] does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Auctionedsale price unknown does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Buyeranonymous sale,[prov:type: Person , prov:location: ?] does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Auctionedsale price unknown does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Buyeranonymous sale,[prov:type: Person , prov:location: ?] does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Auctionedsale price unknown does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Buyeranonymous sale,[prov:type: Person , prov:location: ?] does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Buyerthe Rijksmuseum-Stichting,[prov:type: Person , prov:location: ?] does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#AuctionedDM 5,600 does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Buyerthe Rijksmuseum-Stichting,[prov:type: Person , prov:location: ?] does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Buyerthe Rijksmuseum-Stichting,[prov:type: Person , prov:location: ?] does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Buyerthe Rijksmuseum-Stichting,[prov:type: Person , prov:location: ?] does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Buyerthe Rijksmuseum-Stichting,[prov:type: Person , prov:location: ?] does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#AuctionedDM 5,600 does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#AuctionedDM 5,600 does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#AuctionedDM 5,600 does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#AuctionedDM 5,600 does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#AuctionedDM 5,600 does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#AuctionedDM 5,600 does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Buyerthe Rijksmuseum-Stichting,[prov:type: Person , prov:location: ?] does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#AuctionedDM 5,600 does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Buyerthe Rijksmuseum-Stichting,[prov:type: Person , prov:location: ?] does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#AuctionedDM 5,600 does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Buyerthe Rijksmuseum-Stichting,[prov:type: Person , prov:location: ?] does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#AuctionedDM 5,600 does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Buyerthe Rijksmuseum-Stichting,[prov:type: Person , prov:location: ?] does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#AuctionedDM 5,600 does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Buyerthe Rijksmuseum-Stichting,[prov:type: Person , prov:location: ?] does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Buyerthe Rijksmuseum-Stichting,[prov:type: Person , prov:location: ?] does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#AuctionedDM 5,600 does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Buyerthe Rijksmuseum-Stichting,[prov:type: Person , prov:location: ?] does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Buyerthe Rijksmuseum-Stichting,[prov:type: Person , prov:location: ?] does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Buyerthe Rijksmuseum-Stichting,[prov:type: Person , prov:location: ?] does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Buyerthe Rijksmuseum-Stichting,[prov:type: Person , prov:location: ?] does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#AuctionedDM 5,600 does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#AuctionedDM 5,600 does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#AuctionedDM 5,600 does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#AuctionedDM 5,600 does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#AuctionedDM 5,600 does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#AuctionedDM 5,600 does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Buyerthe Rijksmuseum-Stichting,[prov:type: Person , prov:location: ?] does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#AuctionedDM 5,600 does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Buyerthe Rijksmuseum-Stichting,[prov:type: Person , prov:location: ?] does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#AuctionedDM 5,600 does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Buyerthe Rijksmuseum-Stichting,[prov:type: Person , prov:location: ?] does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#AuctionedDM 5,600 does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Buyerthe Rijksmuseum-Stichting,[prov:type: Person , prov:location: ?] does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#AuctionedDM 5,600 does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Buyerthe Rijksmuseum-Stichting,[prov:type: Person , prov:location: ?] does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#BuyerAdolph Staring van de Wildenborch (1890-1980),[prov:type: Person , prov:location: Deventer] does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Auctioned fl. 60 does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#BuyerAdolph Staring van de Wildenborch (1890-1980),[prov:type: Person , prov:location: Deventer] does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#BuyerAdolph Staring van de Wildenborch (1890-1980),[prov:type: Person , prov:location: Deventer] does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#BuyerAdolph Staring van de Wildenborch (1890-1980),[prov:type: Person , prov:location: Deventer] does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#BuyerAdolph Staring van de Wildenborch (1890-1980),[prov:type: Person , prov:location: Deventer] does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Auctioned fl. 60 does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Auctioned fl. 60 does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Auctioned fl. 60 does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Auctioned fl. 60 does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Auctioned fl. 60 does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Auctioned fl. 60 does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#BuyerAdolph Staring van de Wildenborch (1890-1980),[prov:type: Person , prov:location: Deventer] does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Auctioned fl. 60 does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#BuyerAdolph Staring van de Wildenborch (1890-1980),[prov:type: Person , prov:location: Deventer] does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Auctioned fl. 60 does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#BuyerAdolph Staring van de Wildenborch (1890-1980),[prov:type: Person , prov:location: Deventer] does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Auctioned fl. 60 does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#BuyerAdolph Staring van de Wildenborch (1890-1980),[prov:type: Person , prov:location: Deventer] does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Auctioned fl. 60 does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#BuyerAdolph Staring van de Wildenborch (1890-1980),[prov:type: Person , prov:location: Deventer] does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#BuyerAdolph Staring van de Wildenborch (1890-1980),[prov:type: Person , prov:location: Deventer] does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Auctioned fl. 38 does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#BuyerAdolph Staring van de Wildenborch (1890-1980),[prov:type: Person , prov:location: Deventer] does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#BuyerAdolph Staring van de Wildenborch (1890-1980),[prov:type: Person , prov:location: Deventer] does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#BuyerAdolph Staring van de Wildenborch (1890-1980),[prov:type: Person , prov:location: Deventer] does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#BuyerAdolph Staring van de Wildenborch (1890-1980),[prov:type: Person , prov:location: Deventer] does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Auctioned fl. 38 does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Auctioned fl. 38 does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Auctioned fl. 38 does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Auctioned fl. 38 does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Auctioned fl. 38 does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Auctioned fl. 38 does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#BuyerAdolph Staring van de Wildenborch (1890-1980),[prov:type: Person , prov:location: Deventer] does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Auctioned fl. 38 does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#BuyerAdolph Staring van de Wildenborch (1890-1980),[prov:type: Person , prov:location: Deventer] does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Auctioned fl. 38 does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#BuyerAdolph Staring van de Wildenborch (1890-1980),[prov:type: Person , prov:location: Deventer] does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Auctioned fl. 38 does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#BuyerAdolph Staring van de Wildenborch (1890-1980),[prov:type: Person , prov:location: Deventer] does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Auctioned fl. 38 does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#BuyerAdolph Staring van de Wildenborch (1890-1980),[prov:type: Person , prov:location: Deventer] does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#BuyerAdolph Staring van de Wildenborch (1890-1980),[prov:type: Person , prov:location: Deventer] does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Auctioned fl. 10 does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#BuyerAdolph Staring van de Wildenborch (1890-1980),[prov:type: Person , prov:location: Deventer] does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#BuyerAdolph Staring van de Wildenborch (1890-1980),[prov:type: Person , prov:location: Deventer] does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#BuyerAdolph Staring van de Wildenborch (1890-1980),[prov:type: Person , prov:location: Deventer] does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#BuyerAdolph Staring van de Wildenborch (1890-1980),[prov:type: Person , prov:location: Deventer] does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Auctioned fl. 10 does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Auctioned fl. 10 does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Auctioned fl. 10 does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Auctioned fl. 10 does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Auctioned fl. 10 does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Auctioned fl. 10 does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#BuyerAdolph Staring van de Wildenborch (1890-1980),[prov:type: Person , prov:location: Deventer] does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Auctioned fl. 10 does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#BuyerAdolph Staring van de Wildenborch (1890-1980),[prov:type: Person , prov:location: Deventer] does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Auctioned fl. 10 does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#BuyerAdolph Staring van de Wildenborch (1890-1980),[prov:type: Person , prov:location: Deventer] does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Auctioned fl. 10 does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#BuyerAdolph Staring van de Wildenborch (1890-1980),[prov:type: Person , prov:location: Deventer] does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Auctioned fl. 10 does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#BuyerAdolph Staring van de Wildenborch (1890-1980),[prov:type: Person , prov:location: Deventer] does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#BuyerAdolph Staring van de Wildenborch (1890-1980),[prov:type: Person , prov:location: Deventer] does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Auctioned fl. 130 does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#BuyerAdolph Staring van de Wildenborch (1890-1980),[prov:type: Person , prov:location: Deventer] does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#BuyerAdolph Staring van de Wildenborch (1890-1980),[prov:type: Person , prov:location: Deventer] does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#BuyerAdolph Staring van de Wildenborch (1890-1980),[prov:type: Person , prov:location: Deventer] does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#BuyerAdolph Staring van de Wildenborch (1890-1980),[prov:type: Person , prov:location: Deventer] does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Auctioned fl. 130 does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Auctioned fl. 130 does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Auctioned fl. 130 does not look like a valid URI, trying to serialize this will break.
# ...
# http://www.example.org/rijks_prov#Buyeranonymous sale,[prov:type: Person , prov:location: ?] does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Buyeranonymous sale,[prov:type: Person , prov:location: ?] does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Buyeranonymous sale,[prov:type: Person , prov:location: ?] does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Auctionedsale price unknown does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Auctionedsale price unknown does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Auctionedsale price unknown does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Auctionedsale price unknown does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Auctionedsale price unknown does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Auctionedsale price unknown does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Buyeranonymous sale,[prov:type: Person , prov:location: ?] does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Auctionedsale price unknown does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Buyeranonymous sale,[prov:type: Person , prov:location: ?] does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Auctionedsale price unknown does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Buyeranonymous sale,[prov:type: Person , prov:location: ?] does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Auctionedsale price unknown does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Buyeranonymous sale,[prov:type: Person , prov:location: ?] does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Auctionedsale price unknown does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Buyeranonymous sale,[prov:type: Person , prov:location: ?] does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Buyeranonymous sale,[prov:type: Person , prov:location: ?] does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Auctionedsale price unknown does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Buyeranonymous sale,[prov:type: Person , prov:location: ?] does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Buyeranonymous sale,[prov:type: Person , prov:location: ?] does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Buyeranonymous sale,[prov:type: Person , prov:location: ?] does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Buyeranonymous sale,[prov:type: Person , prov:location: ?] does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Auctionedsale price unknown does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Auctionedsale price unknown does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Auctionedsale price unknown does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Auctionedsale price unknown does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Auctionedsale price unknown does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Auctionedsale price unknown does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Buyeranonymous sale,[prov:type: Person , prov:location: ?] does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Auctionedsale price unknown does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Buyeranonymous sale,[prov:type: Person , prov:location: ?] does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Auctionedsale price unknown does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Buyeranonymous sale,[prov:type: Person , prov:location: ?] does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Auctionedsale price unknown does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Buyeranonymous sale,[prov:type: Person , prov:location: ?] does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Auctionedsale price unknown does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Buyeranonymous sale,[prov:type: Person , prov:location: ?] does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#BuyerAntoon van Welie (1866-1956),[prov:type: Person , prov:location: The Hague] does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Auctionedsale price unknown does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#BuyerAntoon van Welie (1866-1956),[prov:type: Person , prov:location: The Hague] does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#BuyerAntoon van Welie (1866-1956),[prov:type: Person , prov:location: The Hague] does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#BuyerAntoon van Welie (1866-1956),[prov:type: Person , prov:location: The Hague] does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#BuyerAntoon van Welie (1866-1956),[prov:type: Person , prov:location: The Hague] does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Auctionedsale price unknown does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Auctionedsale price unknown does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Auctionedsale price unknown does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Auctionedsale price unknown does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Auctionedsale price unknown does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Auctionedsale price unknown does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#BuyerAntoon van Welie (1866-1956),[prov:type: Person , prov:location: The Hague] does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Auctionedsale price unknown does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#BuyerAntoon van Welie (1866-1956),[prov:type: Person , prov:location: The Hague] does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Auctionedsale price unknown does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#BuyerAntoon van Welie (1866-1956),[prov:type: Person , prov:location: The Hague] does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Auctionedsale price unknown does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#BuyerAntoon van Welie (1866-1956),[prov:type: Person , prov:location: The Hague] does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Auctionedsale price unknown does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#BuyerAntoon van Welie (1866-1956),[prov:type: Person , prov:location: The Hague] does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#BuyerAntoon Derkinderen (1859-1925),[prov:type: Person , prov:location: Amsterdam] does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Auctioned fl. 410 does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#BuyerAntoon Derkinderen (1859-1925),[prov:type: Person , prov:location: Amsterdam] does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#BuyerAntoon Derkinderen (1859-1925),[prov:type: Person , prov:location: Amsterdam] does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#BuyerAntoon Derkinderen (1859-1925),[prov:type: Person , prov:location: Amsterdam] does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#BuyerAntoon Derkinderen (1859-1925),[prov:type: Person , prov:location: Amsterdam] does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Auctioned fl. 410 does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Auctioned fl. 410 does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Auctioned fl. 410 does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Auctioned fl. 410 does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Auctioned fl. 410 does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Auctioned fl. 410 does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#BuyerAntoon Derkinderen (1859-1925),[prov:type: Person , prov:location: Amsterdam] does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Auctioned fl. 410 does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#BuyerAntoon Derkinderen (1859-1925),[prov:type: Person , prov:location: Amsterdam] does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Auctioned fl. 410 does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#BuyerAntoon Derkinderen (1859-1925),[prov:type: Person , prov:location: Amsterdam] does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Auctioned fl. 410 does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#BuyerAntoon Derkinderen (1859-1925),[prov:type: Person , prov:location: Amsterdam] does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#Auctioned fl. 410 does not look like a valid URI, trying to serialize this will break.
# http://www.example.org/rijks_prov#BuyerAntoon Derkinderen (1859-1925),[prov:type: Person , prov:location: Amsterdam] does not look like a valid URI, trying to serialize this will break.
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-6-6cf6f9a947e9> in <module>()
# ----> 1 rijksmuseum.serialize('test_file', format='rdf', rdf_format='ttl')
#
# ~\Anaconda3\lib\site-packages\prov\model.py in serialize(self, destination, format, **args)
#    2400             fd, name = tempfile.mkstemp()
#    2401             stream = os.fdopen(fd, "wb")
# -> 2402             serializer.serialize(stream, **args)
#    2403             stream.close()
#    2404             if hasattr(shutil, "move"):
#
# ~\Anaconda3\lib\site-packages\prov\serializers\provrdf.py in serialize(self, stream, rdf_format, **kwargs)
#     109             buf = io.BytesIO()
#     110             try:
# --> 111                 container.serialize(buf, **newargs)
#     112                 buf.seek(0, 0)
#     113                 # Right now this is a bytestream. If the object to stream to is
#
# ~\Anaconda3\lib\site-packages\rdflib\graph.py in serialize(self, destination, format, base, encoding, **args)
#     945         if hasattr(destination, "write"):
#     946             stream = destination
# --> 947             serializer.serialize(stream, base=base, encoding=encoding, **args)
#     948         else:
#     949             location = destination
#
# ~\Anaconda3\lib\site-packages\rdflib\plugins\serializers\turtle.py in serialize(self, stream, base, encoding, spacious, **args)
#     230             if firstTime:
#     231                 firstTime = False
# --> 232             if self.statement(subject) and not firstTime:
#     233                 self.write('\n')
#     234
#
# ~\Anaconda3\lib\site-packages\rdflib\plugins\serializers\turtle.py in statement(self, subject)
#     291     def statement(self, subject):
#     292         self.subjectDone(subject)
# --> 293         return self.s_squared(subject) or self.s_default(subject)
#     294
#     295     def s_default(self, subject):
#
# ~\Anaconda3\lib\site-packages\rdflib\plugins\serializers\turtle.py in s_default(self, subject)
#     295     def s_default(self, subject):
#     296         self.write('\n' + self.indent())
# --> 297         self.path(subject, SUBJECT)
#     298         self.predicateList(subject)
#     299         self.write(' .')
#
# ~\Anaconda3\lib\site-packages\rdflib\plugins\serializers\turtle.py in path(self, node, position, newline)
#     310     def path(self, node, position, newline=False):
#     311         if not (self.p_squared(node, position, newline)
# --> 312                 or self.p_default(node, position, newline)):
#     313             raise Error("Cannot serialize node '%s'" % (node, ))
#     314
#
# ~\Anaconda3\lib\site-packages\rdflib\plugins\serializers\turtle.py in p_default(self, node, position, newline)
#     316         if position != SUBJECT and not newline:
#     317             self.write(' ')
# --> 318         self.write(self.label(node, position))
#     319         return True
#     320
#
# ~\Anaconda3\lib\site-packages\rdflib\plugins\serializers\turtle.py in label(self, node, position)
#     332             node = self.relativize(node)
#     333
# --> 334             return self.getQName(node, position == VERB) or node.n3()
#     335
#     336     def p_squared(self, node, position, newline=False):
#
# ~\Anaconda3\lib\site-packages\rdflib\term.py in n3(self, namespace_manager)
#     245
#     246         if not _is_valid_uri(self):
# --> 247             raise Exception('"%s" does not look like a valid URI, I cannot serialize this as N3/Turtle. Perhaps you wanted to urlencode it?'%self)
#     248
#     249         if namespace_manager:
#
# Exception: "http://www.example.org/rijks_prov#Auctioned $ 71" does not look like a valid URI, I cannot serialize this as N3/Turtle. Perhaps you wanted to urlencode it?

# %%
#function for all auction items
def auction_item(item):
    """
    Parse provenance items sold at an auction and return the new proper format, the readable sentence, and the format if the item is suspicious
    """
    start_source = ''
    sale_section = ''
    owner = ''
    BDDate = ''
    place_collection = ''
    place_auction = ''
    auctionhouse = ''
    date_auction = ''
    kavel_no = ''
    attribution = ''
    description = ''
    pendant = ''
    pendant_extra = ''
    price = ''
    buyer = ''
    buyer_city = ''
    supporter = ''
    source = ''
    anonymous = False
    his = False
    her = False
    start_item = item
        
    certain_uncertain = item.split('(')
    if '?' in certain_uncertain[0]:
        #provenance data is uncertain
        proper_format = '? '
        readable_sent = 'Possibly sold by'
    else:
        #provenance data is certain
        proper_format = ''
        readable_sent = 'Sold by'
    #start_source
    source_split = item.split('}')
    if len(source_split) >1:
        if ('sale' in source_split[0] or 'Sale' in source_split[0]) and not 'sale' in source_split[1] and not 'Sale' in source_split[1]:
            return 'Wrongly assigned due to source information', 'Wrongly assigned due to source information', 'Wrongly assigned due to source information'
        if 'sale' in source_split[1]:
            start_source = source_split[0].replace('{', '').strip()
    #source
    if start_source == '':
        source_split = item.split('{')
        if len(source_split) >1:
            source = source_split[1].replace('}', '').strip()
        
    #item without source
    if start_source != '':
        item = item.replace(start_source, '').strip()
        start_source = '{'+start_source+'}'
    if source != '':
        item = item.replace(source, '').strip()
        source = '{'+source+'}'

    comma_split = item.split(',')
    #name of owner
    if 'anonymous sale' in comma_split[0]:
        anonymous = True
        owner = ''
        if 'section' in comma_split[0]:
            square_split = item.split('[')
            sale_section = square_split[1]
            sale_section = sale_section.split(']')
            sale_section = sale_section[0].strip()
    elif 'his' in comma_split[0] and 'sale' in comma_split[0]:
        his = True
        owner = ''
    elif 'her' in comma_split[0] and 'sale' in comma_split[0]:
        her = True
        owner = ''
    else:
        owner = comma_split[1].split('(')
        owner = owner[0].strip()
        
    #if et al. in owner
    if 'et al.' in owner:
        square_split = item.split('[')
        if len(square_split) >1:
            if 'section' in square_split[1]:
                square_split = square_split[1].split(']')
                owner = owner + ' [' + square_split[0].strip() + ']'
                item = item.replace(square_split[0],'')
    #new comma split in case there was a section item
    comma_split = item.split(',')
    if 'et al.' in comma_split[2]:
        owner = owner + ', ' + comma_split[2]
        owner = owner.strip()
    
    #birth/death date owner and place of collection before sale
    if owner != '':
        BDDate_item = comma_split[1]
        if '†' in BDDate_item:
            BDdate = '†'
        elif ('1' in BDDate_item or '2' in BDDate_item) and not 'collection' in comma_split[2]:
            BDsplit = BDDate_item.split('(')
            BDDate = BDsplit[1].replace(')', '').strip()
            if not BDsplit[1].endswith(')'):
                place_collection = comma_split[2].replace(')','').strip()                
    
    #place of auction and auction house
    #for anonymous sale:
    if owner == '':
        place_auction_item = comma_split[1]
        auction_split = place_auction_item.split('(')
        place_auction = auction_split[0].strip()
        if len(auction_split) >1:
            auctionhouse = auction_split[1].replace(')', '').strip()
    #for known owner
    
    if owner != '' and place_collection == '':
        if 'et al.' in owner and ',' in owner:
            place_auction_item = comma_split[3]
        else:
            place_auction_item = comma_split[2]
        auction_split = place_auction_item.split('(')
        place_auction = auction_split[0].strip()
        if len(auction_split) > 1:
            auctionhouse = auction_split[1].replace(')', '').strip()
    if owner != '' and place_collection != '':
        if 'et al.' in owner and ',' in owner:
            place_auction_item = comma_split[4]
        else:
            place_auction_item = comma_split[3]
        auction_split = place_auction_item.split('(')
        place_auction = auction_split[0].strip()
        if len(auction_split) > 1:
            auctionhouse = auction_split[1].replace(')', '').strip()
            if '1' in auctionhouse:
                date_auction = auctionhouse
                auctionhouse = ''
      
    if '1' in auctionhouse:
        date_auction = auctionhouse
        auctionhouse = ''
    #date auction
    #for anonymous sale
    if owner == '':
        if 'no.' not in comma_split[2]:
            date_auction = comma_split[2].strip()
    #for known owner
    elif owner != '' and place_collection == '' and date_auction =='':
        if 'et al.' in owner and ',' in owner:
            if 'no.' not in comma_split[4]:
                date_auction = comma_split[4].strip()
        else:
            if 'no.' not in comma_split[3]:
                date_auction = comma_split[3].strip()
    elif owner != '' and place_collection != '' and len(comma_split) >4 and date_auction =='':
        if 'et al.' in owner and ',' in owner:
            if 'no.' not in comma_split[5]:
                date_auction = comma_split[5].strip()
        else:
            if 'no.' not in comma_split[4]:
                date_auction = comma_split[4].strip()
        
    #kavel no, price, attribution, pendant, pendant extra
    for item in comma_split:
        if 'no.' in item and kavel_no == '':
            kavel_no = item.strip()
        money = (' fl. ', ' frs. ', ' bf ', '£', ' gns ', ' s ', '$', ' DM ', ' CHF ', ' CAD ', ' ATS ')
        for valuta in money:
            if valuta in item:
                price = item
                price_index = comma_split.index(price)
                if len(comma_split) > price_index+2:
                    if comma_split[price_index+1].isnumeric():
                        price = price+','+comma_split[price_index+1]
                        price = price.strip()
        if ' to ' in item:
            buyer_index = item
            buyer = item.strip()
            #is the city of the buyer specified
            buyer_index = comma_split.index(buyer_index)
            if (len(comma_split) > (buyer_index + 1)) and 'with support' not in comma_split[(buyer_index+1)]:
                buyer_city = comma_split[(buyer_index+1)].strip()
        if 'with support' in item:
            supporter = item.strip()
        if 'without attribution' in item:
            attribution = item.strip()
        if ' as ' in item:
            attribution = item.strip()
        if 'with pendant' in item:
            pendant = item.strip()
        if pendant != '':                     
            if 'no.' in item:
                item_index_1 = comma_split.index(item)
                for item in comma_split:
                    for valuta in money:
                        if valuta in item:
                            item_index_2 = comma_split.index(item)
                            pendant_extra = comma_split[int(item_index_1):item_index_2]
                            pendant_extra = ','.join(pendant_extra)
                            
    para_split = item.split('(')
    for item in para_split:
        if item.startswith("'"):
            description = item.split(')')
            description = description[0].strip()
            
    #proper format and readable sentence
    #proper format
    if start_source != '':
        proper_format = f"{start_source} {proper_format}"
    if anonymous == True and sale_section == '':
        proper_format = f"{proper_format}anonymous sale"
    if anonymous == True and sale_section != '':
        proper_format = f"{proper_format}anonymous sale [{sale_section}]"
    if his == True:
        proper_format = f"{proper_format}his sale"
    if her == True:
        proper_format = f"{proper_format}her sale"
    if anonymous == False and his == False and her == False:
        proper_format = f"{proper_format}sale"
    if owner != '' and anonymous == False and his == False and her == False:
        proper_format = f"{proper_format}, {owner}"
    if BDDate != '' and place_collection == '':
        proper_format = f"{proper_format} ({BDDate})"
    if BDDate != '' and place_collection != '':
        proper_format = f"{proper_format} ({BDDate}, {place_collection})"
    if place_auction != '':
        proper_format = f"{proper_format}, {place_auction}"
    if auctionhouse != '':
        proper_format = f"{proper_format} ({auctionhouse})"
    if date_auction != '':
        proper_format = f"{proper_format}, {date_auction}"
    if kavel_no != '':
        proper_format = f"{proper_format}, {kavel_no}"
    if attribution != '':
        proper_format = f"{proper_format}, {attribution}"
    if description != '':
        proper_format = f"{proper_format} ({description})"
    if pendant != '':
        proper_format = f"{proper_format}, {pendant}"
    if pendant_extra != '':
        proper_format = f"{proper_format}, {pendant_extra}"
    if price != '':
        proper_format = f"{proper_format}, {price}"
    if buyer != '':
        proper_format = f"{proper_format}, {buyer}"
    if buyer_city != '':
        proper_format = f"{proper_format}, {buyer_city}"
    if supporter != '':
        proper_format = f"{proper_format}, {supporter}"
    if source != '':
        proper_format = f"{proper_format} {source}"
    
    #readable sentence
    if anonymous == True and sale_section == '':
        readable_sent = f"{readable_sent} anonymous"
    if anonymous == True and sale_section != '':
        readable_sent = f"{readable_sent} anonymous [{sale_section}]"
    if his == True:
        readable_sent = f"{readable_sent} him"
    if her == True:
        readable_sent = f"{readable_sent} her"
    if anonymous == False and his == False and her == False and owner != '':
        readable_sent = f"{readable_sent} {owner}"
    if BDDate != '' and place_collection == '':
        readable_sent = f"{readable_sent} ({BDDate})"
    if BDDate != '' and place_collection != '':
        readable_sent = f"{readable_sent} ({BDDate}, item previously kept in {place_collection})"
    if place_auction != '':
        readable_sent = f"{readable_sent}, auctioned off in {place_auction}"
    if auctionhouse != '':
        readable_sent = f"{readable_sent} (auction house {auctionhouse})"
    if date_auction != '':
        readable_sent = f"{readable_sent} on {date_auction}"
    if kavel_no != '':
        readable_sent = f"{readable_sent}, {kavel_no}"
    if attribution != '':
        readable_sent = f"{readable_sent}, {attribution}"
    if description != '':
        readable_sent = f"{readable_sent} ({description})"
    if pendant != '':
        readable_sent = f"{readable_sent}, {pendant}"
    if pendant_extra != '':
        readable_sent = f"{readable_sent}, {pendant_extra}"
    if price != '':
        readable_sent = f"{readable_sent}, bought for {price}"
    if buyer != '':
        readable_sent = f"{readable_sent}, sold {buyer}"
    if buyer_city != '':
        readable_sent = f"{readable_sent}, {buyer_city}"
    if supporter != '':
        readable_sent = f"{readable_sent}, {supporter}"
    readable_sent = f"{readable_sent}."
    
    if start_source != '':
        source = start_source
    
    parsed_dict = {'Source' : source, 'Section of the sale' : sale_section, 'Owner name' : owner, 'Owner Birth and Death Date' : BDDate, 'Place collection was stored': place_collection, 'Place of auction' : place_auction, 'Auction house' : auctionhouse, 'Date of auction' : date_auction, 'Kavel' : kavel_no, 'Attribution' : attribution, 'Description' : description, 'Pendant' : pendant, 'Pendant extra information' : pendant_extra, 'Price' : price, 'Buyer' : buyer, 'City of buyer': buyer_city, 'Supporter of buy' : supporter}
    
    return proper_format, readable_sent, parsed_dict
